# %%
import tensorflow as tf
import sys
import time
import os
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
import gym
import random
import tensorboard
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
#tf.compat.v1.disable_eager_execution()

# %%
def clean_tensorboard():
    import os
    tensor_board_sess_path = 'C:/Users/Eaj59/AppData/Local/Temp/.tensorboard-info/'
    temp_sess_files = os.listdir(tensor_board_sess_path)
    for i in temp_sess_files:
        temp_file_path = os.path.join(tensor_board_sess_path,i)
        os.remove(temp_file_path)

# %%
#clean_tensorboard()
#%load_ext tensorboard
#%tensorboard --logdir 'C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/log_dir'

# %%
class Agent():
    
    def __init__(self,env_name,enable_tb_logging=False,enable_dueling=True):
        self.env = gym.make(env_name)
        self.env_state = self.env.reset()
        self.lr = 0.001
        self.gamma = .95
        self.epsilon_decay_rate = .99
        self.initializer = tf.keras.initializers.HeUniform(seed=None)
        self.loss_fn = tf.keras.losses.Huber(delta=1.0)
        self.optimizer = tf.keras.optimizers.Adam(lr=self.lr)
        self.n_actions = self.env.action_space.n
        self.n_states = self.env.observation_space.shape[0]
        self.buffer = ReplayBuffer(max_len=10000)
        self.tau = 0.10
        self.batch_size = 32
        self.epsilon = 1
        self.min_epsilon = .001
        self.dueling_method = 'max'
        self.enable_tb_logging = enable_tb_logging
        self.enable_dueling = enable_dueling
        self.episodic_rewards = 0
        self.episode_counter = 0
        self.episode_time_step_counter = 0
        

        if self.enable_dueling:
            self.online = self.make_dueling_nn()
        else:
            self.online = self.make_nn()
            
        self.target = self.make_target()
        
        if self.enable_tb_logging:
            self.online_run_id, self.online_tensor_board_callback = self.create_tensor_board_callback(model_name='Soft_10_Target_MAX_Dueling_DDQN_Huber')
            self.training_steps_counter = 0
        
    def reset_env(self):
        self.episode_counter+=1
        if self.enable_tb_logging:
            with self.online_tensor_board_callback.as_default():
                tf.summary.scalar(name='Episode_Reward',data=self.episodic_rewards,step=self.episode_counter)
                tf.summary.scalar(name='Episode_Time_Steps',data=self.episode_time_step_counter,step=self.episode_counter)
        self.episodic_rewards = 0
        self.episode_time_step_counter = 0
        self.env_state = self.env.reset()
        
        
    def generate_run_directory(self,root_log_dir,model_name):
        run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
        run_id = model_name+'_'+run_id
        base_dir = 'C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL'
        os.chdir('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/log_dir')
        os.mkdir(run_id)
        os.chdir(base_dir)
        return run_id
        
    
    def create_tensor_board_callback(self,model_name):
        root_log_dir = os.path.join(os.curdir,'log_dir')
        run_id = self.generate_run_directory(root_log_dir=root_log_dir,model_name=model_name)
        model_cb_path = os.path.join(root_log_dir,run_id)
        file_writer = tf.summary.create_file_writer(model_cb_path)
        return run_id, file_writer
    
        
        
    def make_nn(self):
        online = tf.keras.models.Sequential()
        online.add(tf.keras.layers.Dense(24,input_dim=self.n_states,activation='swish',kernel_initializer=self.initializer))
        online.add(tf.keras.layers.Dense(24, activation='swish',kernel_initializer=self.initializer))
        online.add(tf.keras.layers.Dense(self.n_actions,activation='linear',kernel_initializer=self.initializer))
        online.compile(loss=self.loss_fn,optimizer=self.optimizer,metrics=['accuracy'])
        return online
    
    def make_dueling_nn(self):
        Dueling_Input = tf.keras.layers.Input(shape=(self.n_states,),name='Dueling_Input')
        layer_1_Dense = tf.keras.layers.Dense(64,activation='swish',kernel_initializer=self.initializer,name='layer_1_Dense')(Dueling_Input)
        layer_2_Dense = tf.keras.layers.Dense(64,activation='swish',kernel_initializer=self.initializer,name='layer_2_Dense')(layer_1_Dense)
        layer_3_Dense = tf.keras.layers.Dense(36,activation='swish',kernel_initializer=self.initializer,name='layer_3_Dense')(layer_2_Dense)
        Value_Function_Dense_Layer = tf.keras.layers.Dense(512,activation='swish',kernel_initializer=self.initializer,name='Value_Function_Dense_Layer')(layer_3_Dense)
        Value_Function_Output_Layer = tf.keras.layers.Dense(1,activation='linear',kernel_initializer=self.initializer,name='Value_Function_Output_Layer')(Value_Function_Dense_Layer)
        Advantage_Function_Dense_Layer = tf.keras.layers.Dense(512,activation='swish',kernel_initializer=self.initializer,name='Advantage_Function_Dense_Layer')(layer_3_Dense)
        Advantage_Function_Ouput_Layer = tf.keras.layers.Dense(self.n_actions,activation='linear',kernel_initializer=self.initializer,name='Advantage_Function_Output_Layer')(Advantage_Function_Dense_Layer)
        
        if self.dueling_method == 'average':
            online_output = Value_Function_Output_Layer + (Advantage_Function_Ouput_Layer - tf.reduce_mean(Advantage_Function_Ouput_Layer,axis=1,keepdims=True))
            
            
        elif self.dueling_method == 'sum':
            online_output = Value_Function_Output_Layer + Advantage_Function_Ouput_Layer
           
            
        else:
            online_output = Value_Function_Output_Layer + (Advantage_Function_Ouput_Layer - tf.reduce_max(Advantage_Function_Ouput_Layer,axis=1,keepdims=True))
            
            
        online = tf.keras.Model(Dueling_Input,online_output)
        online.compile(loss=self.loss_fn,optimizer=self.optimizer,metrics=['accuracy'])
        online.summary()
        return online
            

    def make_target(self):
        target = tf.keras.models.clone_model(self.online)
        target.set_weights(self.online.get_weights())
        return target
        
        
    def epsilon_greedy_policy(self):
        if np.random.random() <= self.epsilon:
            return np.random.randint(low=0,high=self.n_actions)
        else:
            Q_values = self.online.predict(np.reshape(self.env_state,(1,len(self.env_state))))
            return np.argmax(Q_values[0])
        
        
        
    def play_one_step(self):
        state = np.array(self.env_state)
        action = self.epsilon_greedy_policy()
        next_state, reward, done, _ = self.env.step(action)
        self.buffer.add_exp(state=state, action=action, reward=reward, next_state=next_state, done=done)
        self.env_state = next_state
        self.episodic_rewards += reward
        self.episode_time_step_counter +=1
        return state, action, reward, next_state, done
        
        
    def soft_target_update(self):
        target_weights_current = self.target.get_weights()
        online_weights_current = self.online.get_weights()
        layer_counter = 0
        for tw, ow in zip(target_weights_current,online_weights_current):
            new_target_weights = (1-self.tau)*tw + (self.tau)*ow
            target_weights_current[layer_counter] = new_target_weights
            layer_counter += 1
        self.target.set_weights(target_weights_current)
        
        
    def training_step(self):
        
        if len(self.buffer)<self.batch_size:
            batch_size_instance = len(self.buffer)
        else:
            batch_size_instance = self.batch_size
            
        states,actions,rewards,next_states,dones = self.buffer.exp_sample(batch_size=batch_size_instance)
        online_state_prediction = self.online.predict(states)
        online_next_state_arg_max = tf.math.argmax(self.online.predict(next_states),axis=1)
        online_arg_max_mask = tf.one_hot(online_next_state_arg_max,depth=self.n_actions)
        target_next_state_preds = self.target.predict(next_states)
        max_target_next_state_preds = tf.reduce_sum(target_next_state_preds*online_arg_max_mask,axis=1,keepdims=True)
        q_update = rewards + (1 - dones) * self.gamma * max_target_next_state_preds
        actual_actions_mask = tf.one_hot(actions,depth=self.n_actions)
        inverse_actions_mask = tf.reverse(actual_actions_mask,axis=[-1])
        online_state_prediction = (q_update*actual_actions_mask)+(online_state_prediction*inverse_actions_mask)

        if self.enable_tb_logging:
            metrics_output = self.online.train_on_batch(states,online_state_prediction,reset_metrics=True)
            self.training_steps_counter+=1
            with self.online_tensor_board_callback.as_default():
                tf.summary.scalar(name='Batch_MSE_Loss',data=metrics_output[0],step=self.training_steps_counter)
                tf.summary.scalar(name='Accuracy',data=metrics_output[1],step=self.training_steps_counter)
                tf.summary.scalar(name='Epsilon',data=self.epsilon,step=self.training_steps_counter)
        else:
            self.online.train_on_batch(states,online_state_prediction)
        
        
        
            

    def apply_epsilon_decay(self):
        self.epsilon = max(self.epsilon * self.epsilon_decay_rate,self.min_epsilon)
        
            
    def hard_target_update(self):
        self.target.set_weights(self.online.get_weights())

# %%
class ReplayBuffer():
    
    def __init__(self,max_len):
        self.max_len = max_len
        self.buffer = deque(maxlen=self.max_len)
        
    
    def add_exp(self,state,action,reward,next_state,done):
        exp = (state,action,reward, next_state, done)
        if len(self.buffer)<= self.max_len:
            self.buffer.append(exp)
        else:
            self.buffer[0] = exp
        
    def __len__(self):
        return len(self.buffer)
    
    def exp_sample(self,batch_size):
        indices = np.random.randint(len(self.buffer), size=batch_size)
        batch = [self.buffer[index] for index in indices]
        states, actions, rewards, next_states, dones = [np.array([experience[entry] for experience in batch])for entry in range(5)]
        return states, actions, rewards[:,np.newaxis], next_states, dones[:,np.newaxis]

# %%
my_agent = Agent('LunarLander-v2',enable_tb_logging=True,enable_dueling=True)
rewards_buffer = []
max_episodes = 750
mean_score_buffer = deque(maxlen=100)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Dueling_Input (InputLayer)      [(None, 8)]          0
# __________________________________________________________________________________________________
# layer_1_Dense (Dense)           (None, 64)           576         Dueling_Input[0][0]
# __________________________________________________________________________________________________
# layer_2_Dense (Dense)           (None, 64)           4160        layer_1_Dense[0][0]
# __________________________________________________________________________________________________
# layer_3_Dense (Dense)           (None, 36)           2340        layer_2_Dense[0][0]
# __________________________________________________________________________________________________
# Advantage_Function_Dense_Layer  (None, 512)          18944       layer_3_Dense[0][0]
# __________________________________________________________________________________________________
# Advantage_Function_Output_Layer (None, 4)            2052        Advantage_Function_Dense_Layer[0]
# __________________________________________________________________________________________________
# Value_Function_Dense_Layer (Den (None, 512)          18944       layer_3_Dense[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) (None, 1)            0           Advantage_Function_Output_Layer[0
# __________________________________________________________________________________________________
# Value_Function_Output_Layer (De (None, 1)            513         Value_Function_Dense_Layer[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 4)            0           Advantage_Function_Output_Layer[0
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 4)            0           Value_Function_Output_Layer[0][0]
#                                                                  tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 47,529
# Trainable params: 47,529
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
for i in range(0,max_episodes):
    my_agent.reset_env()
    done = False
    rewards_episodic = 0
    while not(done):
        state, action, reward, next_state, done = my_agent.play_one_step()
        reward = reward if not done else -100
        rewards_episodic += reward
        #my_agent.buffer.add_exp(state, action, reward, next_state, done)
        my_agent.training_step()
        
        
    
    my_agent.apply_epsilon_decay()
    my_agent.soft_target_update()
    
    rewards_buffer.append(round(rewards_episodic,2))
    mean_score = round(np.mean(rewards_buffer))
    mean_score_buffer.append(rewards_episodic)
    recent_mean = round(np.mean(list(mean_score_buffer)))
    print("\r Episode: {}, Episode_Reward: {}, 10_Episode_Reward_Avg {}".format(i, rewards_episodic, recent_mean, end=""))
    
    
    '''if i == 500:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_500')
        
    if i == 1000:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_1000')
        
    if i == 1500:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_1500')
        
    if i == 2000:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_2000')'''
        
        
    if recent_mean >= 200.0:
        print('DQN solved problem terminating...')
        break
# Out:
#  Episode: 0, Episode_Reward: -120.31704943306323, 10_Episode_Reward_Avg -120
#  Episode: 1, Episode_Reward: -109.83881424937844, 10_Episode_Reward_Avg -115
#  Episode: 2, Episode_Reward: -136.4321925280359, 10_Episode_Reward_Avg -122
#  Episode: 3, Episode_Reward: -144.54061712085263, 10_Episode_Reward_Avg -128
#  Episode: 4, Episode_Reward: -145.31802907352966, 10_Episode_Reward_Avg -131
#  Episode: 5, Episode_Reward: -62.62096238089086, 10_Episode_Reward_Avg -120
#  Episode: 6, Episode_Reward: -82.7771844083966, 10_Episode_Reward_Avg -115
#  Episode: 7, Episode_Reward: -90.71188897467833, 10_Episode_Reward_Avg -112
#  Episode: 8, Episode_Reward: -165.36666895502663, 10_Episode_Reward_Avg -118
#  Episode: 9, Episode_Reward: -98.81136855698135, 10_Episode_Reward_Avg -116
#  Episode: 10, Episode_Reward: -305.1513542613416, 10_Episode_Reward_Avg -133
#  Episode: 11, Episode_Reward: -147.05669418880532, 10_Episode_Reward_Avg -134
#  Episode: 12, Episode_Reward: -63.43201318261844, 10_Episode_Reward_Avg -129
#  Episode: 13, Episode_Reward: -243.75643268917625, 10_Episode_Reward_Avg -137
#  Episode: 14, Episode_Reward: -185.95493532065765, 10_Episode_Reward_Avg -140
#  Episode: 15, Episode_Reward: -95.05063611230338, 10_Episode_Reward_Avg -137
#  Episode: 16, Episode_Reward: -56.933951871142995, 10_Episode_Reward_Avg -133
#  Episode: 17, Episode_Reward: -165.6372311013615, 10_Episode_Reward_Avg -134
#  Episode: 18, Episode_Reward: -13.272944596044653, 10_Episode_Reward_Avg -128
#  Episode: 19, Episode_Reward: -65.9429431281446, 10_Episode_Reward_Avg -125
#  Episode: 20, Episode_Reward: -109.53342505671162, 10_Episode_Reward_Avg -124
#  Episode: 21, Episode_Reward: -211.04019167442505, 10_Episode_Reward_Avg -128
#  Episode: 22, Episode_Reward: -64.4464494978591, 10_Episode_Reward_Avg -125
#  Episode: 23, Episode_Reward: -297.73141915196106, 10_Episode_Reward_Avg -133
#  Episode: 24, Episode_Reward: -104.38589286983938, 10_Episode_Reward_Avg -131
#  Episode: 25, Episode_Reward: -151.32201802530625, 10_Episode_Reward_Avg -132
#  Episode: 26, Episode_Reward: -163.3142880227945, 10_Episode_Reward_Avg -133
#  Episode: 27, Episode_Reward: -95.5148349903355, 10_Episode_Reward_Avg -132
#  Episode: 28, Episode_Reward: -94.58587801775018, 10_Episode_Reward_Avg -131
#  Episode: 29, Episode_Reward: -287.0581756418451, 10_Episode_Reward_Avg -136
#  Episode: 30, Episode_Reward: -79.01880361864886, 10_Episode_Reward_Avg -134
#  Episode: 31, Episode_Reward: -137.67288506896466, 10_Episode_Reward_Avg -134
#  Episode: 32, Episode_Reward: -73.98337045154223, 10_Episode_Reward_Avg -132
#  Episode: 33, Episode_Reward: -16.957022229298957, 10_Episode_Reward_Avg -129
#  Episode: 34, Episode_Reward: -262.10725832972514, 10_Episode_Reward_Avg -133
#  Episode: 35, Episode_Reward: -45.50715531591397, 10_Episode_Reward_Avg -130
#  Episode: 36, Episode_Reward: -15.130142857801133, 10_Episode_Reward_Avg -127
#  Episode: 37, Episode_Reward: -84.04154422503966, 10_Episode_Reward_Avg -126
#  Episode: 38, Episode_Reward: -428.94093050712587, 10_Episode_Reward_Avg -134
#  Episode: 39, Episode_Reward: -60.35538411873202, 10_Episode_Reward_Avg -132
#  Episode: 111, Episode_Reward: -137.0163413128208, 10_Episode_Reward_Avg -182
#  Episode: 112, Episode_Reward: -557.6388471217158, 10_Episode_Reward_Avg -187
#  Episode: 113, Episode_Reward: -416.9243658022036, 10_Episode_Reward_Avg -189
#  Episode: 114, Episode_Reward: -210.69454042478768, 10_Episode_Reward_Avg -189
#  Episode: 115, Episode_Reward: -486.772965228825, 10_Episode_Reward_Avg -193
#  Episode: 116, Episode_Reward: -136.89252870623176, 10_Episode_Reward_Avg -194
#  Episode: 117, Episode_Reward: -58.45650066988534, 10_Episode_Reward_Avg -193
#  Episode: 118, Episode_Reward: -86.40091757302714, 10_Episode_Reward_Avg -194
#  Episode: 119, Episode_Reward: -387.7619260577852, 10_Episode_Reward_Avg -197
#  Episode: 120, Episode_Reward: -405.15979734991794, 10_Episode_Reward_Avg -200
#  Episode: 121, Episode_Reward: -310.5066744841254, 10_Episode_Reward_Avg -201
#  Episode: 122, Episode_Reward: -304.6664538111463, 10_Episode_Reward_Avg -203
#  Episode: 123, Episode_Reward: -321.4424345235816, 10_Episode_Reward_Avg -204
#  Episode: 124, Episode_Reward: -444.32014898228323, 10_Episode_Reward_Avg -207
#  Episode: 125, Episode_Reward: -337.48946925168934, 10_Episode_Reward_Avg -209
#  Episode: 126, Episode_Reward: -405.95036531611925, 10_Episode_Reward_Avg -211
#  Episode: 127, Episode_Reward: -416.85977948996486, 10_Episode_Reward_Avg -214
#  Episode: 128, Episode_Reward: -107.48773950520902, 10_Episode_Reward_Avg -215
#  Episode: 129, Episode_Reward: -150.52311667582256, 10_Episode_Reward_Avg -213
#  Episode: 130, Episode_Reward: -76.47279723522769, 10_Episode_Reward_Avg -213
#  Episode: 131, Episode_Reward: -136.48055510994027, 10_Episode_Reward_Avg -213
#  Episode: 132, Episode_Reward: -457.44153012952563, 10_Episode_Reward_Avg -217
#  Episode: 133, Episode_Reward: -112.89427772086884, 10_Episode_Reward_Avg -218
#  Episode: 134, Episode_Reward: -400.75356313978847, 10_Episode_Reward_Avg -219
#  Episode: 135, Episode_Reward: -109.8314863774283, 10_Episode_Reward_Avg -220
#  Episode: 136, Episode_Reward: -480.26202327999295, 10_Episode_Reward_Avg -225
#  Episode: 137, Episode_Reward: -131.68097193141355, 10_Episode_Reward_Avg -225
#  Episode: 138, Episode_Reward: -404.8962103821236, 10_Episode_Reward_Avg -225
#  Episode: 139, Episode_Reward: -266.9370467872154, 10_Episode_Reward_Avg -227
#  Episode: 140, Episode_Reward: -93.6176296836643, 10_Episode_Reward_Avg -226
#  Episode: 141, Episode_Reward: -207.4556708794102, 10_Episode_Reward_Avg -227
#  Episode: 142, Episode_Reward: -227.51664257597685, 10_Episode_Reward_Avg -228
#  Episode: 143, Episode_Reward: -308.2026741483753, 10_Episode_Reward_Avg -230
#  Episode: 144, Episode_Reward: -181.13819661317984, 10_Episode_Reward_Avg -231
#  Episode: 145, Episode_Reward: -405.51214294634593, 10_Episode_Reward_Avg -233
#  Episode: 146, Episode_Reward: -325.87017687923435, 10_Episode_Reward_Avg -235
#  Episode: 147, Episode_Reward: -356.7882705074047, 10_Episode_Reward_Avg -237
#  Episode: 148, Episode_Reward: -419.8501125661858, 10_Episode_Reward_Avg -240
#  Episode: 149, Episode_Reward: -423.44294371214943, 10_Episode_Reward_Avg -243
#  Episode: 150, Episode_Reward: -203.0749421445307, 10_Episode_Reward_Avg -245
#  Episode: 151, Episode_Reward: -232.20560088089607, 10_Episode_Reward_Avg -244
#  Episode: 152, Episode_Reward: -221.7901312720814, 10_Episode_Reward_Avg -243
#  Episode: 153, Episode_Reward: -322.7748732595481, 10_Episode_Reward_Avg -245
#  Episode: 154, Episode_Reward: -512.3416397421505, 10_Episode_Reward_Avg -249
#  Episode: 155, Episode_Reward: -596.3651908729391, 10_Episode_Reward_Avg -253
#  Episode: 156, Episode_Reward: -417.49064937113525, 10_Episode_Reward_Avg -256
#  Episode: 157, Episode_Reward: -445.9577208325364, 10_Episode_Reward_Avg -261
#  Episode: 158, Episode_Reward: -158.78544110138048, 10_Episode_Reward_Avg -261
#  Episode: 159, Episode_Reward: -215.0086093457682, 10_Episode_Reward_Avg -260
#  Episode: 160, Episode_Reward: -510.87956612315804, 10_Episode_Reward_Avg -261
#  Episode: 161, Episode_Reward: -547.5987288899089, 10_Episode_Reward_Avg -266
#  Episode: 162, Episode_Reward: -341.8402058007762, 10_Episode_Reward_Avg -267
#  Episode: 163, Episode_Reward: -49.357010254725, 10_Episode_Reward_Avg -262
#  Episode: 164, Episode_Reward: -337.6864332086355, 10_Episode_Reward_Avg -264
#  Episode: 165, Episode_Reward: -217.88941028974702, 10_Episode_Reward_Avg -265
#  Episode: 166, Episode_Reward: -404.3196826014258, 10_Episode_Reward_Avg -268
#  Episode: 167, Episode_Reward: -373.0592632879341, 10_Episode_Reward_Avg -266
#  Episode: 168, Episode_Reward: -185.73993443291033, 10_Episode_Reward_Avg -267
#  Episode: 169, Episode_Reward: -338.56396900227446, 10_Episode_Reward_Avg -270
#  Episode: 170, Episode_Reward: -462.4250348383509, 10_Episode_Reward_Avg -274
#  Episode: 171, Episode_Reward: -392.8603729647408, 10_Episode_Reward_Avg -276
#  Episode: 172, Episode_Reward: -27.098334444033227, 10_Episode_Reward_Avg -276
#  Episode: 173, Episode_Reward: -308.4414349798867, 10_Episode_Reward_Avg -278
#  Episode: 174, Episode_Reward: -185.15566739076496, 10_Episode_Reward_Avg -277
#  Episode: 175, Episode_Reward: -98.78892275050772, 10_Episode_Reward_Avg -277
#  Episode: 176, Episode_Reward: -391.4111531856043, 10_Episode_Reward_Avg -279
#  Episode: 177, Episode_Reward: -422.16974520553975, 10_Episode_Reward_Avg -280
#  Episode: 178, Episode_Reward: -405.7278633282598, 10_Episode_Reward_Avg -281
#  Episode: 179, Episode_Reward: -54.616267259244566, 10_Episode_Reward_Avg -278
#  Episode: 180, Episode_Reward: -91.9714672485643, 10_Episode_Reward_Avg -278
#  Episode: 181, Episode_Reward: -172.9174739294453, 10_Episode_Reward_Avg -278
#  Episode: 182, Episode_Reward: -116.29520112258979, 10_Episode_Reward_Avg -278
#  Episode: 183, Episode_Reward: -286.7967075229593, 10_Episode_Reward_Avg -279
#  Episode: 184, Episode_Reward: -29.353831678098004, 10_Episode_Reward_Avg -279
#  Episode: 185, Episode_Reward: -514.5460530433947, 10_Episode_Reward_Avg -282
#  Episode: 186, Episode_Reward: -247.4287228662963, 10_Episode_Reward_Avg -282
#  Episode: 187, Episode_Reward: -244.59665626040848, 10_Episode_Reward_Avg -280
#  Episode: 188, Episode_Reward: -256.9462428955563, 10_Episode_Reward_Avg -281
#  Episode: 189, Episode_Reward: -197.59070108529406, 10_Episode_Reward_Avg -279
#  Episode: 190, Episode_Reward: -269.24448975898997, 10_Episode_Reward_Avg -281
#  Episode: 191, Episode_Reward: -244.88003466828803, 10_Episode_Reward_Avg -281
#  Episode: 192, Episode_Reward: -120.49133239882372, 10_Episode_Reward_Avg -278
#  Episode: 193, Episode_Reward: -129.7710402146066, 10_Episode_Reward_Avg -275
#  Episode: 194, Episode_Reward: -9.436576143054353, 10_Episode_Reward_Avg -272
#  Episode: 195, Episode_Reward: -340.45555676129607, 10_Episode_Reward_Avg -273
#  Episode: 196, Episode_Reward: -362.3906539744462, 10_Episode_Reward_Avg -275
#  Episode: 197, Episode_Reward: -509.2839940050184, 10_Episode_Reward_Avg -278
#  Episode: 198, Episode_Reward: -739.1339622827795, 10_Episode_Reward_Avg -283
#  Episode: 199, Episode_Reward: -296.9315180368899, 10_Episode_Reward_Avg -283
#  Episode: 200, Episode_Reward: -223.2933781820852, 10_Episode_Reward_Avg -282
#  Episode: 201, Episode_Reward: -144.54443816125524, 10_Episode_Reward_Avg -281
#  Episode: 202, Episode_Reward: -65.46556962213454, 10_Episode_Reward_Avg -278
#  Episode: 203, Episode_Reward: -97.01234381620543, 10_Episode_Reward_Avg -278
#  Episode: 204, Episode_Reward: -352.5775124939154, 10_Episode_Reward_Avg -278
#  Episode: 205, Episode_Reward: -330.20177216447837, 10_Episode_Reward_Avg -279
#  Episode: 206, Episode_Reward: -390.8319584053413, 10_Episode_Reward_Avg -282
#  Episode: 207, Episode_Reward: -265.3959315820699, 10_Episode_Reward_Avg -283
#  Episode: 208, Episode_Reward: -216.20901707056373, 10_Episode_Reward_Avg -283
#  Episode: 209, Episode_Reward: -374.18137927193953, 10_Episode_Reward_Avg -283
#  Episode: 210, Episode_Reward: -210.37849010672505, 10_Episode_Reward_Avg -284
#  Episode: 211, Episode_Reward: -101.79399176869575, 10_Episode_Reward_Avg -284
#  Episode: 212, Episode_Reward: -158.76829701589796, 10_Episode_Reward_Avg -280
#  Episode: 213, Episode_Reward: -230.8045049385673, 10_Episode_Reward_Avg -278
#  Episode: 214, Episode_Reward: -177.670101214179, 10_Episode_Reward_Avg -278
#  Episode: 215, Episode_Reward: -347.421816826895, 10_Episode_Reward_Avg -276
#  Episode: 216, Episode_Reward: -260.9824731944847, 10_Episode_Reward_Avg -278
#  Episode: 288, Episode_Reward: -648.855501947921, 10_Episode_Reward_Avg -277
#  Episode: 289, Episode_Reward: -229.00699184364146, 10_Episode_Reward_Avg -278
#  Episode: 290, Episode_Reward: -82.79237930525, 10_Episode_Reward_Avg -276
#  Episode: 291, Episode_Reward: -105.70011911749043, 10_Episode_Reward_Avg -274
#  Episode: 292, Episode_Reward: -294.6466063346878, 10_Episode_Reward_Avg -276
#  Episode: 293, Episode_Reward: -81.13985756691652, 10_Episode_Reward_Avg -276
#  Episode: 294, Episode_Reward: -167.82859782859674, 10_Episode_Reward_Avg -277
#  Episode: 295, Episode_Reward: -276.12070381413, 10_Episode_Reward_Avg -276
#  Episode: 296, Episode_Reward: -111.57269872440834, 10_Episode_Reward_Avg -274
#  Episode: 297, Episode_Reward: -36.94990497896252, 10_Episode_Reward_Avg -269
#  Episode: 298, Episode_Reward: -250.27151983588067, 10_Episode_Reward_Avg -264
#  Episode: 299, Episode_Reward: -523.5269131501781, 10_Episode_Reward_Avg -267
#  Episode: 300, Episode_Reward: -150.35914367938074, 10_Episode_Reward_Avg -266
#  Episode: 301, Episode_Reward: -504.9556593753951, 10_Episode_Reward_Avg -270
#  Episode: 302, Episode_Reward: -374.41555237047635, 10_Episode_Reward_Avg -273
#  Episode: 303, Episode_Reward: -361.5537794876254, 10_Episode_Reward_Avg -275
#  Episode: 304, Episode_Reward: -350.1198830940485, 10_Episode_Reward_Avg -275
#  Episode: 305, Episode_Reward: -183.77830132969612, 10_Episode_Reward_Avg -274
#  Episode: 306, Episode_Reward: -410.66220371846174, 10_Episode_Reward_Avg -274
#  Episode: 307, Episode_Reward: -112.38222655450954, 10_Episode_Reward_Avg -272
#  Episode: 308, Episode_Reward: -455.53100596266273, 10_Episode_Reward_Avg -275
#  Episode: 309, Episode_Reward: -123.43788737005093, 10_Episode_Reward_Avg -272
#  Episode: 310, Episode_Reward: -18.741441217019045, 10_Episode_Reward_Avg -270
#  Episode: 311, Episode_Reward: -154.06158394426552, 10_Episode_Reward_Avg -271
#  Episode: 312, Episode_Reward: -453.622931784776, 10_Episode_Reward_Avg -274
#  Episode: 313, Episode_Reward: -527.7553033694935, 10_Episode_Reward_Avg -277
#  Episode: 314, Episode_Reward: -547.326902278849, 10_Episode_Reward_Avg -281
#  Episode: 315, Episode_Reward: -135.55485254797384, 10_Episode_Reward_Avg -278
#  Episode: 316, Episode_Reward: -429.6907504902345, 10_Episode_Reward_Avg -280
#  Episode: 317, Episode_Reward: -539.3696397293631, 10_Episode_Reward_Avg -284
#  Episode: 318, Episode_Reward: -369.0141716103386, 10_Episode_Reward_Avg -283
#  Episode: 319, Episode_Reward: -336.748236870583, 10_Episode_Reward_Avg -285
#  Episode: 320, Episode_Reward: -313.40442685956157, 10_Episode_Reward_Avg -285
#  Episode: 321, Episode_Reward: -53.1086671201878, 10_Episode_Reward_Avg -286
#  Episode: 322, Episode_Reward: -310.2609030749253, 10_Episode_Reward_Avg -285
#  Episode: 323, Episode_Reward: -322.69725144840436, 10_Episode_Reward_Avg -285
#  Episode: 395, Episode_Reward: -225.5801290228032, 10_Episode_Reward_Avg -264
#  Episode: 396, Episode_Reward: -182.33397222373506, 10_Episode_Reward_Avg -265
#  Episode: 397, Episode_Reward: -516.3093495887655, 10_Episode_Reward_Avg -270
#  Episode: 398, Episode_Reward: 68.39576043620809, 10_Episode_Reward_Avg -267
#  Episode: 399, Episode_Reward: -163.19011148409916, 10_Episode_Reward_Avg -263
#  Episode: 400, Episode_Reward: -475.2221475630022, 10_Episode_Reward_Avg -266
#  Episode: 401, Episode_Reward: -146.47858949946487, 10_Episode_Reward_Avg -263
#  Episode: 402, Episode_Reward: -161.9482963688205, 10_Episode_Reward_Avg -261
#  Episode: 403, Episode_Reward: -137.70002996859048, 10_Episode_Reward_Avg -258
#  Episode: 404, Episode_Reward: -188.11992929298023, 10_Episode_Reward_Avg -257
#  Episode: 405, Episode_Reward: -408.6378497826256, 10_Episode_Reward_Avg -259
#  Episode: 406, Episode_Reward: -476.7022433042249, 10_Episode_Reward_Avg -260
#  Episode: 407, Episode_Reward: -366.56016391593874, 10_Episode_Reward_Avg -262
#  Episode: 408, Episode_Reward: -167.72045760620753, 10_Episode_Reward_Avg -259
#  Episode: 409, Episode_Reward: -161.56685250389376, 10_Episode_Reward_Avg -260
#  Episode: 410, Episode_Reward: -200.03196771425797, 10_Episode_Reward_Avg -262
#  Episode: 411, Episode_Reward: -129.04117938320556, 10_Episode_Reward_Avg -261
#  Episode: 412, Episode_Reward: -100.5879731839054, 10_Episode_Reward_Avg -258
#  Episode: 413, Episode_Reward: -82.07148296584523, 10_Episode_Reward_Avg -253
#  Episode: 414, Episode_Reward: -149.1189728072527, 10_Episode_Reward_Avg -249
#  Episode: 415, Episode_Reward: -241.98039803895068, 10_Episode_Reward_Avg -250
#  Episode: 416, Episode_Reward: -178.92617206879208, 10_Episode_Reward_Avg -248
#  Episode: 417, Episode_Reward: -171.5000946126821, 10_Episode_Reward_Avg -244
#  Episode: 418, Episode_Reward: -105.06221348485127, 10_Episode_Reward_Avg -242
#  Episode: 419, Episode_Reward: -94.98407991943728, 10_Episode_Reward_Avg -239
#  Episode: 420, Episode_Reward: -78.37129125008596, 10_Episode_Reward_Avg -237
#  Episode: 421, Episode_Reward: -124.49603241218898, 10_Episode_Reward_Avg -237
#  Episode: 422, Episode_Reward: -132.48785829518036, 10_Episode_Reward_Avg -236
#  Episode: 423, Episode_Reward: -471.2397123101759, 10_Episode_Reward_Avg -237
#  Episode: 424, Episode_Reward: -472.68898233752174, 10_Episode_Reward_Avg -239
#  Episode: 425, Episode_Reward: -57.42912086856482, 10_Episode_Reward_Avg -239
#  Episode: 426, Episode_Reward: -428.58648909408294, 10_Episode_Reward_Avg -239
#  Episode: 427, Episode_Reward: -117.06715276080752, 10_Episode_Reward_Avg -240
#  Episode: 428, Episode_Reward: -51.699803627267045, 10_Episode_Reward_Avg -234
#  Episode: 429, Episode_Reward: -318.21567714961293, 10_Episode_Reward_Avg -235
#  Episode: 466, Episode_Reward: -113.08252134785482, 10_Episode_Reward_Avg -233
#  Episode: 467, Episode_Reward: -227.35872438875802, 10_Episode_Reward_Avg -232
#  Episode: 468, Episode_Reward: -361.2279253398745, 10_Episode_Reward_Avg -230
#  Episode: 469, Episode_Reward: -68.49448183948319, 10_Episode_Reward_Avg -229
#  Episode: 470, Episode_Reward: -105.53033133794895, 10_Episode_Reward_Avg -226
#  Episode: 471, Episode_Reward: -446.4998182178703, 10_Episode_Reward_Avg -229
#  Episode: 472, Episode_Reward: 12.044107999280783, 10_Episode_Reward_Avg -224
#  Episode: 473, Episode_Reward: -527.9180409637011, 10_Episode_Reward_Avg -228
#  Episode: 474, Episode_Reward: -639.6784561974467, 10_Episode_Reward_Avg -232
#  Episode: 475, Episode_Reward: -82.30738146107231, 10_Episode_Reward_Avg -229
#  Episode: 476, Episode_Reward: -742.3684944713415, 10_Episode_Reward_Avg -233
#  Episode: 477, Episode_Reward: -50.34416289694647, 10_Episode_Reward_Avg -231
#  Episode: 478, Episode_Reward: -525.3503513357305, 10_Episode_Reward_Avg -235
#  Episode: 479, Episode_Reward: -211.23818133251194, 10_Episode_Reward_Avg -235
#  Episode: 480, Episode_Reward: 52.91594703836279, 10_Episode_Reward_Avg -232
#  Episode: 481, Episode_Reward: -251.02121018538116, 10_Episode_Reward_Avg -232
#  Episode: 482, Episode_Reward: -174.58850273546136, 10_Episode_Reward_Avg -232
#  Episode: 483, Episode_Reward: -510.0225496995713, 10_Episode_Reward_Avg -235
#  Episode: 484, Episode_Reward: -96.31362847810198, 10_Episode_Reward_Avg -234
#  Episode: 485, Episode_Reward: -125.09244481010492, 10_Episode_Reward_Avg -234
#  Episode: 486, Episode_Reward: -562.6156247318117, 10_Episode_Reward_Avg -234
#  Episode: 487, Episode_Reward: -90.94339840723292, 10_Episode_Reward_Avg -233
#  Episode: 488, Episode_Reward: -165.75665486197985, 10_Episode_Reward_Avg -234
#  Episode: 489, Episode_Reward: -480.0013230328754, 10_Episode_Reward_Avg -237
#  Episode: 490, Episode_Reward: -102.81900647359342, 10_Episode_Reward_Avg -237
#  Episode: 491, Episode_Reward: -331.40847229764626, 10_Episode_Reward_Avg -237
#  Episode: 492, Episode_Reward: -599.6696662873228, 10_Episode_Reward_Avg -242
#  Episode: 493, Episode_Reward: -283.24414002612514, 10_Episode_Reward_Avg -242
#  Episode: 494, Episode_Reward: -87.20256291149893, 10_Episode_Reward_Avg -239
#  Episode: 495, Episode_Reward: -72.62693713495091, 10_Episode_Reward_Avg -238
#  Episode: 496, Episode_Reward: -162.9369948854719, 10_Episode_Reward_Avg -238
#  Episode: 497, Episode_Reward: -237.2552108467748, 10_Episode_Reward_Avg -235
#  Episode: 498, Episode_Reward: -195.63359634154443, 10_Episode_Reward_Avg -238
#  Episode: 499, Episode_Reward: -246.5169947473217, 10_Episode_Reward_Avg -238
#  Episode: 500, Episode_Reward: -86.09245535538918, 10_Episode_Reward_Avg -235
#  Episode: 501, Episode_Reward: -489.3213424160409, 10_Episode_Reward_Avg -238
#  Episode: 502, Episode_Reward: -185.82713358192711, 10_Episode_Reward_Avg -238
#  Episode: 503, Episode_Reward: 42.063358815685774, 10_Episode_Reward_Avg -236
#  Episode: 504, Episode_Reward: -164.06972557342084, 10_Episode_Reward_Avg -236
#  Episode: 505, Episode_Reward: -111.05374955981345, 10_Episode_Reward_Avg -233
#  Episode: 506, Episode_Reward: -163.5380595397153, 10_Episode_Reward_Avg -230
#  Episode: 507, Episode_Reward: -414.5838161992689, 10_Episode_Reward_Avg -231
#  Episode: 508, Episode_Reward: -263.6556352645223, 10_Episode_Reward_Avg -232
#  Episode: 509, Episode_Reward: -103.45819839224106, 10_Episode_Reward_Avg -231
#  Episode: 510, Episode_Reward: -298.68919819793086, 10_Episode_Reward_Avg -232
#  Episode: 511, Episode_Reward: -493.9571056222515, 10_Episode_Reward_Avg -236
#  Episode: 512, Episode_Reward: -167.07362755982308, 10_Episode_Reward_Avg -236
#  Episode: 513, Episode_Reward: -261.4722562654018, 10_Episode_Reward_Avg -238
#  Episode: 514, Episode_Reward: -362.41827923833915, 10_Episode_Reward_Avg -240
#  Episode: 515, Episode_Reward: -61.50830265375701, 10_Episode_Reward_Avg -238
#  Episode: 516, Episode_Reward: -467.4231743586627, 10_Episode_Reward_Avg -241
#  Episode: 517, Episode_Reward: -112.54731648593648, 10_Episode_Reward_Avg -241
#  Episode: 518, Episode_Reward: -186.83723597228163, 10_Episode_Reward_Avg -241
#  Episode: 519, Episode_Reward: -577.5932642178508, 10_Episode_Reward_Avg -246
#  Episode: 520, Episode_Reward: -227.1272843467878, 10_Episode_Reward_Avg -248
#  Episode: 521, Episode_Reward: -122.94933484878007, 10_Episode_Reward_Avg -248
#  Episode: 522, Episode_Reward: -130.65864288493776, 10_Episode_Reward_Avg -248
#  Episode: 523, Episode_Reward: -239.06082824837029, 10_Episode_Reward_Avg -245
#  Episode: 524, Episode_Reward: -197.25667519651344, 10_Episode_Reward_Avg -243
#  Episode: 525, Episode_Reward: -115.75392963361284, 10_Episode_Reward_Avg -243
#  Episode: 526, Episode_Reward: -138.1157194017015, 10_Episode_Reward_Avg -240
#  Episode: 527, Episode_Reward: -473.7020800336699, 10_Episode_Reward_Avg -244
#  Episode: 528, Episode_Reward: -549.0252183377145, 10_Episode_Reward_Avg -249
#  Episode: 529, Episode_Reward: -322.65044061485304, 10_Episode_Reward_Avg -249
#  Episode: 530, Episode_Reward: -118.25169096044684, 10_Episode_Reward_Avg -248
#  Episode: 531, Episode_Reward: -482.23848944118254, 10_Episode_Reward_Avg -250
#  Episode: 532, Episode_Reward: -438.38207545500444, 10_Episode_Reward_Avg -253
#  Episode: 533, Episode_Reward: -178.57134218843473, 10_Episode_Reward_Avg -252
#  Episode: 534, Episode_Reward: -632.7148275031026, 10_Episode_Reward_Avg -255
#  Episode: 535, Episode_Reward: -126.46207415398442, 10_Episode_Reward_Avg -254
#  Episode: 536, Episode_Reward: -483.206417393895, 10_Episode_Reward_Avg -259
#  Episode: 537, Episode_Reward: -129.8784240126956, 10_Episode_Reward_Avg -259
#  Episode: 538, Episode_Reward: -78.12470858948623, 10_Episode_Reward_Avg -257
#  Episode: 539, Episode_Reward: -172.74448900264338, 10_Episode_Reward_Avg -256
#  Episode: 540, Episode_Reward: -199.06746095371645, 10_Episode_Reward_Avg -255
#  Episode: 541, Episode_Reward: -110.43525690223554, 10_Episode_Reward_Avg -251
#  Episode: 542, Episode_Reward: -199.7313396940686, 10_Episode_Reward_Avg -252
#  Episode: 543, Episode_Reward: -212.15368848763057, 10_Episode_Reward_Avg -251
#  Episode: 544, Episode_Reward: -545.2257956544203, 10_Episode_Reward_Avg -256
#  Episode: 545, Episode_Reward: -190.76455590665046, 10_Episode_Reward_Avg -257
#  Episode: 546, Episode_Reward: -218.09906242253624, 10_Episode_Reward_Avg -254
#  Episode: 547, Episode_Reward: -737.9393218890029, 10_Episode_Reward_Avg -257
#  Episode: 548, Episode_Reward: -328.0617279471032, 10_Episode_Reward_Avg -258
#  Episode: 549, Episode_Reward: -142.11693694859338, 10_Episode_Reward_Avg -255
#  Episode: 550, Episode_Reward: -278.8845411892562, 10_Episode_Reward_Avg -253
#  Episode: 551, Episode_Reward: -305.4294087692102, 10_Episode_Reward_Avg -256
#  Episode: 552, Episode_Reward: -29.524024579026133, 10_Episode_Reward_Avg -255
#  Episode: 553, Episode_Reward: -210.87471112141432, 10_Episode_Reward_Avg -256
#  Episode: 554, Episode_Reward: -87.7261745854852, 10_Episode_Reward_Avg -256
#  Episode: 555, Episode_Reward: -73.30696508562167, 10_Episode_Reward_Avg -255
#  Episode: 556, Episode_Reward: -97.91245545318834, 10_Episode_Reward_Avg -253
#  Episode: 557, Episode_Reward: -146.89535068112002, 10_Episode_Reward_Avg -253
#  Episode: 558, Episode_Reward: -412.3070015352195, 10_Episode_Reward_Avg -253
#  Episode: 559, Episode_Reward: -106.35701456015575, 10_Episode_Reward_Avg -253
#  Episode: 560, Episode_Reward: -195.31768524140915, 10_Episode_Reward_Avg -253
#  Episode: 561, Episode_Reward: -156.27598676262747, 10_Episode_Reward_Avg -251
#  Episode: 562, Episode_Reward: -146.16814666630307, 10_Episode_Reward_Avg -252
#  Episode: 563, Episode_Reward: -279.55927733635986, 10_Episode_Reward_Avg -250
#  Episode: 564, Episode_Reward: -260.26571555949874, 10_Episode_Reward_Avg -249
#  Episode: 565, Episode_Reward: -197.6569440163446, 10_Episode_Reward_Avg -250
#  Episode: 566, Episode_Reward: -324.50053439107296, 10_Episode_Reward_Avg -252
#  Episode: 567, Episode_Reward: -136.82845778879673, 10_Episode_Reward_Avg -251
#  Episode: 568, Episode_Reward: -538.5610685200083, 10_Episode_Reward_Avg -253
#  Episode: 569, Episode_Reward: -108.90481018484516, 10_Episode_Reward_Avg -253
#  Episode: 570, Episode_Reward: -209.64260011757852, 10_Episode_Reward_Avg -254
#  Episode: 571, Episode_Reward: -88.54025389704341, 10_Episode_Reward_Avg -251
#  Episode: 572, Episode_Reward: -290.1275242518474, 10_Episode_Reward_Avg -254
#  Episode: 573, Episode_Reward: -344.49924118019476, 10_Episode_Reward_Avg -252
#  Episode: 574, Episode_Reward: -138.72065406440697, 10_Episode_Reward_Avg -247
#  Episode: 575, Episode_Reward: -461.6358309703018, 10_Episode_Reward_Avg -250
#  Episode: 576, Episode_Reward: -431.47876081241714, 10_Episode_Reward_Avg -247
#  Episode: 577, Episode_Reward: -156.79879287848908, 10_Episode_Reward_Avg -248
#  Episode: 578, Episode_Reward: -449.6444215354729, 10_Episode_Reward_Avg -248
#  Episode: 579, Episode_Reward: -122.97870034859486, 10_Episode_Reward_Avg -247
#  Episode: 580, Episode_Reward: -277.0947472124388, 10_Episode_Reward_Avg -250
#  Episode: 581, Episode_Reward: -153.6493821715831, 10_Episode_Reward_Avg -249
#  Episode: 582, Episode_Reward: -126.0678307896205, 10_Episode_Reward_Avg -249
#  Episode: 583, Episode_Reward: -224.96335066760366, 10_Episode_Reward_Avg -246
#  Episode: 584, Episode_Reward: -332.62011809060846, 10_Episode_Reward_Avg -248
#  Episode: 585, Episode_Reward: -449.12532045013234, 10_Episode_Reward_Avg -251
#  Episode: 586, Episode_Reward: -164.44369254532882, 10_Episode_Reward_Avg -247
#  Episode: 587, Episode_Reward: -504.08179589208663, 10_Episode_Reward_Avg -252
#  Episode: 588, Episode_Reward: -324.2203508272423, 10_Episode_Reward_Avg -253
#  Episode: 589, Episode_Reward: -389.74252725720936, 10_Episode_Reward_Avg -252
#  Episode: 590, Episode_Reward: -360.3657362729557, 10_Episode_Reward_Avg -255
#  Episode: 591, Episode_Reward: -244.47295384219706, 10_Episode_Reward_Avg -254
#  Episode: 592, Episode_Reward: -151.46998284703272, 10_Episode_Reward_Avg -249
#  Episode: 593, Episode_Reward: -217.96777165768088, 10_Episode_Reward_Avg -249
#  Episode: 594, Episode_Reward: -123.00101130109098, 10_Episode_Reward_Avg -249
#  Episode: 595, Episode_Reward: -206.03996863521644, 10_Episode_Reward_Avg -250
#  Episode: 596, Episode_Reward: -174.89962645860786, 10_Episode_Reward_Avg -251
#  Episode: 597, Episode_Reward: -76.19009073894341, 10_Episode_Reward_Avg -249
#  Episode: 598, Episode_Reward: -157.25865104251125, 10_Episode_Reward_Avg -249
#  Episode: 599, Episode_Reward: -810.767762077707, 10_Episode_Reward_Avg -254
#  Episode: 600, Episode_Reward: -182.82836292477594, 10_Episode_Reward_Avg -255
#  Episode: 601, Episode_Reward: -123.58877194084742, 10_Episode_Reward_Avg -252
#  Episode: 602, Episode_Reward: -267.1469421884325, 10_Episode_Reward_Avg -252
#  Episode: 603, Episode_Reward: -210.02548523588166, 10_Episode_Reward_Avg -255
#  Episode: 604, Episode_Reward: -465.38964997960363, 10_Episode_Reward_Avg -258
#  Episode: 605, Episode_Reward: -390.2841014335375, 10_Episode_Reward_Avg -261
#  Episode: 606, Episode_Reward: -207.7956075788179, 10_Episode_Reward_Avg -261
#  Episode: 607, Episode_Reward: -192.91739921936906, 10_Episode_Reward_Avg -259
#  Episode: 608, Episode_Reward: -245.54031867174902, 10_Episode_Reward_Avg -259
#  Episode: 609, Episode_Reward: -230.43562963811252, 10_Episode_Reward_Avg -260
#  Episode: 610, Episode_Reward: -194.75287449847178, 10_Episode_Reward_Avg -259
#  Episode: 611, Episode_Reward: -243.56535996484448, 10_Episode_Reward_Avg -256
#  Episode: 612, Episode_Reward: -204.9203570697075, 10_Episode_Reward_Avg -257
#  Episode: 613, Episode_Reward: -121.94876313194263, 10_Episode_Reward_Avg -255
#  Episode: 614, Episode_Reward: -309.8250709200703, 10_Episode_Reward_Avg -255
#  Episode: 615, Episode_Reward: -505.80978438079893, 10_Episode_Reward_Avg -259
#  Episode: 616, Episode_Reward: -81.17705556484033, 10_Episode_Reward_Avg -256
#  Episode: 617, Episode_Reward: -8.267504806797831, 10_Episode_Reward_Avg -254
#  Episode: 618, Episode_Reward: -108.64050430542329, 10_Episode_Reward_Avg -254
#  Episode: 619, Episode_Reward: -108.53768801252002, 10_Episode_Reward_Avg -249
#  Episode: 620, Episode_Reward: -126.96970841778086, 10_Episode_Reward_Avg -248
#  Episode: 621, Episode_Reward: -206.31419566063855, 10_Episode_Reward_Avg -249
#  Episode: 622, Episode_Reward: 0.9224015994122823, 10_Episode_Reward_Avg -248
#  Episode: 623, Episode_Reward: -136.71181679826236, 10_Episode_Reward_Avg -246
#  Episode: 624, Episode_Reward: 20.795673932077733, 10_Episode_Reward_Avg -244
#  Episode: 625, Episode_Reward: -97.8779470893637, 10_Episode_Reward_Avg -244
#  Episode: 626, Episode_Reward: -404.061829414831, 10_Episode_Reward_Avg -247
#  Episode: 627, Episode_Reward: -320.2719524954486, 10_Episode_Reward_Avg -245
#  Episode: 628, Episode_Reward: -66.84822566592909, 10_Episode_Reward_Avg -240
#  Episode: 629, Episode_Reward: -196.49161944890562, 10_Episode_Reward_Avg -239
#  Episode: 630, Episode_Reward: -108.7516779785951, 10_Episode_Reward_Avg -239
#  Episode: 631, Episode_Reward: -86.68881253986953, 10_Episode_Reward_Avg -235
#  Episode: 632, Episode_Reward: -342.88622738818253, 10_Episode_Reward_Avg -234
#  Episode: 633, Episode_Reward: -629.8241433975174, 10_Episode_Reward_Avg -239
#  Episode: 634, Episode_Reward: 13.61594231254307, 10_Episode_Reward_Avg -232
#  Episode: 635, Episode_Reward: -134.5811865034536, 10_Episode_Reward_Avg -232
#  Episode: 636, Episode_Reward: -33.70008473471559, 10_Episode_Reward_Avg -228
#  Episode: 637, Episode_Reward: -179.9259101892489, 10_Episode_Reward_Avg -228
#  Episode: 638, Episode_Reward: 30.527857196050633, 10_Episode_Reward_Avg -227
#  Episode: 639, Episode_Reward: -398.9642070496293, 10_Episode_Reward_Avg -229
#  Episode: 640, Episode_Reward: -168.6519938759306, 10_Episode_Reward_Avg -229
#  Episode: 641, Episode_Reward: -150.57591420043832, 10_Episode_Reward_Avg -230
#  Episode: 642, Episode_Reward: -240.51560415344278, 10_Episode_Reward_Avg -230
#  Episode: 643, Episode_Reward: -93.69243957782957, 10_Episode_Reward_Avg -229
#  Episode: 644, Episode_Reward: -467.51618656808324, 10_Episode_Reward_Avg -228
#  Episode: 645, Episode_Reward: -557.09615963068, 10_Episode_Reward_Avg -232
#  Episode: 646, Episode_Reward: -150.97117283829303, 10_Episode_Reward_Avg -231
#  Episode: 647, Episode_Reward: -152.75593675783733, 10_Episode_Reward_Avg -225
#  Episode: 648, Episode_Reward: -95.54123361166148, 10_Episode_Reward_Avg -223
#  Episode: 649, Episode_Reward: -77.09439083146115, 10_Episode_Reward_Avg -222
#  Episode: 650, Episode_Reward: -527.6235895431363, 10_Episode_Reward_Avg -225
#  Episode: 651, Episode_Reward: -275.23222440622243, 10_Episode_Reward_Avg -224
#  Episode: 652, Episode_Reward: -428.78806211240783, 10_Episode_Reward_Avg -228
#  Episode: 653, Episode_Reward: -309.8571251454532, 10_Episode_Reward_Avg -229
#  Episode: 654, Episode_Reward: -197.28435005369147, 10_Episode_Reward_Avg -230
#  Episode: 655, Episode_Reward: -269.34819042620376, 10_Episode_Reward_Avg -232
#  Episode: 656, Episode_Reward: -390.5502237121158, 10_Episode_Reward_Avg -235
#  Episode: 657, Episode_Reward: -228.67196257230938, 10_Episode_Reward_Avg -236
#  Episode: 658, Episode_Reward: -199.59770063030666, 10_Episode_Reward_Avg -234
#  Episode: 659, Episode_Reward: -181.26664325545755, 10_Episode_Reward_Avg -235
#  Episode: 660, Episode_Reward: -238.60962365337252, 10_Episode_Reward_Avg -235
#  Episode: 661, Episode_Reward: -234.20814371890648, 10_Episode_Reward_Avg -236
#  Episode: 662, Episode_Reward: -357.06327985339067, 10_Episode_Reward_Avg -238
#  Episode: 663, Episode_Reward: -613.8511016675051, 10_Episode_Reward_Avg -241
#  Episode: 664, Episode_Reward: -174.4733794553847, 10_Episode_Reward_Avg -241
#  Episode: 665, Episode_Reward: -280.3018350685248, 10_Episode_Reward_Avg -241
#  Episode: 666, Episode_Reward: -264.44979600238946, 10_Episode_Reward_Avg -241
#  Episode: 667, Episode_Reward: -160.20660211990054, 10_Episode_Reward_Avg -241
#  Episode: 668, Episode_Reward: -635.4576856988598, 10_Episode_Reward_Avg -242
#  Episode: 669, Episode_Reward: -526.5063096450245, 10_Episode_Reward_Avg -246
#  Episode: 670, Episode_Reward: -103.88909540086141, 10_Episode_Reward_Avg -245
#  Episode: 671, Episode_Reward: -344.13368437585734, 10_Episode_Reward_Avg -248
#  Episode: 672, Episode_Reward: -229.5246246277985, 10_Episode_Reward_Avg -247
#  Episode: 673, Episode_Reward: -238.40789284620476, 10_Episode_Reward_Avg -246
#  Episode: 674, Episode_Reward: -248.39532329724813, 10_Episode_Reward_Avg -247
#  Episode: 675, Episode_Reward: -404.89943908782726, 10_Episode_Reward_Avg -247
#  Episode: 676, Episode_Reward: -288.46493987798544, 10_Episode_Reward_Avg -245
#  Episode: 677, Episode_Reward: -295.0117130399121, 10_Episode_Reward_Avg -246
#  Episode: 678, Episode_Reward: -253.5333314206856, 10_Episode_Reward_Avg -245
#  Episode: 679, Episode_Reward: -137.17558854108717, 10_Episode_Reward_Avg -245
#  Episode: 680, Episode_Reward: -231.92893272246621, 10_Episode_Reward_Avg -244
#  Episode: 681, Episode_Reward: -198.74730802170217, 10_Episode_Reward_Avg -245
#  Episode: 682, Episode_Reward: -292.52893929182005, 10_Episode_Reward_Avg -246
#  Episode: 683, Episode_Reward: -222.92767370604565, 10_Episode_Reward_Avg -246
#  Episode: 684, Episode_Reward: -311.0819382010171, 10_Episode_Reward_Avg -246
#  Episode: 685, Episode_Reward: -279.4237087955113, 10_Episode_Reward_Avg -244
#  Episode: 686, Episode_Reward: -207.98813543929987, 10_Episode_Reward_Avg -245
#  Episode: 687, Episode_Reward: -164.24499130662178, 10_Episode_Reward_Avg -241
#  Episode: 688, Episode_Reward: -212.57629146839122, 10_Episode_Reward_Avg -240
#  Episode: 689, Episode_Reward: -215.707970442298, 10_Episode_Reward_Avg -239
#  Episode: 690, Episode_Reward: -269.66614849768916, 10_Episode_Reward_Avg -238
#  Episode: 691, Episode_Reward: -213.6467080326232, 10_Episode_Reward_Avg -237
#  Episode: 692, Episode_Reward: -188.16922525461223, 10_Episode_Reward_Avg -238
#  Episode: 693, Episode_Reward: -216.11640970343518, 10_Episode_Reward_Avg -238
#  Episode: 694, Episode_Reward: -287.56104840003974, 10_Episode_Reward_Avg -239
#  Episode: 695, Episode_Reward: -268.6122353623349, 10_Episode_Reward_Avg -240
#  Episode: 696, Episode_Reward: -329.1174122407925, 10_Episode_Reward_Avg -242
#  Episode: 697, Episode_Reward: -186.01313299171375, 10_Episode_Reward_Avg -243
#  Episode: 698, Episode_Reward: -112.49970624703288, 10_Episode_Reward_Avg -242
#  Episode: 699, Episode_Reward: -220.1327855088652, 10_Episode_Reward_Avg -236
#  Episode: 700, Episode_Reward: -218.7568696413199, 10_Episode_Reward_Avg -237
#  Episode: 701, Episode_Reward: -265.2928489872596, 10_Episode_Reward_Avg -238
#  Episode: 702, Episode_Reward: -215.92149353667816, 10_Episode_Reward_Avg -238
#  Episode: 703, Episode_Reward: -85.87719610343636, 10_Episode_Reward_Avg -236
#  Episode: 704, Episode_Reward: -199.38176384161693, 10_Episode_Reward_Avg -234
#  Episode: 705, Episode_Reward: -488.9830318070851, 10_Episode_Reward_Avg -235
#  Episode: 706, Episode_Reward: -209.3292468528848, 10_Episode_Reward_Avg -235
#  Episode: 707, Episode_Reward: -154.1879190805102, 10_Episode_Reward_Avg -234
#  Episode: 708, Episode_Reward: -140.7701671369217, 10_Episode_Reward_Avg -233
#  Episode: 709, Episode_Reward: -413.91457922843017, 10_Episode_Reward_Avg -235
#  Episode: 710, Episode_Reward: -92.13455027874099, 10_Episode_Reward_Avg -234
#  Episode: 711, Episode_Reward: 39.20509067672808, 10_Episode_Reward_Avg -231
#  Episode: 712, Episode_Reward: -458.4546000294082, 10_Episode_Reward_Avg -234
#  Episode: 713, Episode_Reward: -128.32201764491305, 10_Episode_Reward_Avg -234
#  Episode: 714, Episode_Reward: -108.29394033755054, 10_Episode_Reward_Avg -232
#  Episode: 715, Episode_Reward: -276.43369626819253, 10_Episode_Reward_Avg -229
#  Episode: 716, Episode_Reward: -187.02212080613174, 10_Episode_Reward_Avg -231
#  Episode: 717, Episode_Reward: -113.15220360716415, 10_Episode_Reward_Avg -232
#  Episode: 718, Episode_Reward: -155.37897397667257, 10_Episode_Reward_Avg -232
#  Episode: 719, Episode_Reward: -245.2272653851006, 10_Episode_Reward_Avg -233
#  Episode: 720, Episode_Reward: -231.81628171803058, 10_Episode_Reward_Avg -234
#  Episode: 721, Episode_Reward: -418.0356997051019, 10_Episode_Reward_Avg -237
#  Episode: 722, Episode_Reward: -384.86422386186524, 10_Episode_Reward_Avg -240
#  Episode: 723, Episode_Reward: -152.46267600868612, 10_Episode_Reward_Avg -241
#  Episode: 724, Episode_Reward: -240.98722445926808, 10_Episode_Reward_Avg -243
#  Episode: 725, Episode_Reward: -87.18368946821262, 10_Episode_Reward_Avg -243
#  Episode: 726, Episode_Reward: -240.20867419718556, 10_Episode_Reward_Avg -241
#  Episode: 727, Episode_Reward: -180.7588363867179, 10_Episode_Reward_Avg -240
#  Episode: 728, Episode_Reward: -346.0845177295063, 10_Episode_Reward_Avg -243
#  Episode: 729, Episode_Reward: -564.3082555158703, 10_Episode_Reward_Avg -247
#  Episode: 730, Episode_Reward: -302.5913748730168, 10_Episode_Reward_Avg -248
#  Episode: 731, Episode_Reward: -288.17606547952937, 10_Episode_Reward_Avg -251
#  Episode: 732, Episode_Reward: -115.03541248109862, 10_Episode_Reward_Avg -248
#  Episode: 733, Episode_Reward: -213.59315464587922, 10_Episode_Reward_Avg -244
#  Episode: 734, Episode_Reward: -377.25197422385156, 10_Episode_Reward_Avg -248
#  Episode: 735, Episode_Reward: -149.1288199294563, 10_Episode_Reward_Avg -248
#  Episode: 736, Episode_Reward: -94.40737328901876, 10_Episode_Reward_Avg -249
#  Episode: 737, Episode_Reward: -172.99179311022283, 10_Episode_Reward_Avg -249
#  Episode: 738, Episode_Reward: -266.9301997515396, 10_Episode_Reward_Avg -252
#  Episode: 739, Episode_Reward: -451.37231657311435, 10_Episode_Reward_Avg -252
#  Episode: 740, Episode_Reward: -223.79875785852855, 10_Episode_Reward_Avg -253
#  Episode: 741, Episode_Reward: -482.28335084798135, 10_Episode_Reward_Avg -256
#  Episode: 742, Episode_Reward: -177.65896634456294, 10_Episode_Reward_Avg -255
#  Episode: 743, Episode_Reward: -395.45839825128485, 10_Episode_Reward_Avg -258
#  Episode: 744, Episode_Reward: -269.99555032804506, 10_Episode_Reward_Avg -256
#  Episode: 745, Episode_Reward: -369.5688533773359, 10_Episode_Reward_Avg -255
#  Episode: 746, Episode_Reward: -365.92888313045194, 10_Episode_Reward_Avg -257
#  Episode: 747, Episode_Reward: -297.7425066328297, 10_Episode_Reward_Avg -258
#  Episode: 748, Episode_Reward: -367.78381733100366, 10_Episode_Reward_Avg -261
#  Episode: 749, Episode_Reward: -334.8203498822703, 10_Episode_Reward_Avg -263
