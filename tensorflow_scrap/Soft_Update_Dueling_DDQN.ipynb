# %%
import tensorflow as tf
import sys
import time
import os
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
import gym
import random
import tensorboard
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
#tf.compat.v1.disable_eager_execution()

# %%
def clean_tensorboard():
    import os
    tensor_board_sess_path = 'C:/Users/Eaj59/AppData/Local/Temp/.tensorboard-info/'
    temp_sess_files = os.listdir(tensor_board_sess_path)
    for i in temp_sess_files:
        temp_file_path = os.path.join(tensor_board_sess_path,i)
        os.remove(temp_file_path)

# %%
#clean_tensorboard()
#%load_ext tensorboard
#%tensorboard --logdir 'C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/log_dir'

# %%
class Agent():
    
    def __init__(self,env_name,enable_tb_logging=False,enable_dueling=True):
        self.env = gym.make(env_name)
        self.env_state = self.env.reset()
        self.lr = 0.001
        self.gamma = .95
        self.epsilon_decay_rate = .99
        self.initializer = tf.keras.initializers.HeUniform(seed=None)
        self.loss_fn = tf.keras.losses.Huber(delta=1.0)
        self.optimizer = tf.keras.optimizers.Adam(lr=self.lr)
        self.n_actions = self.env.action_space.n
        self.n_states = self.env.observation_space.shape[0]
        self.buffer = ReplayBuffer(max_len=10000)
        self.tau = 0.10
        self.batch_size = 32
        self.epsilon = 1
        self.min_epsilon = .001
        self.dueling_method = 'average'
        self.enable_tb_logging = enable_tb_logging
        self.enable_dueling = enable_dueling
        self.episodic_rewards = 0
        self.episode_counter = 0
        self.episode_time_step_counter = 0
        

        if self.enable_dueling:
            self.online = self.make_dueling_nn()
        else:
            self.online = self.make_nn()
            
        self.target = self.make_target()
        
        if self.enable_tb_logging:
            self.online_run_id, self.online_tensor_board_callback = self.create_tensor_board_callback(model_name='Soft_10_Target_AVG_Dueling_DDQN_Huber')
            self.training_steps_counter = 0
        
    def reset_env(self):
        self.episode_counter+=1
        if self.enable_tb_logging:
            with self.online_tensor_board_callback.as_default():
                tf.summary.scalar(name='Episode_Reward',data=self.episodic_rewards,step=self.episode_counter)
                tf.summary.scalar(name='Episode_Time_Steps',data=self.episode_time_step_counter,step=self.episode_counter)
        self.episodic_rewards = 0
        self.episode_time_step_counter = 0
        self.env_state = self.env.reset()
        
        
    def generate_run_directory(self,root_log_dir,model_name):
        run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
        run_id = model_name+'_'+run_id
        base_dir = 'C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL'
        os.chdir('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/log_dir')
        os.mkdir(run_id)
        os.chdir(base_dir)
        return run_id
        
    
    def create_tensor_board_callback(self,model_name):
        root_log_dir = os.path.join(os.curdir,'log_dir')
        run_id = self.generate_run_directory(root_log_dir=root_log_dir,model_name=model_name)
        model_cb_path = os.path.join(root_log_dir,run_id)
        file_writer = tf.summary.create_file_writer(model_cb_path)
        return run_id, file_writer
    
        
        
    def make_nn(self):
        online = tf.keras.models.Sequential()
        online.add(tf.keras.layers.Dense(24,input_dim=self.n_states,activation='swish',kernel_initializer=self.initializer))
        online.add(tf.keras.layers.Dense(24, activation='swish',kernel_initializer=self.initializer))
        online.add(tf.keras.layers.Dense(self.n_actions,activation='linear',kernel_initializer=self.initializer))
        online.compile(loss=self.loss_fn,optimizer=self.optimizer,metrics=['accuracy'])
        return online
    
    def make_dueling_nn(self):
        Dueling_Input = tf.keras.layers.Input(shape=(self.n_states,),name='Dueling_Input')
        layer_1_Dense = tf.keras.layers.Dense(64,activation='swish',kernel_initializer=self.initializer,name='layer_1_Dense')(Dueling_Input)
        layer_2_Dense = tf.keras.layers.Dense(64,activation='swish',kernel_initializer=self.initializer,name='layer_2_Dense')(layer_1_Dense)
        layer_3_Dense = tf.keras.layers.Dense(36,activation='swish',kernel_initializer=self.initializer,name='layer_3_Dense')(layer_2_Dense)
        Value_Function_Dense_Layer = tf.keras.layers.Dense(512,activation='swish',kernel_initializer=self.initializer,name='Value_Function_Dense_Layer')(layer_3_Dense)
        Value_Function_Output_Layer = tf.keras.layers.Dense(1,activation='linear',kernel_initializer=self.initializer,name='Value_Function_Output_Layer')(Value_Function_Dense_Layer)
        Advantage_Function_Dense_Layer = tf.keras.layers.Dense(512,activation='swish',kernel_initializer=self.initializer,name='Advantage_Function_Dense_Layer')(layer_3_Dense)
        Advantage_Function_Ouput_Layer = tf.keras.layers.Dense(self.n_actions,activation='linear',kernel_initializer=self.initializer,name='Advantage_Function_Output_Layer')(Advantage_Function_Dense_Layer)
        
        if self.dueling_method == 'average':
            online_output = Value_Function_Output_Layer + (Advantage_Function_Ouput_Layer - tf.reduce_mean(Advantage_Function_Ouput_Layer,axis=1,keepdims=True))
            
            
        elif self.dueling_method == 'sum':
            online_output = Value_Function_Output_Layer + Advantage_Function_Ouput_Layer
           
            
        else:
            online_output = Value_Function_Output_Layer + (Advantage_Function_Ouput_Layer - tf.reduce_max(Advantage_Function_Ouput_Layer,axis=1,keepdims=True))
            
            
        online = tf.keras.Model(Dueling_Input,online_output)
        online.compile(loss=self.loss_fn,optimizer=self.optimizer,metrics=['accuracy'])
        online.summary()
        return online
            

    def make_target(self):
        target = tf.keras.models.clone_model(self.online)
        target.set_weights(self.online.get_weights())
        return target
        
        
    def epsilon_greedy_policy(self):
        if np.random.random() <= self.epsilon:
            return np.random.randint(low=0,high=self.n_actions)
        else:
            Q_values = self.online.predict(np.reshape(self.env_state,(1,len(self.env_state))))
            return np.argmax(Q_values[0])
        
        
        
    def play_one_step(self):
        state = np.array(self.env_state)
        action = self.epsilon_greedy_policy()
        next_state, reward, done, _ = self.env.step(action)
        self.buffer.add_exp(state=state, action=action, reward=reward, next_state=next_state, done=done)
        self.env_state = next_state
        self.episodic_rewards += reward
        self.episode_time_step_counter +=1
        return state, action, reward, next_state, done
        
        
    def soft_target_update(self):
        target_weights_current = self.target.get_weights()
        online_weights_current = self.online.get_weights()
        layer_counter = 0
        for tw, ow in zip(target_weights_current,online_weights_current):
            new_target_weights = (1-self.tau)*tw + (self.tau)*ow
            target_weights_current[layer_counter] = new_target_weights
            layer_counter += 1
        self.target.set_weights(target_weights_current)
        
        
    def training_step(self):
        
        if len(self.buffer)<self.batch_size:
            batch_size_instance = len(self.buffer)
        else:
            batch_size_instance = self.batch_size
            
        states,actions,rewards,next_states,dones = self.buffer.exp_sample(batch_size=batch_size_instance)
        online_state_prediction = self.online.predict(states)
        online_next_state_arg_max = tf.math.argmax(self.online.predict(next_states),axis=1)
        online_arg_max_mask = tf.one_hot(online_next_state_arg_max,depth=self.n_actions)
        target_next_state_preds = self.target.predict(next_states)
        max_target_next_state_preds = tf.reduce_sum(target_next_state_preds*online_arg_max_mask,axis=1,keepdims=True)
        q_update = rewards + (1 - dones) * self.gamma * max_target_next_state_preds
        actual_actions_mask = tf.one_hot(actions,depth=self.n_actions)
        inverse_actions_mask = tf.reverse(actual_actions_mask,axis=[-1])
        online_state_prediction = (q_update*actual_actions_mask)+(online_state_prediction*inverse_actions_mask)

        if self.enable_tb_logging:
            metrics_output = self.online.train_on_batch(states,online_state_prediction,reset_metrics=True)
            self.training_steps_counter+=1
            with self.online_tensor_board_callback.as_default():
                tf.summary.scalar(name='Batch_MSE_Loss',data=metrics_output[0],step=self.training_steps_counter)
                tf.summary.scalar(name='Accuracy',data=metrics_output[1],step=self.training_steps_counter)
                tf.summary.scalar(name='Epsilon',data=self.epsilon,step=self.training_steps_counter)
        else:
            self.online.train_on_batch(states,online_state_prediction)
        
        
        
            

    def apply_epsilon_decay(self):
        self.epsilon = max(self.epsilon * self.epsilon_decay_rate,self.min_epsilon)
        
            
    def hard_target_update(self):
        self.target.set_weights(self.online.get_weights())

# %%
class ReplayBuffer():
    
    def __init__(self,max_len):
        self.max_len = max_len
        self.buffer = deque(maxlen=self.max_len)
        
    
    def add_exp(self,state,action,reward,next_state,done):
        exp = (state,action,reward, next_state, done)
        if len(self.buffer)<= self.max_len:
            self.buffer.append(exp)
        else:
            self.buffer[0] = exp
        
    def __len__(self):
        return len(self.buffer)
    
    def exp_sample(self,batch_size):
        indices = np.random.randint(len(self.buffer), size=batch_size)
        batch = [self.buffer[index] for index in indices]
        states, actions, rewards, next_states, dones = [np.array([experience[entry] for experience in batch])for entry in range(5)]
        return states, actions, rewards[:,np.newaxis], next_states, dones[:,np.newaxis]

# %%
my_agent = Agent('LunarLander-v2',enable_tb_logging=True,enable_dueling=True)
rewards_buffer = []
max_episodes = 750
mean_score_buffer = deque(maxlen=100)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Dueling_Input (InputLayer)      [(None, 8)]          0
# __________________________________________________________________________________________________
# layer_1_Dense (Dense)           (None, 64)           576         Dueling_Input[0][0]
# __________________________________________________________________________________________________
# layer_2_Dense (Dense)           (None, 64)           4160        layer_1_Dense[0][0]
# __________________________________________________________________________________________________
# layer_3_Dense (Dense)           (None, 36)           2340        layer_2_Dense[0][0]
# __________________________________________________________________________________________________
# Advantage_Function_Dense_Layer  (None, 512)          18944       layer_3_Dense[0][0]
# __________________________________________________________________________________________________
# Advantage_Function_Output_Layer (None, 4)            2052        Advantage_Function_Dense_Layer[0]
# __________________________________________________________________________________________________
# Value_Function_Dense_Layer (Den (None, 512)          18944       layer_3_Dense[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 1)            0           Advantage_Function_Output_Layer[0
# __________________________________________________________________________________________________
# Value_Function_Output_Layer (De (None, 1)            513         Value_Function_Dense_Layer[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 4)            0           Advantage_Function_Output_Layer[0
#                                                                  tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 4)            0           Value_Function_Output_Layer[0][0]
#                                                                  tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 47,529
# Trainable params: 47,529
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
for i in range(0,max_episodes):
    my_agent.reset_env()
    done = False
    rewards_episodic = 0
    while not(done):
        state, action, reward, next_state, done = my_agent.play_one_step()
        reward = reward if not done else -100
        rewards_episodic += reward
        #my_agent.buffer.add_exp(state, action, reward, next_state, done)
        my_agent.training_step()
        
        
    
    my_agent.apply_epsilon_decay()
    my_agent.soft_target_update()
    
    rewards_buffer.append(round(rewards_episodic,2))
    mean_score = round(np.mean(rewards_buffer))
    mean_score_buffer.append(rewards_episodic)
    recent_mean = round(np.mean(list(mean_score_buffer)))
    print("\r Episode: {}, Episode_Reward: {}, 10_Episode_Reward_Avg {}".format(i, rewards_episodic, recent_mean, end=""))
    
    
    '''if i == 500:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_500')
        
    if i == 1000:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_1000')
        
    if i == 1500:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_1500')
        
    if i == 2000:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_2000')'''
        
        
    if recent_mean >= 200.0:
        print('DQN solved problem terminating...')
        break
# Out:
#  Episode: 0, Episode_Reward: -340.10231266316123, 10_Episode_Reward_Avg -340
#  Episode: 1, Episode_Reward: -82.83737531101866, 10_Episode_Reward_Avg -211
#  Episode: 2, Episode_Reward: -292.5980196986561, 10_Episode_Reward_Avg -239
#  Episode: 3, Episode_Reward: -149.92524513732445, 10_Episode_Reward_Avg -216
#  Episode: 4, Episode_Reward: -289.00602860058996, 10_Episode_Reward_Avg -231
#  Episode: 5, Episode_Reward: -135.48387519462432, 10_Episode_Reward_Avg -215
#  Episode: 6, Episode_Reward: -119.15805590020987, 10_Episode_Reward_Avg -201
#  Episode: 7, Episode_Reward: -139.232942286166, 10_Episode_Reward_Avg -194
#  Episode: 8, Episode_Reward: -89.0030569578808, 10_Episode_Reward_Avg -182
#  Episode: 9, Episode_Reward: -112.269460203206, 10_Episode_Reward_Avg -175
#  Episode: 10, Episode_Reward: -128.9834821095327, 10_Episode_Reward_Avg -171
#  Episode: 11, Episode_Reward: -217.6951278694825, 10_Episode_Reward_Avg -175
#  Episode: 12, Episode_Reward: -136.07996094902683, 10_Episode_Reward_Avg -172
#  Episode: 13, Episode_Reward: -63.716547479447016, 10_Episode_Reward_Avg -164
#  Episode: 14, Episode_Reward: -164.18618759685413, 10_Episode_Reward_Avg -164
#  Episode: 15, Episode_Reward: -115.40461100123416, 10_Episode_Reward_Avg -161
#  Episode: 16, Episode_Reward: -70.71324687679973, 10_Episode_Reward_Avg -156
#  Episode: 17, Episode_Reward: -90.10979905284938, 10_Episode_Reward_Avg -152
#  Episode: 18, Episode_Reward: -89.71499918615139, 10_Episode_Reward_Avg -149
#  Episode: 19, Episode_Reward: -65.32950368899577, 10_Episode_Reward_Avg -145
#  Episode: 20, Episode_Reward: -140.07762299739264, 10_Episode_Reward_Avg -144
#  Episode: 21, Episode_Reward: -263.0790441606735, 10_Episode_Reward_Avg -150
#  Episode: 22, Episode_Reward: -235.8627656260739, 10_Episode_Reward_Avg -154
#  Episode: 23, Episode_Reward: -80.78889479680886, 10_Episode_Reward_Avg -150
#  Episode: 24, Episode_Reward: -35.8159179321119, 10_Episode_Reward_Avg -146
#  Episode: 25, Episode_Reward: -152.04854792962493, 10_Episode_Reward_Avg -146
#  Episode: 26, Episode_Reward: -242.84037854124622, 10_Episode_Reward_Avg -150
#  Episode: 27, Episode_Reward: -322.4364930171979, 10_Episode_Reward_Avg -156
#  Episode: 28, Episode_Reward: -98.04250240866834, 10_Episode_Reward_Avg -154
#  Episode: 29, Episode_Reward: -324.9206616656039, 10_Episode_Reward_Avg -160
#  Episode: 30, Episode_Reward: -68.92965280480666, 10_Episode_Reward_Avg -157
#  Episode: 31, Episode_Reward: -351.6140153757189, 10_Episode_Reward_Avg -163
#  Episode: 32, Episode_Reward: -127.20234938977639, 10_Episode_Reward_Avg -162
#  Episode: 33, Episode_Reward: -275.9870550119141, 10_Episode_Reward_Avg -165
#  Episode: 34, Episode_Reward: -83.84824088794203, 10_Episode_Reward_Avg -163
#  Episode: 35, Episode_Reward: -67.21581657308981, 10_Episode_Reward_Avg -160
#  Episode: 36, Episode_Reward: -304.7099954332267, 10_Episode_Reward_Avg -164
#  Episode: 37, Episode_Reward: -74.72413733257567, 10_Episode_Reward_Avg -162
#  Episode: 38, Episode_Reward: -320.28754352246716, 10_Episode_Reward_Avg -166
#  Episode: 39, Episode_Reward: -60.05160805351131, 10_Episode_Reward_Avg -163
#  Episode: 40, Episode_Reward: -344.1748747577866, 10_Episode_Reward_Avg -167
#  Episode: 41, Episode_Reward: -217.1679514206634, 10_Episode_Reward_Avg -169
#  Episode: 42, Episode_Reward: -321.8279668343664, 10_Episode_Reward_Avg -172
#  Episode: 43, Episode_Reward: -421.5887729989509, 10_Episode_Reward_Avg -178
#  Episode: 44, Episode_Reward: -94.69697733935175, 10_Episode_Reward_Avg -176
#  Episode: 45, Episode_Reward: -31.972183637818688, 10_Episode_Reward_Avg -173
#  Episode: 46, Episode_Reward: -131.12360502610062, 10_Episode_Reward_Avg -172
#  Episode: 47, Episode_Reward: -72.9087937753375, 10_Episode_Reward_Avg -170
#  Episode: 48, Episode_Reward: -30.478617627879643, 10_Episode_Reward_Avg -167
#  Episode: 49, Episode_Reward: -131.4254181553962, 10_Episode_Reward_Avg -166
#  Episode: 50, Episode_Reward: 28.21212042174824, 10_Episode_Reward_Avg -163
#  Episode: 51, Episode_Reward: -242.04327824576873, 10_Episode_Reward_Avg -164
#  Episode: 52, Episode_Reward: 22.30764178280799, 10_Episode_Reward_Avg -161
#  Episode: 53, Episode_Reward: -82.07594937499601, 10_Episode_Reward_Avg -159
#  Episode: 54, Episode_Reward: -69.94126469754852, 10_Episode_Reward_Avg -158
#  Episode: 55, Episode_Reward: -28.734986254499688, 10_Episode_Reward_Avg -155
#  Episode: 56, Episode_Reward: -77.47507651758602, 10_Episode_Reward_Avg -154
#  Episode: 57, Episode_Reward: -371.3129570499936, 10_Episode_Reward_Avg -158
#  Episode: 58, Episode_Reward: -75.86427670995265, 10_Episode_Reward_Avg -156
#  Episode: 59, Episode_Reward: -136.4333077844675, 10_Episode_Reward_Avg -156
#  Episode: 60, Episode_Reward: -315.9441406671093, 10_Episode_Reward_Avg -159
#  Episode: 61, Episode_Reward: -132.4996379967343, 10_Episode_Reward_Avg -158
#  Episode: 62, Episode_Reward: -148.8160389723305, 10_Episode_Reward_Avg -158
#  Episode: 63, Episode_Reward: -134.40253001066077, 10_Episode_Reward_Avg -158
#  Episode: 64, Episode_Reward: -126.02482720164504, 10_Episode_Reward_Avg -157
#  Episode: 65, Episode_Reward: -89.48362603399612, 10_Episode_Reward_Avg -156
#  Episode: 66, Episode_Reward: -130.9188411802146, 10_Episode_Reward_Avg -156
#  Episode: 67, Episode_Reward: -292.5504504559452, 10_Episode_Reward_Avg -158
#  Episode: 104, Episode_Reward: -213.53212940805307, 10_Episode_Reward_Avg -166
#  Episode: 105, Episode_Reward: -171.93467643732748, 10_Episode_Reward_Avg -166
#  Episode: 106, Episode_Reward: -26.80257238094009, 10_Episode_Reward_Avg -166
#  Episode: 107, Episode_Reward: -509.28987940226284, 10_Episode_Reward_Avg -169
#  Episode: 108, Episode_Reward: -105.44475255838738, 10_Episode_Reward_Avg -169
#  Episode: 109, Episode_Reward: -215.32762821560658, 10_Episode_Reward_Avg -170
#  Episode: 110, Episode_Reward: -431.5099656390126, 10_Episode_Reward_Avg -173
#  Episode: 111, Episode_Reward: -139.16628143189874, 10_Episode_Reward_Avg -173
#  Episode: 112, Episode_Reward: -409.7092976994906, 10_Episode_Reward_Avg -175
#  Episode: 113, Episode_Reward: -71.3152650670948, 10_Episode_Reward_Avg -176
#  Episode: 114, Episode_Reward: -380.09705719227594, 10_Episode_Reward_Avg -178
#  Episode: 115, Episode_Reward: -205.50271898021947, 10_Episode_Reward_Avg -179
#  Episode: 116, Episode_Reward: -298.6349022781178, 10_Episode_Reward_Avg -181
#  Episode: 117, Episode_Reward: -493.3751436670097, 10_Episode_Reward_Avg -185
#  Episode: 118, Episode_Reward: -434.0821849822939, 10_Episode_Reward_Avg -188
#  Episode: 119, Episode_Reward: -486.40463608705556, 10_Episode_Reward_Avg -193
#  Episode: 120, Episode_Reward: -304.08676366777195, 10_Episode_Reward_Avg -194
#  Episode: 121, Episode_Reward: -200.97440762666497, 10_Episode_Reward_Avg -194
#  Episode: 122, Episode_Reward: -281.8961173987252, 10_Episode_Reward_Avg -194
#  Episode: 123, Episode_Reward: -219.90411559561278, 10_Episode_Reward_Avg -195
#  Episode: 124, Episode_Reward: -258.3517797498929, 10_Episode_Reward_Avg -198
#  Episode: 125, Episode_Reward: -265.82421001377395, 10_Episode_Reward_Avg -199
#  Episode: 126, Episode_Reward: -331.660958045786, 10_Episode_Reward_Avg -200
#  Episode: 127, Episode_Reward: -96.025862440264, 10_Episode_Reward_Avg -197
#  Episode: 128, Episode_Reward: -68.73697322594019, 10_Episode_Reward_Avg -197
#  Episode: 129, Episode_Reward: -177.13123974579318, 10_Episode_Reward_Avg -196
#  Episode: 130, Episode_Reward: -384.88680820917745, 10_Episode_Reward_Avg -199
#  Episode: 131, Episode_Reward: -248.94120483181277, 10_Episode_Reward_Avg -198
#  Episode: 132, Episode_Reward: -89.93264423040631, 10_Episode_Reward_Avg -197
#  Episode: 133, Episode_Reward: -399.6580229755603, 10_Episode_Reward_Avg -199
#  Episode: 134, Episode_Reward: -223.69413954437226, 10_Episode_Reward_Avg -200
#  Episode: 135, Episode_Reward: -308.7807280498568, 10_Episode_Reward_Avg -202
#  Episode: 136, Episode_Reward: -322.69304421230333, 10_Episode_Reward_Avg -203
#  Episode: 137, Episode_Reward: -51.16488278318259, 10_Episode_Reward_Avg -202
#  Episode: 138, Episode_Reward: -305.8297421834976, 10_Episode_Reward_Avg -202
#  Episode: 139, Episode_Reward: -200.07576811015252, 10_Episode_Reward_Avg -204
#  Episode: 247, Episode_Reward: -179.67516022742342, 10_Episode_Reward_Avg -274
#  Episode: 248, Episode_Reward: -462.6568213000621, 10_Episode_Reward_Avg -276
#  Episode: 249, Episode_Reward: -130.3550148936697, 10_Episode_Reward_Avg -276
#  Episode: 250, Episode_Reward: -620.2930007762604, 10_Episode_Reward_Avg -276
#  Episode: 251, Episode_Reward: -404.02253294843723, 10_Episode_Reward_Avg -279
#  Episode: 252, Episode_Reward: -618.9817781569844, 10_Episode_Reward_Avg -282
#  Episode: 253, Episode_Reward: -73.29212454172546, 10_Episode_Reward_Avg -281
#  Episode: 254, Episode_Reward: -678.7905735632357, 10_Episode_Reward_Avg -286
#  Episode: 255, Episode_Reward: -492.17754110586617, 10_Episode_Reward_Avg -288
#  Episode: 256, Episode_Reward: -316.66370761537155, 10_Episode_Reward_Avg -288
#  Episode: 257, Episode_Reward: -332.6135025351183, 10_Episode_Reward_Avg -290
#  Episode: 258, Episode_Reward: -518.3033533232723, 10_Episode_Reward_Avg -294
#  Episode: 259, Episode_Reward: -272.9221602335853, 10_Episode_Reward_Avg -292
#  Episode: 260, Episode_Reward: -467.0960747754557, 10_Episode_Reward_Avg -294
#  Episode: 261, Episode_Reward: -155.82737899691026, 10_Episode_Reward_Avg -292
#  Episode: 262, Episode_Reward: -114.5210220856703, 10_Episode_Reward_Avg -291
#  Episode: 263, Episode_Reward: -186.57769359016908, 10_Episode_Reward_Avg -292
#  Episode: 264, Episode_Reward: -648.4743939599987, 10_Episode_Reward_Avg -292
#  Episode: 265, Episode_Reward: -211.09539761248368, 10_Episode_Reward_Avg -292
#  Episode: 266, Episode_Reward: -180.6579328757402, 10_Episode_Reward_Avg -293
#  Episode: 267, Episode_Reward: -359.7229957729999, 10_Episode_Reward_Avg -293
#  Episode: 268, Episode_Reward: -330.87007921050156, 10_Episode_Reward_Avg -289
#  Episode: 269, Episode_Reward: -408.4440139238751, 10_Episode_Reward_Avg -292
#  Episode: 270, Episode_Reward: -820.40627769224, 10_Episode_Reward_Avg -297
#  Episode: 271, Episode_Reward: -91.78892479764463, 10_Episode_Reward_Avg -295
#  Episode: 272, Episode_Reward: -249.22860945564767, 10_Episode_Reward_Avg -294
#  Episode: 273, Episode_Reward: -150.69244441994937, 10_Episode_Reward_Avg -293
#  Episode: 274, Episode_Reward: -174.90732705834097, 10_Episode_Reward_Avg -290
#  Episode: 275, Episode_Reward: -281.99505597453737, 10_Episode_Reward_Avg -291
#  Episode: 276, Episode_Reward: -549.4330342048704, 10_Episode_Reward_Avg -294
#  Episode: 277, Episode_Reward: -376.3254802897843, 10_Episode_Reward_Avg -295
#  Episode: 278, Episode_Reward: -223.82846946782553, 10_Episode_Reward_Avg -295
#  Episode: 279, Episode_Reward: -287.3142973262268, 10_Episode_Reward_Avg -296
#  Episode: 280, Episode_Reward: -42.79749328916485, 10_Episode_Reward_Avg -296
#  Episode: 281, Episode_Reward: -107.97248644459142, 10_Episode_Reward_Avg -292
#  Episode: 282, Episode_Reward: -61.966988932254864, 10_Episode_Reward_Avg -288
#  Episode: 283, Episode_Reward: -474.7226960664494, 10_Episode_Reward_Avg -293
#  Episode: 284, Episode_Reward: -553.9135487937103, 10_Episode_Reward_Avg -293
#  Episode: 285, Episode_Reward: -373.4603288172376, 10_Episode_Reward_Avg -291
#  Episode: 286, Episode_Reward: -151.26630780290628, 10_Episode_Reward_Avg -291
#  Episode: 287, Episode_Reward: -165.81617924531287, 10_Episode_Reward_Avg -288
#  Episode: 288, Episode_Reward: -158.84984327642258, 10_Episode_Reward_Avg -288
#  Episode: 289, Episode_Reward: -194.59147231744197, 10_Episode_Reward_Avg -287
#  Episode: 290, Episode_Reward: -127.08295982308492, 10_Episode_Reward_Avg -285
#  Episode: 291, Episode_Reward: -294.1181326835426, 10_Episode_Reward_Avg -285
#  Episode: 292, Episode_Reward: -141.5220705556629, 10_Episode_Reward_Avg -284
#  Episode: 293, Episode_Reward: -171.64216516653815, 10_Episode_Reward_Avg -283
#  Episode: 294, Episode_Reward: -122.54561173990875, 10_Episode_Reward_Avg -283
#  Episode: 295, Episode_Reward: -528.4691879001778, 10_Episode_Reward_Avg -286
#  Episode: 296, Episode_Reward: 30.498032970515112, 10_Episode_Reward_Avg -285
#  Episode: 297, Episode_Reward: -190.87422859187404, 10_Episode_Reward_Avg -284
#  Episode: 298, Episode_Reward: -182.658990570492, 10_Episode_Reward_Avg -284
#  Episode: 299, Episode_Reward: -437.7120699931156, 10_Episode_Reward_Avg -286
#  Episode: 300, Episode_Reward: -460.9827679500252, 10_Episode_Reward_Avg -285
#  Episode: 301, Episode_Reward: -262.19341534767545, 10_Episode_Reward_Avg -286
#  Episode: 302, Episode_Reward: -447.33996023755554, 10_Episode_Reward_Avg -288
#  Episode: 303, Episode_Reward: -645.795697568541, 10_Episode_Reward_Avg -293
#  Episode: 304, Episode_Reward: -136.84973553358293, 10_Episode_Reward_Avg -293
#  Episode: 305, Episode_Reward: -445.90250696516046, 10_Episode_Reward_Avg -295
#  Episode: 306, Episode_Reward: -215.95232466684143, 10_Episode_Reward_Avg -295
#  Episode: 307, Episode_Reward: -154.82565396004566, 10_Episode_Reward_Avg -295
#  Episode: 308, Episode_Reward: -29.91737924214442, 10_Episode_Reward_Avg -294
#  Episode: 309, Episode_Reward: -118.66286754274287, 10_Episode_Reward_Avg -291
#  Episode: 310, Episode_Reward: -323.8086330073145, 10_Episode_Reward_Avg -293
#  Episode: 311, Episode_Reward: -384.39629140251174, 10_Episode_Reward_Avg -295
#  Episode: 312, Episode_Reward: -173.03108380427003, 10_Episode_Reward_Avg -296
#  Episode: 313, Episode_Reward: -472.2471811271474, 10_Episode_Reward_Avg -299
#  Episode: 314, Episode_Reward: -105.57071668194587, 10_Episode_Reward_Avg -298
#  Episode: 315, Episode_Reward: -263.0395810722212, 10_Episode_Reward_Avg -296
#  Episode: 316, Episode_Reward: -523.6785841191885, 10_Episode_Reward_Avg -296
#  Episode: 317, Episode_Reward: -98.05240879270845, 10_Episode_Reward_Avg -293
#  Episode: 318, Episode_Reward: -370.81884751647385, 10_Episode_Reward_Avg -292
#  Episode: 391, Episode_Reward: -185.60453214044935, 10_Episode_Reward_Avg -257
#  Episode: 392, Episode_Reward: -231.95652217269776, 10_Episode_Reward_Avg -257
#  Episode: 393, Episode_Reward: -55.14786370986552, 10_Episode_Reward_Avg -256
#  Episode: 394, Episode_Reward: -598.4115150498487, 10_Episode_Reward_Avg -261
#  Episode: 395, Episode_Reward: -231.5204889729731, 10_Episode_Reward_Avg -258
#  Episode: 396, Episode_Reward: -381.12091870318045, 10_Episode_Reward_Avg -262
#  Episode: 397, Episode_Reward: -155.47815130612338, 10_Episode_Reward_Avg -262
#  Episode: 398, Episode_Reward: -74.72868991826724, 10_Episode_Reward_Avg -261
#  Episode: 399, Episode_Reward: -476.828667251198, 10_Episode_Reward_Avg -261
#  Episode: 400, Episode_Reward: -196.25103223281624, 10_Episode_Reward_Avg -259
#  Episode: 401, Episode_Reward: -52.25943253790091, 10_Episode_Reward_Avg -256
#  Episode: 402, Episode_Reward: -138.23111791946536, 10_Episode_Reward_Avg -253
#  Episode: 403, Episode_Reward: -106.7961870674569, 10_Episode_Reward_Avg -248
#  Episode: 404, Episode_Reward: -513.0122136585894, 10_Episode_Reward_Avg -252
#  Episode: 405, Episode_Reward: -650.5844475532444, 10_Episode_Reward_Avg -254
#  Episode: 406, Episode_Reward: -191.01221966555335, 10_Episode_Reward_Avg -254
#  Episode: 407, Episode_Reward: -440.140598683901, 10_Episode_Reward_Avg -256
#  Episode: 408, Episode_Reward: -388.7823470943408, 10_Episode_Reward_Avg -260
#  Episode: 409, Episode_Reward: -233.26777978542526, 10_Episode_Reward_Avg -261
#  Episode: 410, Episode_Reward: -221.4022639800122, 10_Episode_Reward_Avg -260
#  Episode: 411, Episode_Reward: -332.56864269110883, 10_Episode_Reward_Avg -260
#  Episode: 412, Episode_Reward: -318.4948713805245, 10_Episode_Reward_Avg -261
#  Episode: 413, Episode_Reward: -491.56262036740594, 10_Episode_Reward_Avg -261
#  Episode: 414, Episode_Reward: -512.4802931570794, 10_Episode_Reward_Avg -265
#  Episode: 415, Episode_Reward: -188.15194593834357, 10_Episode_Reward_Avg -265
#  Episode: 416, Episode_Reward: -282.7323546762692, 10_Episode_Reward_Avg -262
#  Episode: 417, Episode_Reward: -423.3897500787848, 10_Episode_Reward_Avg -265
#  Episode: 418, Episode_Reward: -486.9542068393564, 10_Episode_Reward_Avg -267
#  Episode: 419, Episode_Reward: -88.38169952078957, 10_Episode_Reward_Avg -266
#  Episode: 420, Episode_Reward: -94.73546863398091, 10_Episode_Reward_Avg -262
#  Episode: 421, Episode_Reward: -496.7644844948208, 10_Episode_Reward_Avg -266
#  Episode: 422, Episode_Reward: -217.6391714786833, 10_Episode_Reward_Avg -266
#  Episode: 423, Episode_Reward: -330.3813809157145, 10_Episode_Reward_Avg -266
#  Episode: 424, Episode_Reward: -342.57007780564766, 10_Episode_Reward_Avg -268
#  Episode: 425, Episode_Reward: -99.7016584481552, 10_Episode_Reward_Avg -269
#  Episode: 426, Episode_Reward: -190.15453791933038, 10_Episode_Reward_Avg -268
#  Episode: 463, Episode_Reward: -372.101687972256, 10_Episode_Reward_Avg -285
#  Episode: 464, Episode_Reward: -381.72070112333677, 10_Episode_Reward_Avg -286
#  Episode: 465, Episode_Reward: -145.0959968021537, 10_Episode_Reward_Avg -284
#  Episode: 466, Episode_Reward: -396.37045664332504, 10_Episode_Reward_Avg -283
#  Episode: 467, Episode_Reward: -268.40474038923867, 10_Episode_Reward_Avg -281
#  Episode: 468, Episode_Reward: -210.47689240780002, 10_Episode_Reward_Avg -281
#  Episode: 469, Episode_Reward: -0.7539355305286222, 10_Episode_Reward_Avg -277
#  Episode: 470, Episode_Reward: -193.90444393381642, 10_Episode_Reward_Avg -278
#  Episode: 471, Episode_Reward: -70.71931497709713, 10_Episode_Reward_Avg -276
#  Episode: 472, Episode_Reward: -78.3186503183397, 10_Episode_Reward_Avg -269
#  Episode: 473, Episode_Reward: -694.4430580065317, 10_Episode_Reward_Avg -273
#  Episode: 474, Episode_Reward: -221.02897345232134, 10_Episode_Reward_Avg -272
#  Episode: 475, Episode_Reward: -172.84544018171096, 10_Episode_Reward_Avg -270
#  Episode: 476, Episode_Reward: -260.80652025925974, 10_Episode_Reward_Avg -271
#  Episode: 477, Episode_Reward: -528.1464555298044, 10_Episode_Reward_Avg -273
#  Episode: 478, Episode_Reward: -250.99560001328055, 10_Episode_Reward_Avg -275
#  Episode: 479, Episode_Reward: -256.07989987874134, 10_Episode_Reward_Avg -276
#  Episode: 480, Episode_Reward: -109.12812800018551, 10_Episode_Reward_Avg -276
#  Episode: 481, Episode_Reward: -98.43906764083648, 10_Episode_Reward_Avg -276
#  Episode: 482, Episode_Reward: -394.23044013233806, 10_Episode_Reward_Avg -279
#  Episode: 483, Episode_Reward: -675.8825268516467, 10_Episode_Reward_Avg -283
#  Episode: 484, Episode_Reward: -208.8848944815867, 10_Episode_Reward_Avg -284
#  Episode: 485, Episode_Reward: -292.8201451702339, 10_Episode_Reward_Avg -284
#  Episode: 486, Episode_Reward: -173.94880224353244, 10_Episode_Reward_Avg -282
#  Episode: 487, Episode_Reward: -476.58333584701256, 10_Episode_Reward_Avg -283
#  Episode: 488, Episode_Reward: -301.2764401965494, 10_Episode_Reward_Avg -282
#  Episode: 489, Episode_Reward: -108.06038603476458, 10_Episode_Reward_Avg -280
#  Episode: 490, Episode_Reward: -98.24541642853787, 10_Episode_Reward_Avg -278
#  Episode: 491, Episode_Reward: -327.32976531131897, 10_Episode_Reward_Avg -279
#  Episode: 492, Episode_Reward: -369.81694003511143, 10_Episode_Reward_Avg -280
#  Episode: 493, Episode_Reward: -468.7771571384559, 10_Episode_Reward_Avg -285
#  Episode: 494, Episode_Reward: -162.54851525970764, 10_Episode_Reward_Avg -280
#  Episode: 495, Episode_Reward: -210.86087874497585, 10_Episode_Reward_Avg -280
#  Episode: 496, Episode_Reward: -524.9942389121704, 10_Episode_Reward_Avg -281
#  Episode: 497, Episode_Reward: -112.46112094079288, 10_Episode_Reward_Avg -281
#  Episode: 498, Episode_Reward: -327.73561660357075, 10_Episode_Reward_Avg -284
#  Episode: 499, Episode_Reward: -451.1874220002017, 10_Episode_Reward_Avg -283
#  Episode: 500, Episode_Reward: -470.5787795384822, 10_Episode_Reward_Avg -286
#  Episode: 501, Episode_Reward: -156.4093839761016, 10_Episode_Reward_Avg -287
#  Episode: 502, Episode_Reward: -566.748707971261, 10_Episode_Reward_Avg -291
#  Episode: 503, Episode_Reward: -336.54242694681534, 10_Episode_Reward_Avg -294
#  Episode: 504, Episode_Reward: -462.8219174028928, 10_Episode_Reward_Avg -293
#  Episode: 505, Episode_Reward: -196.32219769574755, 10_Episode_Reward_Avg -289
#  Episode: 506, Episode_Reward: -175.96495168858436, 10_Episode_Reward_Avg -288
#  Episode: 507, Episode_Reward: -121.5447867876421, 10_Episode_Reward_Avg -285
#  Episode: 508, Episode_Reward: -211.14649693692573, 10_Episode_Reward_Avg -283
#  Episode: 509, Episode_Reward: -194.46564900034323, 10_Episode_Reward_Avg -283
#  Episode: 510, Episode_Reward: -287.73497575464387, 10_Episode_Reward_Avg -284
#  Episode: 511, Episode_Reward: -152.99867441724487, 10_Episode_Reward_Avg -282
#  Episode: 512, Episode_Reward: -141.07813668920284, 10_Episode_Reward_Avg -280
#  Episode: 513, Episode_Reward: -565.1791903834234, 10_Episode_Reward_Avg -281
#  Episode: 514, Episode_Reward: -91.89537013116755, 10_Episode_Reward_Avg -277
#  Episode: 515, Episode_Reward: -606.2960593313666, 10_Episode_Reward_Avg -281
#  Episode: 516, Episode_Reward: -210.00141899263838, 10_Episode_Reward_Avg -280
#  Episode: 517, Episode_Reward: -453.35214955742276, 10_Episode_Reward_Avg -280
#  Episode: 518, Episode_Reward: -269.62548138704653, 10_Episode_Reward_Avg -278
#  Episode: 519, Episode_Reward: -404.9196794651963, 10_Episode_Reward_Avg -281
#  Episode: 520, Episode_Reward: -440.38045035272927, 10_Episode_Reward_Avg -285
#  Episode: 521, Episode_Reward: -380.7394012510837, 10_Episode_Reward_Avg -284
#  Episode: 522, Episode_Reward: -196.52885539394154, 10_Episode_Reward_Avg -284
#  Episode: 523, Episode_Reward: -136.0249969054712, 10_Episode_Reward_Avg -282
#  Episode: 524, Episode_Reward: -422.3788894118843, 10_Episode_Reward_Avg -282
#  Episode: 525, Episode_Reward: -80.08248679407545, 10_Episode_Reward_Avg -282
#  Episode: 526, Episode_Reward: -300.21580838615694, 10_Episode_Reward_Avg -283
#  Episode: 527, Episode_Reward: -295.33867911897255, 10_Episode_Reward_Avg -284
#  Episode: 528, Episode_Reward: -235.55090189476888, 10_Episode_Reward_Avg -283
#  Episode: 529, Episode_Reward: -99.46723716839851, 10_Episode_Reward_Avg -282
#  Episode: 530, Episode_Reward: -151.27285963444677, 10_Episode_Reward_Avg -279
#  Episode: 531, Episode_Reward: -251.87294688108094, 10_Episode_Reward_Avg -280
#  Episode: 532, Episode_Reward: -182.78889079625083, 10_Episode_Reward_Avg -280
#  Episode: 533, Episode_Reward: -351.20017525130595, 10_Episode_Reward_Avg -283
#  Episode: 534, Episode_Reward: -456.1467372361644, 10_Episode_Reward_Avg -283
#  Episode: 535, Episode_Reward: -54.46916785271714, 10_Episode_Reward_Avg -281
#  Episode: 536, Episode_Reward: -287.3844135226533, 10_Episode_Reward_Avg -280
#  Episode: 537, Episode_Reward: -409.7172666203436, 10_Episode_Reward_Avg -281
#  Episode: 538, Episode_Reward: -444.16504832399136, 10_Episode_Reward_Avg -283
#  Episode: 539, Episode_Reward: -304.3567078154364, 10_Episode_Reward_Avg -283
#  Episode: 540, Episode_Reward: -284.0243137871437, 10_Episode_Reward_Avg -284
#  Episode: 541, Episode_Reward: -355.1083190327278, 10_Episode_Reward_Avg -284
#  Episode: 542, Episode_Reward: -405.11929907321223, 10_Episode_Reward_Avg -283
#  Episode: 543, Episode_Reward: -637.0631703085763, 10_Episode_Reward_Avg -288
#  Episode: 544, Episode_Reward: -224.69829188217713, 10_Episode_Reward_Avg -289
#  Episode: 545, Episode_Reward: -459.426152414231, 10_Episode_Reward_Avg -288
#  Episode: 546, Episode_Reward: -360.6070635868889, 10_Episode_Reward_Avg -287
#  Episode: 547, Episode_Reward: -604.0971822301791, 10_Episode_Reward_Avg -292
#  Episode: 548, Episode_Reward: -421.12224745248625, 10_Episode_Reward_Avg -295
#  Episode: 549, Episode_Reward: -11.429982202806784, 10_Episode_Reward_Avg -294
#  Episode: 550, Episode_Reward: -330.29032521066614, 10_Episode_Reward_Avg -292
#  Episode: 551, Episode_Reward: -276.9338325605505, 10_Episode_Reward_Avg -290
#  Episode: 552, Episode_Reward: -320.1328949524741, 10_Episode_Reward_Avg -290
#  Episode: 553, Episode_Reward: -223.80777156319198, 10_Episode_Reward_Avg -290
#  Episode: 554, Episode_Reward: -205.90025428609016, 10_Episode_Reward_Avg -288
#  Episode: 555, Episode_Reward: -135.55590494521866, 10_Episode_Reward_Avg -289
#  Episode: 556, Episode_Reward: -307.82223838829873, 10_Episode_Reward_Avg -290
#  Episode: 557, Episode_Reward: -395.7217480938664, 10_Episode_Reward_Avg -290
#  Episode: 558, Episode_Reward: -149.85831070795106, 10_Episode_Reward_Avg -289
#  Episode: 559, Episode_Reward: -19.159143339080458, 10_Episode_Reward_Avg -286
#  Episode: 560, Episode_Reward: -247.99744232483818, 10_Episode_Reward_Avg -286
#  Episode: 561, Episode_Reward: -267.71522178822744, 10_Episode_Reward_Avg -288
#  Episode: 562, Episode_Reward: -439.45216960672724, 10_Episode_Reward_Avg -290
#  Episode: 563, Episode_Reward: -289.6132652374207, 10_Episode_Reward_Avg -290
#  Episode: 564, Episode_Reward: -185.44200206400706, 10_Episode_Reward_Avg -288
#  Episode: 565, Episode_Reward: -258.040689175264, 10_Episode_Reward_Avg -289
#  Episode: 566, Episode_Reward: -486.7522025529459, 10_Episode_Reward_Avg -290
#  Episode: 567, Episode_Reward: -33.97647075943286, 10_Episode_Reward_Avg -287
#  Episode: 568, Episode_Reward: -163.6528836564775, 10_Episode_Reward_Avg -287
#  Episode: 569, Episode_Reward: -296.7524231360592, 10_Episode_Reward_Avg -290
#  Episode: 570, Episode_Reward: -490.86139790669216, 10_Episode_Reward_Avg -293
#  Episode: 571, Episode_Reward: -383.8123273896818, 10_Episode_Reward_Avg -296
#  Episode: 572, Episode_Reward: -78.73760803202651, 10_Episode_Reward_Avg -296
#  Episode: 573, Episode_Reward: -568.3578491998949, 10_Episode_Reward_Avg -295
#  Episode: 574, Episode_Reward: -123.04982056889091, 10_Episode_Reward_Avg -294
#  Episode: 575, Episode_Reward: -107.91671328242715, 10_Episode_Reward_Avg -293
#  Episode: 576, Episode_Reward: -323.3876859755326, 10_Episode_Reward_Avg -294
#  Episode: 577, Episode_Reward: -83.64742933988788, 10_Episode_Reward_Avg -289
#  Episode: 578, Episode_Reward: -146.6849363348823, 10_Episode_Reward_Avg -288
#  Episode: 579, Episode_Reward: -144.55257703562506, 10_Episode_Reward_Avg -287
#  Episode: 580, Episode_Reward: -77.63498482256118, 10_Episode_Reward_Avg -287
#  Episode: 581, Episode_Reward: -299.2730194334494, 10_Episode_Reward_Avg -289
#  Episode: 582, Episode_Reward: -349.3829178819651, 10_Episode_Reward_Avg -288
#  Episode: 583, Episode_Reward: -161.08724295631083, 10_Episode_Reward_Avg -283
#  Episode: 584, Episode_Reward: -472.83230012672664, 10_Episode_Reward_Avg -286
#  Episode: 585, Episode_Reward: -391.3295342299576, 10_Episode_Reward_Avg -287
#  Episode: 586, Episode_Reward: -359.2956384075354, 10_Episode_Reward_Avg -289
#  Episode: 587, Episode_Reward: -510.7562703209932, 10_Episode_Reward_Avg -289
#  Episode: 588, Episode_Reward: -365.5010982634309, 10_Episode_Reward_Avg -290
#  Episode: 589, Episode_Reward: -290.14300687028225, 10_Episode_Reward_Avg -291
#  Episode: 590, Episode_Reward: -546.1922940990784, 10_Episode_Reward_Avg -296
#  Episode: 591, Episode_Reward: -406.3500848279341, 10_Episode_Reward_Avg -297
#  Episode: 592, Episode_Reward: -82.17608778421075, 10_Episode_Reward_Avg -294
#  Episode: 593, Episode_Reward: -214.44914737527665, 10_Episode_Reward_Avg -291
#  Episode: 594, Episode_Reward: -126.16638634278915, 10_Episode_Reward_Avg -291
#  Episode: 595, Episode_Reward: -84.59428902014892, 10_Episode_Reward_Avg -290
#  Episode: 596, Episode_Reward: -412.7727616066087, 10_Episode_Reward_Avg -288
#  Episode: 597, Episode_Reward: -195.73268970656838, 10_Episode_Reward_Avg -289
#  Episode: 598, Episode_Reward: -41.32873471306152, 10_Episode_Reward_Avg -286
#  Episode: 599, Episode_Reward: -189.97592090959722, 10_Episode_Reward_Avg -284
#  Episode: 600, Episode_Reward: -541.6544245301166, 10_Episode_Reward_Avg -285
#  Episode: 601, Episode_Reward: -294.0031129510319, 10_Episode_Reward_Avg -286
#  Episode: 602, Episode_Reward: -237.18840804572298, 10_Episode_Reward_Avg -283
#  Episode: 603, Episode_Reward: -275.0813423232299, 10_Episode_Reward_Avg -282
#  Episode: 604, Episode_Reward: -169.7707168416934, 10_Episode_Reward_Avg -279
#  Episode: 605, Episode_Reward: 26.755804552977366, 10_Episode_Reward_Avg -277
#  Episode: 606, Episode_Reward: -178.22834480178, 10_Episode_Reward_Avg -277
#  Episode: 607, Episode_Reward: -264.6424795562775, 10_Episode_Reward_Avg -278
#  Episode: 608, Episode_Reward: -500.1195636976523, 10_Episode_Reward_Avg -281
#  Episode: 609, Episode_Reward: -348.13707299394076, 10_Episode_Reward_Avg -283
#  Episode: 610, Episode_Reward: -277.20280333937984, 10_Episode_Reward_Avg -283
#  Episode: 611, Episode_Reward: -571.7050514535771, 10_Episode_Reward_Avg -287
#  Episode: 612, Episode_Reward: -226.1475374094121, 10_Episode_Reward_Avg -288
#  Episode: 613, Episode_Reward: -163.36845643469854, 10_Episode_Reward_Avg -284
#  Episode: 614, Episode_Reward: -124.28745666959105, 10_Episode_Reward_Avg -284
#  Episode: 615, Episode_Reward: -298.67848360989524, 10_Episode_Reward_Avg -281
#  Episode: 616, Episode_Reward: -97.98672153907404, 10_Episode_Reward_Avg -280
#  Episode: 617, Episode_Reward: -234.03362259598103, 10_Episode_Reward_Avg -278
#  Episode: 618, Episode_Reward: -180.5834652088956, 10_Episode_Reward_Avg -277
#  Episode: 619, Episode_Reward: -647.3101190035812, 10_Episode_Reward_Avg -279
#  Episode: 620, Episode_Reward: -296.04846904896056, 10_Episode_Reward_Avg -278
#  Episode: 621, Episode_Reward: -581.262128239264, 10_Episode_Reward_Avg -280
#  Episode: 622, Episode_Reward: -304.3551015170169, 10_Episode_Reward_Avg -281
#  Episode: 623, Episode_Reward: -310.78392666801585, 10_Episode_Reward_Avg -282
#  Episode: 624, Episode_Reward: -199.38605121177108, 10_Episode_Reward_Avg -280
#  Episode: 625, Episode_Reward: -361.9944543767158, 10_Episode_Reward_Avg -283
#  Episode: 626, Episode_Reward: -275.1598681453829, 10_Episode_Reward_Avg -283
#  Episode: 627, Episode_Reward: -230.4807837759297, 10_Episode_Reward_Avg -282
#  Episode: 628, Episode_Reward: -189.59553804715915, 10_Episode_Reward_Avg -282
#  Episode: 629, Episode_Reward: -224.85141547646302, 10_Episode_Reward_Avg -283
#  Episode: 630, Episode_Reward: -83.70595721628086, 10_Episode_Reward_Avg -282
#  Episode: 631, Episode_Reward: -411.16146974859794, 10_Episode_Reward_Avg -284
#  Episode: 632, Episode_Reward: -179.41474312762813, 10_Episode_Reward_Avg -284
#  Episode: 633, Episode_Reward: -326.0843219302962, 10_Episode_Reward_Avg -284
#  Episode: 634, Episode_Reward: -440.70001913534907, 10_Episode_Reward_Avg -283
#  Episode: 635, Episode_Reward: -49.15406080801621, 10_Episode_Reward_Avg -283
#  Episode: 636, Episode_Reward: -620.9021251547422, 10_Episode_Reward_Avg -287
#  Episode: 637, Episode_Reward: -342.83973318922466, 10_Episode_Reward_Avg -286
#  Episode: 638, Episode_Reward: -205.3314321905704, 10_Episode_Reward_Avg -284
#  Episode: 639, Episode_Reward: -294.6822665267135, 10_Episode_Reward_Avg -284
#  Episode: 640, Episode_Reward: -335.0875888273324, 10_Episode_Reward_Avg -284
#  Episode: 641, Episode_Reward: -511.4597392401095, 10_Episode_Reward_Avg -286
#  Episode: 642, Episode_Reward: -233.94452437403083, 10_Episode_Reward_Avg -284
#  Episode: 643, Episode_Reward: -101.57928691542932, 10_Episode_Reward_Avg -279
#  Episode: 644, Episode_Reward: -427.15392735007333, 10_Episode_Reward_Avg -281
#  Episode: 645, Episode_Reward: -513.1356847293473, 10_Episode_Reward_Avg -281
#  Episode: 646, Episode_Reward: -330.880360847301, 10_Episode_Reward_Avg -281
#  Episode: 647, Episode_Reward: -209.83810603027132, 10_Episode_Reward_Avg -277
#  Episode: 648, Episode_Reward: -281.810218455259, 10_Episode_Reward_Avg -276
#  Episode: 649, Episode_Reward: -356.29352836553966, 10_Episode_Reward_Avg -279
#  Episode: 650, Episode_Reward: -105.1335267221206, 10_Episode_Reward_Avg -277
#  Episode: 651, Episode_Reward: -352.03497255183606, 10_Episode_Reward_Avg -277
#  Episode: 652, Episode_Reward: -386.2318274759948, 10_Episode_Reward_Avg -278
#  Episode: 653, Episode_Reward: -274.9778691024152, 10_Episode_Reward_Avg -279
#  Episode: 654, Episode_Reward: -394.51818185957023, 10_Episode_Reward_Avg -281
#  Episode: 655, Episode_Reward: -506.1360001189298, 10_Episode_Reward_Avg -284
#  Episode: 656, Episode_Reward: -249.9859475627479, 10_Episode_Reward_Avg -284
#  Episode: 657, Episode_Reward: -402.808438109218, 10_Episode_Reward_Avg -284
#  Episode: 658, Episode_Reward: -259.2024195109822, 10_Episode_Reward_Avg -285
#  Episode: 659, Episode_Reward: -215.58624423640163, 10_Episode_Reward_Avg -287
#  Episode: 660, Episode_Reward: -66.22655059684507, 10_Episode_Reward_Avg -285
#  Episode: 661, Episode_Reward: -282.5318668974967, 10_Episode_Reward_Avg -285
#  Episode: 662, Episode_Reward: -206.34369578678331, 10_Episode_Reward_Avg -283
#  Episode: 663, Episode_Reward: -387.0033010014436, 10_Episode_Reward_Avg -284
#  Episode: 664, Episode_Reward: -637.7600773718116, 10_Episode_Reward_Avg -288
#  Episode: 665, Episode_Reward: -271.086299670804, 10_Episode_Reward_Avg -288
#  Episode: 666, Episode_Reward: -626.5426164537058, 10_Episode_Reward_Avg -290
#  Episode: 667, Episode_Reward: -192.39918488077996, 10_Episode_Reward_Avg -291
#  Episode: 668, Episode_Reward: -45.75928993396104, 10_Episode_Reward_Avg -290
#  Episode: 669, Episode_Reward: -58.56318726895101, 10_Episode_Reward_Avg -288
#  Episode: 670, Episode_Reward: -498.3880522349151, 10_Episode_Reward_Avg -288
#  Episode: 671, Episode_Reward: -212.24859852753738, 10_Episode_Reward_Avg -286
#  Episode: 672, Episode_Reward: -415.4684450336578, 10_Episode_Reward_Avg -290
#  Episode: 673, Episode_Reward: -466.5871738156718, 10_Episode_Reward_Avg -289
#  Episode: 674, Episode_Reward: -161.7868656530971, 10_Episode_Reward_Avg -289
#  Episode: 675, Episode_Reward: -100.39823131984681, 10_Episode_Reward_Avg -289
#  Episode: 676, Episode_Reward: -180.78153176036537, 10_Episode_Reward_Avg -287
#  Episode: 677, Episode_Reward: -145.34150829065356, 10_Episode_Reward_Avg -288
#  Episode: 678, Episode_Reward: -172.35505287391334, 10_Episode_Reward_Avg -288
#  Episode: 679, Episode_Reward: -167.2301152107274, 10_Episode_Reward_Avg -289
#  Episode: 680, Episode_Reward: -224.32126049533542, 10_Episode_Reward_Avg -290
#  Episode: 681, Episode_Reward: -56.65364359471033, 10_Episode_Reward_Avg -288
#  Episode: 682, Episode_Reward: -236.49572029024995, 10_Episode_Reward_Avg -286
#  Episode: 683, Episode_Reward: -296.029877421774, 10_Episode_Reward_Avg -288
#  Episode: 684, Episode_Reward: -450.4832962396015, 10_Episode_Reward_Avg -288
#  Episode: 685, Episode_Reward: -387.6868428594676, 10_Episode_Reward_Avg -288
#  Episode: 686, Episode_Reward: -470.173540559021, 10_Episode_Reward_Avg -289
#  Episode: 687, Episode_Reward: -824.4216070135767, 10_Episode_Reward_Avg -292
#  Episode: 688, Episode_Reward: -426.6576609152291, 10_Episode_Reward_Avg -292
#  Episode: 689, Episode_Reward: -224.47812148073552, 10_Episode_Reward_Avg -292
#  Episode: 690, Episode_Reward: -95.51002998187978, 10_Episode_Reward_Avg -287
#  Episode: 691, Episode_Reward: -248.80833944036223, 10_Episode_Reward_Avg -286
#  Episode: 692, Episode_Reward: -356.3164486696032, 10_Episode_Reward_Avg -288
#  Episode: 693, Episode_Reward: -531.662771229215, 10_Episode_Reward_Avg -292
#  Episode: 694, Episode_Reward: -590.1335370953846, 10_Episode_Reward_Avg -296
#  Episode: 695, Episode_Reward: -387.6365346002706, 10_Episode_Reward_Avg -299
#  Episode: 696, Episode_Reward: -178.5659722966528, 10_Episode_Reward_Avg -297
#  Episode: 697, Episode_Reward: -324.65029482877236, 10_Episode_Reward_Avg -298
#  Episode: 698, Episode_Reward: 32.262393821514365, 10_Episode_Reward_Avg -297
#  Episode: 699, Episode_Reward: -374.7311313727716, 10_Episode_Reward_Avg -299
#  Episode: 700, Episode_Reward: -390.7353287146957, 10_Episode_Reward_Avg -298
#  Episode: 701, Episode_Reward: -238.43875243588099, 10_Episode_Reward_Avg -297
#  Episode: 702, Episode_Reward: -380.8054123249149, 10_Episode_Reward_Avg -299
#  Episode: 703, Episode_Reward: -104.41284491313506, 10_Episode_Reward_Avg -297
#  Episode: 704, Episode_Reward: -282.5846307881859, 10_Episode_Reward_Avg -298
#  Episode: 705, Episode_Reward: -538.1648056554204, 10_Episode_Reward_Avg -304
#  Episode: 706, Episode_Reward: -230.11917084577053, 10_Episode_Reward_Avg -304
#  Episode: 707, Episode_Reward: -334.32869690291994, 10_Episode_Reward_Avg -305
#  Episode: 708, Episode_Reward: -250.89018729647887, 10_Episode_Reward_Avg -302
#  Episode: 709, Episode_Reward: -469.26268029829305, 10_Episode_Reward_Avg -304
#  Episode: 710, Episode_Reward: -171.70165470235185, 10_Episode_Reward_Avg -303
#  Episode: 711, Episode_Reward: -265.07570697350604, 10_Episode_Reward_Avg -300
#  Episode: 712, Episode_Reward: -118.60865771136366, 10_Episode_Reward_Avg -298
#  Episode: 713, Episode_Reward: -179.79580622530582, 10_Episode_Reward_Avg -299
#  Episode: 714, Episode_Reward: -196.37525958346396, 10_Episode_Reward_Avg -299
#  Episode: 715, Episode_Reward: -173.00737387943667, 10_Episode_Reward_Avg -298
#  Episode: 716, Episode_Reward: -270.91298125619, 10_Episode_Reward_Avg -300
#  Episode: 717, Episode_Reward: -345.12410175631726, 10_Episode_Reward_Avg -301
#  Episode: 718, Episode_Reward: -232.72201162379756, 10_Episode_Reward_Avg -301
#  Episode: 719, Episode_Reward: -229.23728111735838, 10_Episode_Reward_Avg -297
#  Episode: 720, Episode_Reward: -146.4650270848053, 10_Episode_Reward_Avg -296
#  Episode: 721, Episode_Reward: -327.52066119765846, 10_Episode_Reward_Avg -293
#  Episode: 722, Episode_Reward: -242.57209267974238, 10_Episode_Reward_Avg -293
#  Episode: 723, Episode_Reward: -491.7697139241801, 10_Episode_Reward_Avg -294
#  Episode: 724, Episode_Reward: -189.3571239588587, 10_Episode_Reward_Avg -294
#  Episode: 725, Episode_Reward: -396.60588932421234, 10_Episode_Reward_Avg -295
#  Episode: 726, Episode_Reward: -380.50651168631805, 10_Episode_Reward_Avg -296
#  Episode: 727, Episode_Reward: -435.8610335903285, 10_Episode_Reward_Avg -298
#  Episode: 728, Episode_Reward: -289.9991272831162, 10_Episode_Reward_Avg -299
#  Episode: 729, Episode_Reward: -336.50156509455223, 10_Episode_Reward_Avg -300
#  Episode: 730, Episode_Reward: -207.838777150041, 10_Episode_Reward_Avg -301
#  Episode: 731, Episode_Reward: -228.81596590735967, 10_Episode_Reward_Avg -299
#  Episode: 732, Episode_Reward: -456.87260526974666, 10_Episode_Reward_Avg -302
#  Episode: 733, Episode_Reward: -151.8203644574631, 10_Episode_Reward_Avg -300
#  Episode: 734, Episode_Reward: -478.5834055619025, 10_Episode_Reward_Avg -301
#  Episode: 735, Episode_Reward: -301.61280597470204, 10_Episode_Reward_Avg -303
#  Episode: 736, Episode_Reward: -180.78623016408164, 10_Episode_Reward_Avg -299
#  Episode: 737, Episode_Reward: -16.79974699513143, 10_Episode_Reward_Avg -296
#  Episode: 738, Episode_Reward: -284.4821173341636, 10_Episode_Reward_Avg -296
#  Episode: 739, Episode_Reward: -102.00282686137912, 10_Episode_Reward_Avg -294
#  Episode: 740, Episode_Reward: -608.0118709422079, 10_Episode_Reward_Avg -297
#  Episode: 741, Episode_Reward: -355.44935697819506, 10_Episode_Reward_Avg -296
#  Episode: 742, Episode_Reward: -454.0691770680012, 10_Episode_Reward_Avg -298
#  Episode: 743, Episode_Reward: -526.0593702458789, 10_Episode_Reward_Avg -302
#  Episode: 744, Episode_Reward: -254.47140000926694, 10_Episode_Reward_Avg -300
#  Episode: 745, Episode_Reward: -5.422947937372726, 10_Episode_Reward_Avg -295
#  Episode: 746, Episode_Reward: -311.1137878723431, 10_Episode_Reward_Avg -295
#  Episode: 747, Episode_Reward: -445.1586787512226, 10_Episode_Reward_Avg -297
#  Episode: 748, Episode_Reward: -284.5078029358855, 10_Episode_Reward_Avg -297
#  Episode: 749, Episode_Reward: -334.35828090375395, 10_Episode_Reward_Avg -297
