# %%
import tensorflow as tf
import sys
import time
import os
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
import gym
import random
import tensorboard
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
#tf.compat.v1.disable_eager_execution()

# %%
def clean_tensorboard():
    import os
    tensor_board_sess_path = 'C:/Users/Eaj59/AppData/Local/Temp/.tensorboard-info/'
    temp_sess_files = os.listdir(tensor_board_sess_path)
    for i in temp_sess_files:
        temp_file_path = os.path.join(tensor_board_sess_path,i)
        os.remove(temp_file_path)

# %%
clean_tensorboard()
# %load_ext tensorboard
# %tensorboard --logdir 'C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/log_dir'
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 17448.

# %%
class Agent():
    
    def __init__(self,env_name,enable_tb_logging=False,enable_dueling=True):
        self.env = gym.make(env_name)
        self.env_state = self.env.reset()
        self.lr = 0.001
        self.gamma = .95
        self.epsilon_decay_rate = .99
        self.initializer = tf.keras.initializers.HeUniform(seed=None)
        self.loss_fn = tf.keras.losses.Huber(delta=1.0)
        self.optimizer = tf.keras.optimizers.Adam(lr=self.lr)
        self.n_actions = self.env.action_space.n
        self.n_states = self.env.observation_space.shape[0]
        self.buffer = ReplayBuffer(max_len=10000)
        self.tau = 0.10
        self.batch_size = 32
        self.epsilon = 1
        self.min_epsilon = .001
        self.dueling_method = 'max'
        self.enable_tb_logging = enable_tb_logging
        self.enable_dueling = enable_dueling
        self.episodic_rewards = 0
        self.episode_counter = 0
        self.episode_time_step_counter = 0
        

        if self.enable_dueling:
            self.online = self.make_dueling_nn()
        else:
            self.online = self.make_nn()
            
        self.target = self.make_target()
        
        if self.enable_tb_logging:
            self.online_run_id, self.online_tensor_board_callback = self.create_tensor_board_callback(model_name='Hard_Target_MAX_Dueling_DDQN_Huber')
            self.training_steps_counter = 0
        
    def reset_env(self):
        self.episode_counter+=1
        if self.enable_tb_logging:
            with self.online_tensor_board_callback.as_default():
                tf.summary.scalar(name='Episode_Reward',data=self.episodic_rewards,step=self.episode_counter)
                tf.summary.scalar(name='Episode_Time_Steps',data=self.episode_time_step_counter,step=self.episode_counter)
        self.episodic_rewards = 0
        self.episode_time_step_counter = 0
        self.env_state = self.env.reset()
        
        
    def generate_run_directory(self,root_log_dir,model_name):
        run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
        run_id = model_name+'_'+run_id
        base_dir = 'C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL'
        os.chdir('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/log_dir')
        os.mkdir(run_id)
        os.chdir(base_dir)
        return run_id
        
    
    def create_tensor_board_callback(self,model_name):
        root_log_dir = os.path.join(os.curdir,'log_dir')
        run_id = self.generate_run_directory(root_log_dir=root_log_dir,model_name=model_name)
        model_cb_path = os.path.join(root_log_dir,run_id)
        file_writer = tf.summary.create_file_writer(model_cb_path)
        return run_id, file_writer
    
        
        
    def make_nn(self):
        online = tf.keras.models.Sequential()
        online.add(tf.keras.layers.Dense(24,input_dim=self.n_states,activation='swish',kernel_initializer=self.initializer))
        online.add(tf.keras.layers.Dense(24, activation='swish',kernel_initializer=self.initializer))
        online.add(tf.keras.layers.Dense(self.n_actions,activation='linear',kernel_initializer=self.initializer))
        online.compile(loss=self.loss_fn,optimizer=self.optimizer,metrics=['accuracy'])
        return online
    
    def make_dueling_nn(self):
        Dueling_Input = tf.keras.layers.Input(shape=(self.n_states,),name='Dueling_Input')
        layer_1_Dense = tf.keras.layers.Dense(64,activation='swish',kernel_initializer=self.initializer,name='layer_1_Dense')(Dueling_Input)
        layer_2_Dense = tf.keras.layers.Dense(64,activation='swish',kernel_initializer=self.initializer,name='layer_2_Dense')(layer_1_Dense)
        layer_3_Dense = tf.keras.layers.Dense(36,activation='swish',kernel_initializer=self.initializer,name='layer_3_Dense')(layer_2_Dense)
        Value_Function_Dense_Layer = tf.keras.layers.Dense(512,activation='swish',kernel_initializer=self.initializer,name='Value_Function_Dense_Layer')(layer_3_Dense)
        Value_Function_Output_Layer = tf.keras.layers.Dense(1,activation='linear',kernel_initializer=self.initializer,name='Value_Function_Output_Layer')(Value_Function_Dense_Layer)
        Advantage_Function_Dense_Layer = tf.keras.layers.Dense(512,activation='swish',kernel_initializer=self.initializer,name='Advantage_Function_Dense_Layer')(layer_3_Dense)
        Advantage_Function_Ouput_Layer = tf.keras.layers.Dense(self.n_actions,activation='linear',kernel_initializer=self.initializer,name='Advantage_Function_Output_Layer')(Advantage_Function_Dense_Layer)
        
        if self.dueling_method == 'average':
            online_output = Value_Function_Output_Layer + (Advantage_Function_Ouput_Layer - tf.reduce_mean(Advantage_Function_Ouput_Layer,axis=1,keepdims=True))
            
            
        elif self.dueling_method == 'sum':
            online_output = Value_Function_Output_Layer + Advantage_Function_Ouput_Layer
           
            
        else:
            online_output = Value_Function_Output_Layer + (Advantage_Function_Ouput_Layer - tf.reduce_max(Advantage_Function_Ouput_Layer,axis=1,keepdims=True))
            
            
        online = tf.keras.Model(Dueling_Input,online_output)
        online.compile(loss=self.loss_fn,optimizer=self.optimizer,metrics=['accuracy'])
        online.summary()
        return online
            

    def make_target(self):
        target = tf.keras.models.clone_model(self.online)
        target.set_weights(self.online.get_weights())
        return target
        
        
    def epsilon_greedy_policy(self):
        if np.random.random() <= self.epsilon:
            return np.random.randint(low=0,high=self.n_actions)
        else:
            Q_values = self.online.predict(np.reshape(self.env_state,(1,len(self.env_state))))
            return np.argmax(Q_values[0])
        
        
        
    def play_one_step(self):
        state = np.array(self.env_state)
        action = self.epsilon_greedy_policy()
        next_state, reward, done, _ = self.env.step(action)
        self.buffer.add_exp(state=state, action=action, reward=reward, next_state=next_state, done=done)
        self.env_state = next_state
        self.episodic_rewards += reward
        self.episode_time_step_counter +=1
        return state, action, reward, next_state, done
        
        
    def soft_target_update(self):
        target_weights_current = self.target.get_weights()
        online_weights_current = self.online.get_weights()
        layer_counter = 0
        for tw, ow in zip(target_weights_current,online_weights_current):
            new_target_weights = (1-self.tau)*tw + (self.tau)*ow
            target_weights_current[layer_counter] = new_target_weights
            layer_counter += 1
        self.target.set_weights(target_weights_current)
        
        
    def training_step(self):
        
        if len(self.buffer)<self.batch_size:
            batch_size_instance = len(self.buffer)
        else:
            batch_size_instance = self.batch_size
            
        states,actions,rewards,next_states,dones = self.buffer.exp_sample(batch_size=batch_size_instance)
        online_state_prediction = self.online.predict(states)
        online_next_state_arg_max = tf.math.argmax(self.online.predict(next_states),axis=1)
        online_arg_max_mask = tf.one_hot(online_next_state_arg_max,depth=self.n_actions)
        target_next_state_preds = self.target.predict(next_states)
        max_target_next_state_preds = tf.reduce_sum(target_next_state_preds*online_arg_max_mask,axis=1,keepdims=True)
        q_update = rewards + (1 - dones) * self.gamma * max_target_next_state_preds
        actual_actions_mask = tf.one_hot(actions,depth=self.n_actions)
        inverse_actions_mask = tf.reverse(actual_actions_mask,axis=[-1])
        online_state_prediction = (q_update*actual_actions_mask)+(online_state_prediction*inverse_actions_mask)

        if self.enable_tb_logging:
            metrics_output = self.online.train_on_batch(states,online_state_prediction,reset_metrics=True)
            self.training_steps_counter+=1
            with self.online_tensor_board_callback.as_default():
                tf.summary.scalar(name='Batch_MSE_Loss',data=metrics_output[0],step=self.training_steps_counter)
                tf.summary.scalar(name='Accuracy',data=metrics_output[1],step=self.training_steps_counter)
                tf.summary.scalar(name='Epsilon',data=self.epsilon,step=self.training_steps_counter)
        else:
            self.online.train_on_batch(states,online_state_prediction)
        
        
        
            

    def apply_epsilon_decay(self):
        self.epsilon = max(self.epsilon * self.epsilon_decay_rate,self.min_epsilon)
        
            
    def hard_target_update(self):
        self.target.set_weights(self.online.get_weights())

# %%
class ReplayBuffer():
    
    def __init__(self,max_len):
        self.max_len = max_len
        self.buffer = deque(maxlen=self.max_len)
        
    
    def add_exp(self,state,action,reward,next_state,done):
        exp = (state,action,reward, next_state, done)
        if len(self.buffer)<= self.max_len:
            self.buffer.append(exp)
        else:
            self.buffer[0] = exp
        
    def __len__(self):
        return len(self.buffer)
    
    def exp_sample(self,batch_size):
        indices = np.random.randint(len(self.buffer), size=batch_size)
        batch = [self.buffer[index] for index in indices]
        states, actions, rewards, next_states, dones = [np.array([experience[entry] for experience in batch])for entry in range(5)]
        return states, actions, rewards[:,np.newaxis], next_states, dones[:,np.newaxis]

# %%
my_agent = Agent('LunarLander-v2',enable_tb_logging=True,enable_dueling=True)
rewards_buffer = []
max_episodes = 750
mean_score_buffer = deque(maxlen=100)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Dueling_Input (InputLayer)      [(None, 8)]          0
# __________________________________________________________________________________________________
# layer_1_Dense (Dense)           (None, 64)           576         Dueling_Input[0][0]
# __________________________________________________________________________________________________
# layer_2_Dense (Dense)           (None, 64)           4160        layer_1_Dense[0][0]
# __________________________________________________________________________________________________
# layer_3_Dense (Dense)           (None, 36)           2340        layer_2_Dense[0][0]
# __________________________________________________________________________________________________
# Advantage_Function_Dense_Layer  (None, 512)          18944       layer_3_Dense[0][0]
# __________________________________________________________________________________________________
# Advantage_Function_Output_Layer (None, 4)            2052        Advantage_Function_Dense_Layer[0]
# __________________________________________________________________________________________________
# Value_Function_Dense_Layer (Den (None, 512)          18944       layer_3_Dense[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) (None, 1)            0           Advantage_Function_Output_Layer[0
# __________________________________________________________________________________________________
# Value_Function_Output_Layer (De (None, 1)            513         Value_Function_Dense_Layer[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 4)            0           Advantage_Function_Output_Layer[0
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 4)            0           Value_Function_Output_Layer[0][0]
#                                                                  tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 47,529
# Trainable params: 47,529
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
for i in range(0,max_episodes):
    my_agent.reset_env()
    done = False
    rewards_episodic = 0
    while not(done):
        state, action, reward, next_state, done = my_agent.play_one_step()
        reward = reward if not done else -100
        rewards_episodic += reward
        #my_agent.buffer.add_exp(state, action, reward, next_state, done)
        my_agent.training_step()
        
        
    
    my_agent.apply_epsilon_decay()
    my_agent.hard_target_update()
    
    rewards_buffer.append(rewards_episodic)
    mean_score = round(np.mean(rewards_buffer))
    mean_score_buffer.append(rewards_episodic)
    recent_mean = round(np.mean(list(mean_score_buffer)))
    print("\r Episode: {}, Episode_Reward: {}, 10_Episode_Reward_Avg {}".format(i, round(rewards_episodic), recent_mean, end=""))
    
    '''if i == 500:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_500')
        
    if i == 1000:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_1000')
        
    if i == 1500:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_1500')
        
    if i == 2000:
        my_agent.online.save('C:/Users/Eaj59/Documents/RL_Projects/Project_2_DRL/Dueling_DDQN_Episode_2000')'''
        
        
    if recent_mean >= 200.0:
        print('DQN solved problem terminating...')
        break
# Out:
#  Episode: 0, Episode_Reward: -113, 10_Episode_Reward_Avg -113
#  Episode: 1, Episode_Reward: -95, 10_Episode_Reward_Avg -104
#  Episode: 2, Episode_Reward: -395, 10_Episode_Reward_Avg -201
#  Episode: 3, Episode_Reward: -214, 10_Episode_Reward_Avg -204
#  Episode: 4, Episode_Reward: -122, 10_Episode_Reward_Avg -188
#  Episode: 5, Episode_Reward: -162, 10_Episode_Reward_Avg -184
#  Episode: 6, Episode_Reward: -466, 10_Episode_Reward_Avg -224
#  Episode: 7, Episode_Reward: -57, 10_Episode_Reward_Avg -203
#  Episode: 8, Episode_Reward: -99, 10_Episode_Reward_Avg -192
#  Episode: 9, Episode_Reward: -88, 10_Episode_Reward_Avg -181
#  Episode: 10, Episode_Reward: -85, 10_Episode_Reward_Avg -172
#  Episode: 11, Episode_Reward: -418, 10_Episode_Reward_Avg -193
#  Episode: 12, Episode_Reward: -32, 10_Episode_Reward_Avg -181
#  Episode: 13, Episode_Reward: -267, 10_Episode_Reward_Avg -187
#  Episode: 14, Episode_Reward: -281, 10_Episode_Reward_Avg -193
#  Episode: 15, Episode_Reward: -207, 10_Episode_Reward_Avg -194
#  Episode: 16, Episode_Reward: -134, 10_Episode_Reward_Avg -190
#  Episode: 17, Episode_Reward: -198, 10_Episode_Reward_Avg -191
#  Episode: 18, Episode_Reward: -125, 10_Episode_Reward_Avg -187
#  Episode: 19, Episode_Reward: -111, 10_Episode_Reward_Avg -183
#  Episode: 20, Episode_Reward: -169, 10_Episode_Reward_Avg -183
#  Episode: 21, Episode_Reward: -120, 10_Episode_Reward_Avg -180
#  Episode: 22, Episode_Reward: -186, 10_Episode_Reward_Avg -180
#  Episode: 23, Episode_Reward: -68, 10_Episode_Reward_Avg -175
#  Episode: 24, Episode_Reward: -181, 10_Episode_Reward_Avg -176
#  Episode: 25, Episode_Reward: -127, 10_Episode_Reward_Avg -174
#  Episode: 26, Episode_Reward: -187, 10_Episode_Reward_Avg -174
#  Episode: 27, Episode_Reward: -142, 10_Episode_Reward_Avg -173
#  Episode: 28, Episode_Reward: -119, 10_Episode_Reward_Avg -171
#  Episode: 29, Episode_Reward: -280, 10_Episode_Reward_Avg -175
#  Episode: 30, Episode_Reward: -154, 10_Episode_Reward_Avg -174
#  Episode: 31, Episode_Reward: -110, 10_Episode_Reward_Avg -172
#  Episode: 32, Episode_Reward: -406, 10_Episode_Reward_Avg -179
#  Episode: 33, Episode_Reward: -163, 10_Episode_Reward_Avg -179
#  Episode: 34, Episode_Reward: -136, 10_Episode_Reward_Avg -178
#  Episode: 35, Episode_Reward: -54, 10_Episode_Reward_Avg -174
#  Episode: 36, Episode_Reward: -122, 10_Episode_Reward_Avg -173
#  Episode: 37, Episode_Reward: -167, 10_Episode_Reward_Avg -173
#  Episode: 38, Episode_Reward: -45, 10_Episode_Reward_Avg -169
#  Episode: 39, Episode_Reward: -142, 10_Episode_Reward_Avg -169
#  Episode: 40, Episode_Reward: -67, 10_Episode_Reward_Avg -166
#  Episode: 41, Episode_Reward: -48, 10_Episode_Reward_Avg -163
#  Episode: 42, Episode_Reward: -136, 10_Episode_Reward_Avg -163
#  Episode: 43, Episode_Reward: -321, 10_Episode_Reward_Avg -166
#  Episode: 44, Episode_Reward: -210, 10_Episode_Reward_Avg -167
#  Episode: 45, Episode_Reward: -66, 10_Episode_Reward_Avg -165
#  Episode: 46, Episode_Reward: 16, 10_Episode_Reward_Avg -161
#  Episode: 47, Episode_Reward: -268, 10_Episode_Reward_Avg -163
#  Episode: 48, Episode_Reward: -41, 10_Episode_Reward_Avg -161
#  Episode: 49, Episode_Reward: -39, 10_Episode_Reward_Avg -159
#  Episode: 50, Episode_Reward: -147, 10_Episode_Reward_Avg -158
#  Episode: 51, Episode_Reward: -6, 10_Episode_Reward_Avg -155
#  Episode: 52, Episode_Reward: -227, 10_Episode_Reward_Avg -157
#  Episode: 53, Episode_Reward: -134, 10_Episode_Reward_Avg -156
#  Episode: 54, Episode_Reward: -60, 10_Episode_Reward_Avg -155
#  Episode: 55, Episode_Reward: -314, 10_Episode_Reward_Avg -157
#  Episode: 56, Episode_Reward: -15, 10_Episode_Reward_Avg -155
#  Episode: 57, Episode_Reward: -36, 10_Episode_Reward_Avg -153
#  Episode: 58, Episode_Reward: -251, 10_Episode_Reward_Avg -155
#  Episode: 59, Episode_Reward: -94, 10_Episode_Reward_Avg -154
#  Episode: 60, Episode_Reward: -361, 10_Episode_Reward_Avg -157
#  Episode: 61, Episode_Reward: -55, 10_Episode_Reward_Avg -155
#  Episode: 62, Episode_Reward: -630, 10_Episode_Reward_Avg -163
#  Episode: 63, Episode_Reward: -59, 10_Episode_Reward_Avg -161
#  Episode: 64, Episode_Reward: -258, 10_Episode_Reward_Avg -163
#  Episode: 65, Episode_Reward: -391, 10_Episode_Reward_Avg -166
#  Episode: 66, Episode_Reward: -58, 10_Episode_Reward_Avg -165
#  Episode: 67, Episode_Reward: -122, 10_Episode_Reward_Avg -164
#  Episode: 68, Episode_Reward: -106, 10_Episode_Reward_Avg -163
#  Episode: 69, Episode_Reward: -321, 10_Episode_Reward_Avg -165
#  Episode: 70, Episode_Reward: -123, 10_Episode_Reward_Avg -165
#  Episode: 71, Episode_Reward: -75, 10_Episode_Reward_Avg -164
#  Episode: 72, Episode_Reward: -369, 10_Episode_Reward_Avg -166
#  Episode: 73, Episode_Reward: -357, 10_Episode_Reward_Avg -169
#  Episode: 74, Episode_Reward: -334, 10_Episode_Reward_Avg -171
#  Episode: 75, Episode_Reward: -80, 10_Episode_Reward_Avg -170
#  Episode: 76, Episode_Reward: -337, 10_Episode_Reward_Avg -172
#  Episode: 77, Episode_Reward: -219, 10_Episode_Reward_Avg -173
#  Episode: 78, Episode_Reward: -250, 10_Episode_Reward_Avg -174
#  Episode: 79, Episode_Reward: -400, 10_Episode_Reward_Avg -176
#  Episode: 80, Episode_Reward: -158, 10_Episode_Reward_Avg -176
#  Episode: 81, Episode_Reward: -423, 10_Episode_Reward_Avg -179
#  Episode: 82, Episode_Reward: -282, 10_Episode_Reward_Avg -181
#  Episode: 83, Episode_Reward: -381, 10_Episode_Reward_Avg -183
#  Episode: 84, Episode_Reward: -227, 10_Episode_Reward_Avg -183
#  Episode: 85, Episode_Reward: -345, 10_Episode_Reward_Avg -185
#  Episode: 86, Episode_Reward: -551, 10_Episode_Reward_Avg -189
#  Episode: 87, Episode_Reward: -91, 10_Episode_Reward_Avg -188
#  Episode: 88, Episode_Reward: -361, 10_Episode_Reward_Avg -190
#  Episode: 89, Episode_Reward: -140, 10_Episode_Reward_Avg -190
#  Episode: 90, Episode_Reward: -174, 10_Episode_Reward_Avg -190
#  Episode: 91, Episode_Reward: -84, 10_Episode_Reward_Avg -188
#  Episode: 92, Episode_Reward: -174, 10_Episode_Reward_Avg -188
#  Episode: 93, Episode_Reward: -48, 10_Episode_Reward_Avg -187
#  Episode: 94, Episode_Reward: -201, 10_Episode_Reward_Avg -187
#  Episode: 95, Episode_Reward: -53, 10_Episode_Reward_Avg -186
#  Episode: 96, Episode_Reward: -144, 10_Episode_Reward_Avg -185
#  Episode: 97, Episode_Reward: -201, 10_Episode_Reward_Avg -185
#  Episode: 98, Episode_Reward: -465, 10_Episode_Reward_Avg -188
#  Episode: 99, Episode_Reward: -313, 10_Episode_Reward_Avg -189
#  Episode: 100, Episode_Reward: -469, 10_Episode_Reward_Avg -193
#  Episode: 101, Episode_Reward: -160, 10_Episode_Reward_Avg -194
#  Episode: 102, Episode_Reward: -225, 10_Episode_Reward_Avg -192
#  Episode: 103, Episode_Reward: -202, 10_Episode_Reward_Avg -192
#  Episode: 104, Episode_Reward: -405, 10_Episode_Reward_Avg -195
#  Episode: 105, Episode_Reward: -323, 10_Episode_Reward_Avg -196
#  Episode: 106, Episode_Reward: -121, 10_Episode_Reward_Avg -193
#  Episode: 107, Episode_Reward: -116, 10_Episode_Reward_Avg -193
#  Episode: 108, Episode_Reward: -342, 10_Episode_Reward_Avg -196
#  Episode: 109, Episode_Reward: -195, 10_Episode_Reward_Avg -197
#  Episode: 110, Episode_Reward: -246, 10_Episode_Reward_Avg -198
#  Episode: 111, Episode_Reward: -478, 10_Episode_Reward_Avg -199
#  Episode: 112, Episode_Reward: -86, 10_Episode_Reward_Avg -200
#  Episode: 113, Episode_Reward: -414, 10_Episode_Reward_Avg -201
#  Episode: 114, Episode_Reward: -359, 10_Episode_Reward_Avg -202
#  Episode: 115, Episode_Reward: -155, 10_Episode_Reward_Avg -201
#  Episode: 116, Episode_Reward: -41, 10_Episode_Reward_Avg -200
#  Episode: 117, Episode_Reward: -148, 10_Episode_Reward_Avg -200
#  Episode: 118, Episode_Reward: -350, 10_Episode_Reward_Avg -202
#  Episode: 119, Episode_Reward: -151, 10_Episode_Reward_Avg -203
#  Episode: 120, Episode_Reward: -401, 10_Episode_Reward_Avg -205
#  Episode: 121, Episode_Reward: -267, 10_Episode_Reward_Avg -206
#  Episode: 122, Episode_Reward: -405, 10_Episode_Reward_Avg -209
#  Episode: 123, Episode_Reward: -200, 10_Episode_Reward_Avg -210
#  Episode: 124, Episode_Reward: -332, 10_Episode_Reward_Avg -211
#  Episode: 125, Episode_Reward: -393, 10_Episode_Reward_Avg -214
#  Episode: 126, Episode_Reward: -249, 10_Episode_Reward_Avg -215
#  Episode: 127, Episode_Reward: -126, 10_Episode_Reward_Avg -214
#  Episode: 128, Episode_Reward: -112, 10_Episode_Reward_Avg -214
#  Episode: 129, Episode_Reward: -372, 10_Episode_Reward_Avg -215
#  Episode: 130, Episode_Reward: -227, 10_Episode_Reward_Avg -216
#  Episode: 131, Episode_Reward: -407, 10_Episode_Reward_Avg -219
#  Episode: 132, Episode_Reward: -131, 10_Episode_Reward_Avg -216
#  Episode: 133, Episode_Reward: -366, 10_Episode_Reward_Avg -218
#  Episode: 134, Episode_Reward: -109, 10_Episode_Reward_Avg -218
#  Episode: 135, Episode_Reward: -192, 10_Episode_Reward_Avg -219
#  Episode: 136, Episode_Reward: -318, 10_Episode_Reward_Avg -221
#  Episode: 137, Episode_Reward: -351, 10_Episode_Reward_Avg -223
#  Episode: 138, Episode_Reward: -465, 10_Episode_Reward_Avg -227
#  Episode: 139, Episode_Reward: -554, 10_Episode_Reward_Avg -232
#  Episode: 140, Episode_Reward: -279, 10_Episode_Reward_Avg -234
#  Episode: 141, Episode_Reward: -91, 10_Episode_Reward_Avg -234
#  Episode: 142, Episode_Reward: -283, 10_Episode_Reward_Avg -236
#  Episode: 143, Episode_Reward: -229, 10_Episode_Reward_Avg -235
#  Episode: 144, Episode_Reward: -152, 10_Episode_Reward_Avg -234
#  Episode: 145, Episode_Reward: -381, 10_Episode_Reward_Avg -237
#  Episode: 146, Episode_Reward: -264, 10_Episode_Reward_Avg -240
#  Episode: 147, Episode_Reward: -123, 10_Episode_Reward_Avg -239
#  Episode: 148, Episode_Reward: -102, 10_Episode_Reward_Avg -239
#  Episode: 149, Episode_Reward: -206, 10_Episode_Reward_Avg -241
#  Episode: 150, Episode_Reward: -312, 10_Episode_Reward_Avg -242
#  Episode: 151, Episode_Reward: -200, 10_Episode_Reward_Avg -244
#  Episode: 152, Episode_Reward: -394, 10_Episode_Reward_Avg -246
#  Episode: 153, Episode_Reward: -292, 10_Episode_Reward_Avg -248
#  Episode: 154, Episode_Reward: -443, 10_Episode_Reward_Avg -251
#  Episode: 155, Episode_Reward: -334, 10_Episode_Reward_Avg -252
#  Episode: 156, Episode_Reward: -281, 10_Episode_Reward_Avg -254
#  Episode: 157, Episode_Reward: -104, 10_Episode_Reward_Avg -255
#  Episode: 158, Episode_Reward: -251, 10_Episode_Reward_Avg -255
#  Episode: 159, Episode_Reward: -332, 10_Episode_Reward_Avg -257
#  Episode: 160, Episode_Reward: -291, 10_Episode_Reward_Avg -257
#  Episode: 161, Episode_Reward: -589, 10_Episode_Reward_Avg -262
#  Episode: 162, Episode_Reward: -146, 10_Episode_Reward_Avg -257
#  Episode: 163, Episode_Reward: -122, 10_Episode_Reward_Avg -258
#  Episode: 164, Episode_Reward: -172, 10_Episode_Reward_Avg -257
#  Episode: 165, Episode_Reward: -330, 10_Episode_Reward_Avg -256
#  Episode: 166, Episode_Reward: -569, 10_Episode_Reward_Avg -262
#  Episode: 167, Episode_Reward: -134, 10_Episode_Reward_Avg -262
#  Episode: 168, Episode_Reward: -270, 10_Episode_Reward_Avg -263
#  Episode: 169, Episode_Reward: -458, 10_Episode_Reward_Avg -265
#  Episode: 170, Episode_Reward: -220, 10_Episode_Reward_Avg -266
#  Episode: 171, Episode_Reward: -150, 10_Episode_Reward_Avg -266
#  Episode: 172, Episode_Reward: -234, 10_Episode_Reward_Avg -265
#  Episode: 173, Episode_Reward: -348, 10_Episode_Reward_Avg -265
#  Episode: 174, Episode_Reward: -285, 10_Episode_Reward_Avg -264
#  Episode: 175, Episode_Reward: -127, 10_Episode_Reward_Avg -265
#  Episode: 176, Episode_Reward: -318, 10_Episode_Reward_Avg -265
#  Episode: 177, Episode_Reward: -367, 10_Episode_Reward_Avg -266
#  Episode: 178, Episode_Reward: -406, 10_Episode_Reward_Avg -268
#  Episode: 179, Episode_Reward: -418, 10_Episode_Reward_Avg -268
#  Episode: 180, Episode_Reward: -188, 10_Episode_Reward_Avg -268
#  Episode: 181, Episode_Reward: -252, 10_Episode_Reward_Avg -266
#  Episode: 182, Episode_Reward: -424, 10_Episode_Reward_Avg -268
#  Episode: 183, Episode_Reward: -456, 10_Episode_Reward_Avg -269
#  Episode: 184, Episode_Reward: -143, 10_Episode_Reward_Avg -268
#  Episode: 185, Episode_Reward: -417, 10_Episode_Reward_Avg -269
#  Episode: 186, Episode_Reward: -158, 10_Episode_Reward_Avg -265
#  Episode: 187, Episode_Reward: -19, 10_Episode_Reward_Avg -264
#  Episode: 188, Episode_Reward: -382, 10_Episode_Reward_Avg -264
#  Episode: 189, Episode_Reward: -150, 10_Episode_Reward_Avg -264
#  Episode: 190, Episode_Reward: -160, 10_Episode_Reward_Avg -264
#  Episode: 191, Episode_Reward: -288, 10_Episode_Reward_Avg -266
#  Episode: 192, Episode_Reward: -140, 10_Episode_Reward_Avg -266
#  Episode: 193, Episode_Reward: -460, 10_Episode_Reward_Avg -270
#  Episode: 194, Episode_Reward: -178, 10_Episode_Reward_Avg -270
#  Episode: 195, Episode_Reward: -134, 10_Episode_Reward_Avg -270
#  Episode: 196, Episode_Reward: -444, 10_Episode_Reward_Avg -273
#  Episode: 197, Episode_Reward: -404, 10_Episode_Reward_Avg -276
#  Episode: 198, Episode_Reward: -226, 10_Episode_Reward_Avg -273
#  Episode: 199, Episode_Reward: -187, 10_Episode_Reward_Avg -272
#  Episode: 200, Episode_Reward: -198, 10_Episode_Reward_Avg -269
#  Episode: 201, Episode_Reward: -175, 10_Episode_Reward_Avg -269
#  Episode: 202, Episode_Reward: -463, 10_Episode_Reward_Avg -272
#  Episode: 203, Episode_Reward: -329, 10_Episode_Reward_Avg -273
#  Episode: 204, Episode_Reward: -269, 10_Episode_Reward_Avg -272
#  Episode: 205, Episode_Reward: -226, 10_Episode_Reward_Avg -271
#  Episode: 206, Episode_Reward: -435, 10_Episode_Reward_Avg -274
#  Episode: 207, Episode_Reward: -66, 10_Episode_Reward_Avg -273
#  Episode: 208, Episode_Reward: -178, 10_Episode_Reward_Avg -272
#  Episode: 209, Episode_Reward: -463, 10_Episode_Reward_Avg -274
#  Episode: 210, Episode_Reward: -278, 10_Episode_Reward_Avg -275
#  Episode: 211, Episode_Reward: -299, 10_Episode_Reward_Avg -273
#  Episode: 212, Episode_Reward: -169, 10_Episode_Reward_Avg -274
#  Episode: 213, Episode_Reward: -290, 10_Episode_Reward_Avg -272
#  Episode: 214, Episode_Reward: -78, 10_Episode_Reward_Avg -270
#  Episode: 215, Episode_Reward: -366, 10_Episode_Reward_Avg -272
#  Episode: 216, Episode_Reward: -443, 10_Episode_Reward_Avg -276
#  Episode: 217, Episode_Reward: -369, 10_Episode_Reward_Avg -278
#  Episode: 218, Episode_Reward: -355, 10_Episode_Reward_Avg -278
#  Episode: 219, Episode_Reward: -252, 10_Episode_Reward_Avg -279
#  Episode: 220, Episode_Reward: -212, 10_Episode_Reward_Avg -277
#  Episode: 221, Episode_Reward: -388, 10_Episode_Reward_Avg -278
#  Episode: 222, Episode_Reward: -419, 10_Episode_Reward_Avg -278
#  Episode: 223, Episode_Reward: -447, 10_Episode_Reward_Avg -281
#  Episode: 224, Episode_Reward: -311, 10_Episode_Reward_Avg -281
#  Episode: 225, Episode_Reward: -393, 10_Episode_Reward_Avg -281
#  Episode: 226, Episode_Reward: 4, 10_Episode_Reward_Avg -278
#  Episode: 227, Episode_Reward: -348, 10_Episode_Reward_Avg -280
#  Episode: 228, Episode_Reward: -308, 10_Episode_Reward_Avg -282
#  Episode: 229, Episode_Reward: -250, 10_Episode_Reward_Avg -281
#  Episode: 230, Episode_Reward: -149, 10_Episode_Reward_Avg -280
#  Episode: 231, Episode_Reward: -613, 10_Episode_Reward_Avg -282
#  Episode: 232, Episode_Reward: -174, 10_Episode_Reward_Avg -283
#  Episode: 233, Episode_Reward: -416, 10_Episode_Reward_Avg -283
#  Episode: 234, Episode_Reward: -257, 10_Episode_Reward_Avg -285
#  Episode: 235, Episode_Reward: -137, 10_Episode_Reward_Avg -284
#  Episode: 236, Episode_Reward: -559, 10_Episode_Reward_Avg -287
#  Episode: 237, Episode_Reward: -312, 10_Episode_Reward_Avg -286
#  Episode: 238, Episode_Reward: -28, 10_Episode_Reward_Avg -282
#  Episode: 239, Episode_Reward: -304, 10_Episode_Reward_Avg -279
#  Episode: 240, Episode_Reward: -312, 10_Episode_Reward_Avg -280
#  Episode: 241, Episode_Reward: -319, 10_Episode_Reward_Avg -282
#  Episode: 242, Episode_Reward: -321, 10_Episode_Reward_Avg -282
#  Episode: 243, Episode_Reward: -175, 10_Episode_Reward_Avg -282
#  Episode: 244, Episode_Reward: -101, 10_Episode_Reward_Avg -281
#  Episode: 245, Episode_Reward: -496, 10_Episode_Reward_Avg -282
#  Episode: 246, Episode_Reward: -165, 10_Episode_Reward_Avg -282
#  Episode: 247, Episode_Reward: -376, 10_Episode_Reward_Avg -284
#  Episode: 248, Episode_Reward: -342, 10_Episode_Reward_Avg -286
#  Episode: 249, Episode_Reward: -93, 10_Episode_Reward_Avg -285
#  Episode: 250, Episode_Reward: -12, 10_Episode_Reward_Avg -282
#  Episode: 251, Episode_Reward: -261, 10_Episode_Reward_Avg -283
#  Episode: 252, Episode_Reward: -302, 10_Episode_Reward_Avg -282
#  Episode: 253, Episode_Reward: -307, 10_Episode_Reward_Avg -282
#  Episode: 254, Episode_Reward: -339, 10_Episode_Reward_Avg -281
#  Episode: 255, Episode_Reward: -60, 10_Episode_Reward_Avg -278
#  Episode: 256, Episode_Reward: -401, 10_Episode_Reward_Avg -280
#  Episode: 257, Episode_Reward: -356, 10_Episode_Reward_Avg -282
#  Episode: 258, Episode_Reward: -269, 10_Episode_Reward_Avg -282
#  Episode: 259, Episode_Reward: -535, 10_Episode_Reward_Avg -284
#  Episode: 260, Episode_Reward: -224, 10_Episode_Reward_Avg -284
#  Episode: 261, Episode_Reward: -208, 10_Episode_Reward_Avg -280
#  Episode: 262, Episode_Reward: -88, 10_Episode_Reward_Avg -279
#  Episode: 263, Episode_Reward: -190, 10_Episode_Reward_Avg -280
#  Episode: 264, Episode_Reward: -326, 10_Episode_Reward_Avg -281
#  Episode: 265, Episode_Reward: -274, 10_Episode_Reward_Avg -281
#  Episode: 266, Episode_Reward: -96, 10_Episode_Reward_Avg -276
#  Episode: 267, Episode_Reward: -172, 10_Episode_Reward_Avg -277
#  Episode: 268, Episode_Reward: -155, 10_Episode_Reward_Avg -275
#  Episode: 269, Episode_Reward: -69, 10_Episode_Reward_Avg -271
#  Episode: 270, Episode_Reward: -261, 10_Episode_Reward_Avg -272
#  Episode: 271, Episode_Reward: -339, 10_Episode_Reward_Avg -274
#  Episode: 272, Episode_Reward: -447, 10_Episode_Reward_Avg -276
#  Episode: 273, Episode_Reward: -141, 10_Episode_Reward_Avg -274
#  Episode: 274, Episode_Reward: -188, 10_Episode_Reward_Avg -273
#  Episode: 275, Episode_Reward: -300, 10_Episode_Reward_Avg -275
#  Episode: 276, Episode_Reward: -426, 10_Episode_Reward_Avg -276
#  Episode: 277, Episode_Reward: -206, 10_Episode_Reward_Avg -274
#  Episode: 278, Episode_Reward: -466, 10_Episode_Reward_Avg -275
#  Episode: 279, Episode_Reward: -30, 10_Episode_Reward_Avg -271
#  Episode: 280, Episode_Reward: -498, 10_Episode_Reward_Avg -274
#  Episode: 281, Episode_Reward: -332, 10_Episode_Reward_Avg -275
#  Episode: 282, Episode_Reward: -434, 10_Episode_Reward_Avg -275
#  Episode: 283, Episode_Reward: -155, 10_Episode_Reward_Avg -272
#  Episode: 284, Episode_Reward: -178, 10_Episode_Reward_Avg -272
#  Episode: 285, Episode_Reward: -178, 10_Episode_Reward_Avg -270
#  Episode: 286, Episode_Reward: -359, 10_Episode_Reward_Avg -272
#  Episode: 287, Episode_Reward: -244, 10_Episode_Reward_Avg -274
#  Episode: 288, Episode_Reward: -514, 10_Episode_Reward_Avg -275
#  Episode: 289, Episode_Reward: -188, 10_Episode_Reward_Avg -276
#  Episode: 290, Episode_Reward: -187, 10_Episode_Reward_Avg -276
#  Episode: 291, Episode_Reward: -149, 10_Episode_Reward_Avg -275
#  Episode: 292, Episode_Reward: -143, 10_Episode_Reward_Avg -275
#  Episode: 293, Episode_Reward: -113, 10_Episode_Reward_Avg -271
#  Episode: 294, Episode_Reward: -337, 10_Episode_Reward_Avg -273
#  Episode: 295, Episode_Reward: -221, 10_Episode_Reward_Avg -274
#  Episode: 296, Episode_Reward: -321, 10_Episode_Reward_Avg -272
#  Episode: 297, Episode_Reward: -63, 10_Episode_Reward_Avg -269
#  Episode: 298, Episode_Reward: -288, 10_Episode_Reward_Avg -270
#  Episode: 299, Episode_Reward: -456, 10_Episode_Reward_Avg -272
#  Episode: 300, Episode_Reward: -355, 10_Episode_Reward_Avg -274
#  Episode: 301, Episode_Reward: -57, 10_Episode_Reward_Avg -273
#  Episode: 302, Episode_Reward: -182, 10_Episode_Reward_Avg -270
#  Episode: 303, Episode_Reward: -226, 10_Episode_Reward_Avg -269
#  Episode: 304, Episode_Reward: -218, 10_Episode_Reward_Avg -268
#  Episode: 305, Episode_Reward: -593, 10_Episode_Reward_Avg -272
#  Episode: 306, Episode_Reward: -138, 10_Episode_Reward_Avg -269
#  Episode: 307, Episode_Reward: -548, 10_Episode_Reward_Avg -274
#  Episode: 308, Episode_Reward: -182, 10_Episode_Reward_Avg -274
#  Episode: 309, Episode_Reward: -162, 10_Episode_Reward_Avg -271
#  Episode: 310, Episode_Reward: -256, 10_Episode_Reward_Avg -271
#  Episode: 311, Episode_Reward: -395, 10_Episode_Reward_Avg -272
#  Episode: 312, Episode_Reward: -224, 10_Episode_Reward_Avg -272
#  Episode: 313, Episode_Reward: -60, 10_Episode_Reward_Avg -270
#  Episode: 314, Episode_Reward: -346, 10_Episode_Reward_Avg -273
#  Episode: 315, Episode_Reward: -266, 10_Episode_Reward_Avg -272
#  Episode: 316, Episode_Reward: -8, 10_Episode_Reward_Avg -267
#  Episode: 317, Episode_Reward: -280, 10_Episode_Reward_Avg -266
#  Episode: 318, Episode_Reward: -202, 10_Episode_Reward_Avg -265
#  Episode: 319, Episode_Reward: -315, 10_Episode_Reward_Avg -265
#  Episode: 320, Episode_Reward: -185, 10_Episode_Reward_Avg -265
#  Episode: 321, Episode_Reward: -327, 10_Episode_Reward_Avg -265
#  Episode: 322, Episode_Reward: -500, 10_Episode_Reward_Avg -265
#  Episode: 323, Episode_Reward: -214, 10_Episode_Reward_Avg -263
#  Episode: 324, Episode_Reward: -439, 10_Episode_Reward_Avg -264
#  Episode: 325, Episode_Reward: -163, 10_Episode_Reward_Avg -262
#  Episode: 326, Episode_Reward: -439, 10_Episode_Reward_Avg -266
#  Episode: 327, Episode_Reward: -268, 10_Episode_Reward_Avg -266
#  Episode: 328, Episode_Reward: -564, 10_Episode_Reward_Avg -268
#  Episode: 329, Episode_Reward: -215, 10_Episode_Reward_Avg -268
#  Episode: 330, Episode_Reward: -301, 10_Episode_Reward_Avg -269
#  Episode: 331, Episode_Reward: -161, 10_Episode_Reward_Avg -265
#  Episode: 332, Episode_Reward: -420, 10_Episode_Reward_Avg -267
#  Episode: 333, Episode_Reward: -422, 10_Episode_Reward_Avg -267
#  Episode: 334, Episode_Reward: -168, 10_Episode_Reward_Avg -266
#  Episode: 335, Episode_Reward: -519, 10_Episode_Reward_Avg -270
#  Episode: 336, Episode_Reward: -384, 10_Episode_Reward_Avg -269
#  Episode: 337, Episode_Reward: -376, 10_Episode_Reward_Avg -269
#  Episode: 338, Episode_Reward: -567, 10_Episode_Reward_Avg -275
#  Episode: 339, Episode_Reward: -251, 10_Episode_Reward_Avg -274
#  Episode: 340, Episode_Reward: -98, 10_Episode_Reward_Avg -272
#  Episode: 341, Episode_Reward: -272, 10_Episode_Reward_Avg -271
#  Episode: 342, Episode_Reward: -156, 10_Episode_Reward_Avg -270
#  Episode: 343, Episode_Reward: -125, 10_Episode_Reward_Avg -269
#  Episode: 344, Episode_Reward: -100, 10_Episode_Reward_Avg -269
#  Episode: 345, Episode_Reward: -475, 10_Episode_Reward_Avg -269
#  Episode: 346, Episode_Reward: -482, 10_Episode_Reward_Avg -272
#  Episode: 347, Episode_Reward: -176, 10_Episode_Reward_Avg -270
#  Episode: 348, Episode_Reward: -62, 10_Episode_Reward_Avg -267
#  Episode: 349, Episode_Reward: -202, 10_Episode_Reward_Avg -269
#  Episode: 350, Episode_Reward: -117, 10_Episode_Reward_Avg -270
#  Episode: 351, Episode_Reward: -491, 10_Episode_Reward_Avg -272
#  Episode: 352, Episode_Reward: -388, 10_Episode_Reward_Avg -273
#  Episode: 353, Episode_Reward: -186, 10_Episode_Reward_Avg -272
#  Episode: 354, Episode_Reward: -262, 10_Episode_Reward_Avg -271
#  Episode: 355, Episode_Reward: -274, 10_Episode_Reward_Avg -273
#  Episode: 356, Episode_Reward: -73, 10_Episode_Reward_Avg -270
#  Episode: 357, Episode_Reward: -71, 10_Episode_Reward_Avg -267
#  Episode: 358, Episode_Reward: -280, 10_Episode_Reward_Avg -267
#  Episode: 359, Episode_Reward: -451, 10_Episode_Reward_Avg -266
#  Episode: 360, Episode_Reward: -178, 10_Episode_Reward_Avg -266
#  Episode: 361, Episode_Reward: -175, 10_Episode_Reward_Avg -265
#  Episode: 362, Episode_Reward: -180, 10_Episode_Reward_Avg -266
#  Episode: 363, Episode_Reward: -356, 10_Episode_Reward_Avg -268
#  Episode: 364, Episode_Reward: -613, 10_Episode_Reward_Avg -271
#  Episode: 365, Episode_Reward: -439, 10_Episode_Reward_Avg -272
#  Episode: 366, Episode_Reward: -470, 10_Episode_Reward_Avg -276
#  Episode: 367, Episode_Reward: -228, 10_Episode_Reward_Avg -277
#  Episode: 368, Episode_Reward: -397, 10_Episode_Reward_Avg -279
#  Episode: 369, Episode_Reward: -556, 10_Episode_Reward_Avg -284
#  Episode: 370, Episode_Reward: -145, 10_Episode_Reward_Avg -283
#  Episode: 371, Episode_Reward: -214, 10_Episode_Reward_Avg -282
#  Episode: 372, Episode_Reward: -222, 10_Episode_Reward_Avg -279
#  Episode: 373, Episode_Reward: -210, 10_Episode_Reward_Avg -280
#  Episode: 374, Episode_Reward: -191, 10_Episode_Reward_Avg -280
#  Episode: 375, Episode_Reward: -327, 10_Episode_Reward_Avg -280
#  Episode: 376, Episode_Reward: -619, 10_Episode_Reward_Avg -282
#  Episode: 377, Episode_Reward: -251, 10_Episode_Reward_Avg -283
#  Episode: 378, Episode_Reward: -551, 10_Episode_Reward_Avg -283
#  Episode: 379, Episode_Reward: -327, 10_Episode_Reward_Avg -286
#  Episode: 380, Episode_Reward: -86, 10_Episode_Reward_Avg -282
#  Episode: 381, Episode_Reward: -388, 10_Episode_Reward_Avg -283
#  Episode: 382, Episode_Reward: -160, 10_Episode_Reward_Avg -280
#  Episode: 383, Episode_Reward: -208, 10_Episode_Reward_Avg -281
#  Episode: 384, Episode_Reward: -358, 10_Episode_Reward_Avg -282
#  Episode: 385, Episode_Reward: -365, 10_Episode_Reward_Avg -284
#  Episode: 386, Episode_Reward: -619, 10_Episode_Reward_Avg -287
#  Episode: 387, Episode_Reward: -130, 10_Episode_Reward_Avg -286
#  Episode: 388, Episode_Reward: -166, 10_Episode_Reward_Avg -282
#  Episode: 389, Episode_Reward: -206, 10_Episode_Reward_Avg -282
#  Episode: 390, Episode_Reward: -474, 10_Episode_Reward_Avg -285
#  Episode: 391, Episode_Reward: -467, 10_Episode_Reward_Avg -289
#  Episode: 392, Episode_Reward: -134, 10_Episode_Reward_Avg -288
#  Episode: 393, Episode_Reward: -186, 10_Episode_Reward_Avg -289
#  Episode: 394, Episode_Reward: -148, 10_Episode_Reward_Avg -287
#  Episode: 395, Episode_Reward: -227, 10_Episode_Reward_Avg -287
#  Episode: 396, Episode_Reward: -163, 10_Episode_Reward_Avg -286
#  Episode: 397, Episode_Reward: -218, 10_Episode_Reward_Avg -287
#  Episode: 398, Episode_Reward: -206, 10_Episode_Reward_Avg -287
#  Episode: 399, Episode_Reward: -147, 10_Episode_Reward_Avg -283
#  Episode: 400, Episode_Reward: -44, 10_Episode_Reward_Avg -280
#  Episode: 401, Episode_Reward: -55, 10_Episode_Reward_Avg -280
#  Episode: 402, Episode_Reward: -169, 10_Episode_Reward_Avg -280
#  Episode: 403, Episode_Reward: -303, 10_Episode_Reward_Avg -281
#  Episode: 404, Episode_Reward: -196, 10_Episode_Reward_Avg -281
#  Episode: 405, Episode_Reward: -548, 10_Episode_Reward_Avg -280
#  Episode: 406, Episode_Reward: -356, 10_Episode_Reward_Avg -282
#  Episode: 407, Episode_Reward: -152, 10_Episode_Reward_Avg -278
#  Episode: 408, Episode_Reward: -269, 10_Episode_Reward_Avg -279
#  Episode: 409, Episode_Reward: -444, 10_Episode_Reward_Avg -282
#  Episode: 410, Episode_Reward: -204, 10_Episode_Reward_Avg -282
#  Episode: 411, Episode_Reward: -566, 10_Episode_Reward_Avg -283
#  Episode: 412, Episode_Reward: -93, 10_Episode_Reward_Avg -282
#  Episode: 413, Episode_Reward: -247, 10_Episode_Reward_Avg -284
#  Episode: 414, Episode_Reward: -498, 10_Episode_Reward_Avg -285
#  Episode: 415, Episode_Reward: -552, 10_Episode_Reward_Avg -288
#  Episode: 416, Episode_Reward: -375, 10_Episode_Reward_Avg -292
#  Episode: 417, Episode_Reward: -403, 10_Episode_Reward_Avg -293
#  Episode: 418, Episode_Reward: -302, 10_Episode_Reward_Avg -294
#  Episode: 419, Episode_Reward: -486, 10_Episode_Reward_Avg -296
#  Episode: 420, Episode_Reward: -158, 10_Episode_Reward_Avg -296
#  Episode: 421, Episode_Reward: -128, 10_Episode_Reward_Avg -294
#  Episode: 422, Episode_Reward: -374, 10_Episode_Reward_Avg -292
#  Episode: 423, Episode_Reward: -226, 10_Episode_Reward_Avg -292
#  Episode: 424, Episode_Reward: -288, 10_Episode_Reward_Avg -291
#  Episode: 425, Episode_Reward: -303, 10_Episode_Reward_Avg -292
#  Episode: 426, Episode_Reward: -255, 10_Episode_Reward_Avg -291
#  Episode: 427, Episode_Reward: -418, 10_Episode_Reward_Avg -292
#  Episode: 428, Episode_Reward: -386, 10_Episode_Reward_Avg -290
#  Episode: 429, Episode_Reward: -155, 10_Episode_Reward_Avg -290
#  Episode: 430, Episode_Reward: -217, 10_Episode_Reward_Avg -289
#  Episode: 431, Episode_Reward: -199, 10_Episode_Reward_Avg -289
#  Episode: 432, Episode_Reward: -246, 10_Episode_Reward_Avg -287
#  Episode: 433, Episode_Reward: -220, 10_Episode_Reward_Avg -285
#  Episode: 434, Episode_Reward: -248, 10_Episode_Reward_Avg -286
#  Episode: 435, Episode_Reward: -141, 10_Episode_Reward_Avg -282
#  Episode: 436, Episode_Reward: -282, 10_Episode_Reward_Avg -281
#  Episode: 437, Episode_Reward: -319, 10_Episode_Reward_Avg -281
#  Episode: 438, Episode_Reward: -554, 10_Episode_Reward_Avg -281
#  Episode: 439, Episode_Reward: -85, 10_Episode_Reward_Avg -279
#  Episode: 440, Episode_Reward: -215, 10_Episode_Reward_Avg -280
#  Episode: 441, Episode_Reward: -259, 10_Episode_Reward_Avg -280
#  Episode: 442, Episode_Reward: -332, 10_Episode_Reward_Avg -282
#  Episode: 443, Episode_Reward: -220, 10_Episode_Reward_Avg -283
#  Episode: 444, Episode_Reward: -560, 10_Episode_Reward_Avg -287
#  Episode: 445, Episode_Reward: -127, 10_Episode_Reward_Avg -284
#  Episode: 446, Episode_Reward: -294, 10_Episode_Reward_Avg -282
#  Episode: 447, Episode_Reward: -565, 10_Episode_Reward_Avg -286
#  Episode: 448, Episode_Reward: -128, 10_Episode_Reward_Avg -287
#  Episode: 449, Episode_Reward: -60, 10_Episode_Reward_Avg -285
#  Episode: 450, Episode_Reward: -279, 10_Episode_Reward_Avg -287
#  Episode: 451, Episode_Reward: -178, 10_Episode_Reward_Avg -284
#  Episode: 452, Episode_Reward: -331, 10_Episode_Reward_Avg -283
#  Episode: 453, Episode_Reward: -294, 10_Episode_Reward_Avg -284
#  Episode: 454, Episode_Reward: -239, 10_Episode_Reward_Avg -284
#  Episode: 455, Episode_Reward: -80, 10_Episode_Reward_Avg -282
#  Episode: 456, Episode_Reward: -289, 10_Episode_Reward_Avg -284
#  Episode: 457, Episode_Reward: -125, 10_Episode_Reward_Avg -285
#  Episode: 458, Episode_Reward: -132, 10_Episode_Reward_Avg -283
#  Episode: 459, Episode_Reward: -175, 10_Episode_Reward_Avg -280
#  Episode: 460, Episode_Reward: -52, 10_Episode_Reward_Avg -279
#  Episode: 461, Episode_Reward: -454, 10_Episode_Reward_Avg -282
#  Episode: 462, Episode_Reward: -202, 10_Episode_Reward_Avg -282
#  Episode: 463, Episode_Reward: -71, 10_Episode_Reward_Avg -279
#  Episode: 464, Episode_Reward: -76, 10_Episode_Reward_Avg -274
#  Episode: 465, Episode_Reward: -381, 10_Episode_Reward_Avg -273
#  Episode: 466, Episode_Reward: -491, 10_Episode_Reward_Avg -274
#  Episode: 467, Episode_Reward: -74, 10_Episode_Reward_Avg -272
#  Episode: 468, Episode_Reward: -48, 10_Episode_Reward_Avg -269
#  Episode: 469, Episode_Reward: -381, 10_Episode_Reward_Avg -267
#  Episode: 470, Episode_Reward: -242, 10_Episode_Reward_Avg -268
#  Episode: 471, Episode_Reward: 56, 10_Episode_Reward_Avg -265
#  Episode: 472, Episode_Reward: -589, 10_Episode_Reward_Avg -269
#  Episode: 473, Episode_Reward: -642, 10_Episode_Reward_Avg -273
#  Episode: 474, Episode_Reward: -571, 10_Episode_Reward_Avg -277
#  Episode: 475, Episode_Reward: -320, 10_Episode_Reward_Avg -277
#  Episode: 476, Episode_Reward: -489, 10_Episode_Reward_Avg -276
#  Episode: 477, Episode_Reward: -326, 10_Episode_Reward_Avg -276
#  Episode: 478, Episode_Reward: -264, 10_Episode_Reward_Avg -273
#  Episode: 479, Episode_Reward: -247, 10_Episode_Reward_Avg -273
#  Episode: 480, Episode_Reward: -127, 10_Episode_Reward_Avg -273
#  Episode: 481, Episode_Reward: -240, 10_Episode_Reward_Avg -272
#  Episode: 482, Episode_Reward: -256, 10_Episode_Reward_Avg -273
#  Episode: 483, Episode_Reward: -69, 10_Episode_Reward_Avg -271
#  Episode: 484, Episode_Reward: -401, 10_Episode_Reward_Avg -272
#  Episode: 485, Episode_Reward: -160, 10_Episode_Reward_Avg -269
#  Episode: 486, Episode_Reward: -354, 10_Episode_Reward_Avg -267
#  Episode: 487, Episode_Reward: -532, 10_Episode_Reward_Avg -271
#  Episode: 488, Episode_Reward: -208, 10_Episode_Reward_Avg -271
#  Episode: 489, Episode_Reward: -271, 10_Episode_Reward_Avg -272
#  Episode: 490, Episode_Reward: -171, 10_Episode_Reward_Avg -269
#  Episode: 491, Episode_Reward: -240, 10_Episode_Reward_Avg -267
#  Episode: 492, Episode_Reward: -298, 10_Episode_Reward_Avg -268
#  Episode: 493, Episode_Reward: -187, 10_Episode_Reward_Avg -268
#  Episode: 494, Episode_Reward: -219, 10_Episode_Reward_Avg -269
#  Episode: 495, Episode_Reward: -314, 10_Episode_Reward_Avg -270
#  Episode: 496, Episode_Reward: -384, 10_Episode_Reward_Avg -272
#  Episode: 497, Episode_Reward: -53, 10_Episode_Reward_Avg -270
#  Episode: 498, Episode_Reward: -139, 10_Episode_Reward_Avg -270
#  Episode: 499, Episode_Reward: -239, 10_Episode_Reward_Avg -271
#  Episode: 500, Episode_Reward: -306, 10_Episode_Reward_Avg -273
#  Episode: 501, Episode_Reward: -226, 10_Episode_Reward_Avg -275
#  Episode: 502, Episode_Reward: -27, 10_Episode_Reward_Avg -274
#  Episode: 503, Episode_Reward: -300, 10_Episode_Reward_Avg -274
#  Episode: 504, Episode_Reward: -252, 10_Episode_Reward_Avg -274
#  Episode: 505, Episode_Reward: -310, 10_Episode_Reward_Avg -272
#  Episode: 506, Episode_Reward: -441, 10_Episode_Reward_Avg -273
#  Episode: 507, Episode_Reward: -283, 10_Episode_Reward_Avg -274
#  Episode: 508, Episode_Reward: -320, 10_Episode_Reward_Avg -274
#  Episode: 509, Episode_Reward: -419, 10_Episode_Reward_Avg -274
#  Episode: 510, Episode_Reward: -144, 10_Episode_Reward_Avg -274
#  Episode: 511, Episode_Reward: -225, 10_Episode_Reward_Avg -270
#  Episode: 512, Episode_Reward: -251, 10_Episode_Reward_Avg -272
#  Episode: 513, Episode_Reward: -495, 10_Episode_Reward_Avg -274
#  Episode: 514, Episode_Reward: -243, 10_Episode_Reward_Avg -272
#  Episode: 515, Episode_Reward: -595, 10_Episode_Reward_Avg -272
#  Episode: 516, Episode_Reward: -235, 10_Episode_Reward_Avg -271
#  Episode: 517, Episode_Reward: -172, 10_Episode_Reward_Avg -268
#  Episode: 518, Episode_Reward: -566, 10_Episode_Reward_Avg -271
#  Episode: 519, Episode_Reward: -225, 10_Episode_Reward_Avg -268
#  Episode: 520, Episode_Reward: -567, 10_Episode_Reward_Avg -272
#  Episode: 521, Episode_Reward: -298, 10_Episode_Reward_Avg -274
#  Episode: 522, Episode_Reward: -236, 10_Episode_Reward_Avg -273
#  Episode: 523, Episode_Reward: -19, 10_Episode_Reward_Avg -271
#  Episode: 524, Episode_Reward: -564, 10_Episode_Reward_Avg -274
#  Episode: 525, Episode_Reward: -60, 10_Episode_Reward_Avg -271
#  Episode: 526, Episode_Reward: -341, 10_Episode_Reward_Avg -272
#  Episode: 527, Episode_Reward: -263, 10_Episode_Reward_Avg -270
#  Episode: 528, Episode_Reward: -183, 10_Episode_Reward_Avg -268
#  Episode: 529, Episode_Reward: -265, 10_Episode_Reward_Avg -269
#  Episode: 530, Episode_Reward: -339, 10_Episode_Reward_Avg -271
#  Episode: 531, Episode_Reward: -185, 10_Episode_Reward_Avg -271
#  Episode: 532, Episode_Reward: -335, 10_Episode_Reward_Avg -271
#  Episode: 533, Episode_Reward: -582, 10_Episode_Reward_Avg -275
#  Episode: 534, Episode_Reward: -120, 10_Episode_Reward_Avg -274
#  Episode: 535, Episode_Reward: -440, 10_Episode_Reward_Avg -277
#  Episode: 536, Episode_Reward: -365, 10_Episode_Reward_Avg -278
#  Episode: 537, Episode_Reward: -246, 10_Episode_Reward_Avg -277
#  Episode: 538, Episode_Reward: -267, 10_Episode_Reward_Avg -274
#  Episode: 539, Episode_Reward: -68, 10_Episode_Reward_Avg -274
#  Episode: 540, Episode_Reward: -396, 10_Episode_Reward_Avg -276
#  Episode: 541, Episode_Reward: -313, 10_Episode_Reward_Avg -276
#  Episode: 542, Episode_Reward: -211, 10_Episode_Reward_Avg -275
#  Episode: 543, Episode_Reward: -278, 10_Episode_Reward_Avg -276
#  Episode: 544, Episode_Reward: -265, 10_Episode_Reward_Avg -273
#  Episode: 545, Episode_Reward: -324, 10_Episode_Reward_Avg -275
#  Episode: 546, Episode_Reward: -231, 10_Episode_Reward_Avg -274
#  Episode: 547, Episode_Reward: -246, 10_Episode_Reward_Avg -271
#  Episode: 548, Episode_Reward: -268, 10_Episode_Reward_Avg -272
#  Episode: 549, Episode_Reward: -399, 10_Episode_Reward_Avg -276
#  Episode: 550, Episode_Reward: -159, 10_Episode_Reward_Avg -274
#  Episode: 551, Episode_Reward: -254, 10_Episode_Reward_Avg -275
#  Episode: 552, Episode_Reward: -206, 10_Episode_Reward_Avg -274
#  Episode: 553, Episode_Reward: -264, 10_Episode_Reward_Avg -274
#  Episode: 554, Episode_Reward: -150, 10_Episode_Reward_Avg -273
#  Episode: 555, Episode_Reward: -276, 10_Episode_Reward_Avg -275
#  Episode: 556, Episode_Reward: -161, 10_Episode_Reward_Avg -273
#  Episode: 557, Episode_Reward: -345, 10_Episode_Reward_Avg -276
#  Episode: 558, Episode_Reward: -266, 10_Episode_Reward_Avg -277
#  Episode: 559, Episode_Reward: -199, 10_Episode_Reward_Avg -277
#  Episode: 560, Episode_Reward: -343, 10_Episode_Reward_Avg -280
#  Episode: 561, Episode_Reward: -520, 10_Episode_Reward_Avg -281
#  Episode: 562, Episode_Reward: -108, 10_Episode_Reward_Avg -280
#  Episode: 563, Episode_Reward: -191, 10_Episode_Reward_Avg -281
#  Episode: 564, Episode_Reward: -124, 10_Episode_Reward_Avg -281
#  Episode: 565, Episode_Reward: -98, 10_Episode_Reward_Avg -279
#  Episode: 566, Episode_Reward: -239, 10_Episode_Reward_Avg -276
#  Episode: 567, Episode_Reward: -453, 10_Episode_Reward_Avg -280
#  Episode: 568, Episode_Reward: -257, 10_Episode_Reward_Avg -282
#  Episode: 569, Episode_Reward: -137, 10_Episode_Reward_Avg -279
#  Episode: 570, Episode_Reward: -227, 10_Episode_Reward_Avg -279
#  Episode: 571, Episode_Reward: -282, 10_Episode_Reward_Avg -283
#  Episode: 572, Episode_Reward: -435, 10_Episode_Reward_Avg -281
#  Episode: 573, Episode_Reward: -396, 10_Episode_Reward_Avg -279
#  Episode: 574, Episode_Reward: -306, 10_Episode_Reward_Avg -276
#  Episode: 575, Episode_Reward: -119, 10_Episode_Reward_Avg -274
#  Episode: 576, Episode_Reward: -116, 10_Episode_Reward_Avg -270
#  Episode: 577, Episode_Reward: -72, 10_Episode_Reward_Avg -268
#  Episode: 578, Episode_Reward: -173, 10_Episode_Reward_Avg -267
#  Episode: 579, Episode_Reward: -274, 10_Episode_Reward_Avg -267
#  Episode: 580, Episode_Reward: -266, 10_Episode_Reward_Avg -269
#  Episode: 581, Episode_Reward: -94, 10_Episode_Reward_Avg -267
#  Episode: 582, Episode_Reward: -375, 10_Episode_Reward_Avg -268
#  Episode: 583, Episode_Reward: -349, 10_Episode_Reward_Avg -271
#  Episode: 584, Episode_Reward: -237, 10_Episode_Reward_Avg -269
#  Episode: 585, Episode_Reward: -211, 10_Episode_Reward_Avg -270
#  Episode: 586, Episode_Reward: -363, 10_Episode_Reward_Avg -270
#  Episode: 587, Episode_Reward: -98, 10_Episode_Reward_Avg -266
#  Episode: 588, Episode_Reward: -247, 10_Episode_Reward_Avg -266
#  Episode: 589, Episode_Reward: -282, 10_Episode_Reward_Avg -266
#  Episode: 590, Episode_Reward: -435, 10_Episode_Reward_Avg -269
#  Episode: 591, Episode_Reward: -234, 10_Episode_Reward_Avg -269
#  Episode: 592, Episode_Reward: -281, 10_Episode_Reward_Avg -269
#  Episode: 593, Episode_Reward: -95, 10_Episode_Reward_Avg -268
#  Episode: 594, Episode_Reward: -394, 10_Episode_Reward_Avg -269
#  Episode: 595, Episode_Reward: -456, 10_Episode_Reward_Avg -271
#  Episode: 596, Episode_Reward: -286, 10_Episode_Reward_Avg -270
#  Episode: 597, Episode_Reward: -268, 10_Episode_Reward_Avg -272
#  Episode: 598, Episode_Reward: -259, 10_Episode_Reward_Avg -273
#  Episode: 599, Episode_Reward: -369, 10_Episode_Reward_Avg -275
#  Episode: 600, Episode_Reward: -663, 10_Episode_Reward_Avg -278
#  Episode: 601, Episode_Reward: -530, 10_Episode_Reward_Avg -281
#  Episode: 602, Episode_Reward: -323, 10_Episode_Reward_Avg -284
#  Episode: 603, Episode_Reward: -384, 10_Episode_Reward_Avg -285
#  Episode: 604, Episode_Reward: -452, 10_Episode_Reward_Avg -287
#  Episode: 605, Episode_Reward: -119, 10_Episode_Reward_Avg -285
#  Episode: 606, Episode_Reward: -330, 10_Episode_Reward_Avg -284
#  Episode: 607, Episode_Reward: -462, 10_Episode_Reward_Avg -286
#  Episode: 608, Episode_Reward: -112, 10_Episode_Reward_Avg -284
#  Episode: 609, Episode_Reward: -109, 10_Episode_Reward_Avg -281
#  Episode: 610, Episode_Reward: -284, 10_Episode_Reward_Avg -282
#  Episode: 611, Episode_Reward: -346, 10_Episode_Reward_Avg -283
#  Episode: 612, Episode_Reward: -467, 10_Episode_Reward_Avg -285
#  Episode: 613, Episode_Reward: -148, 10_Episode_Reward_Avg -282
#  Episode: 614, Episode_Reward: -335, 10_Episode_Reward_Avg -283
#  Episode: 615, Episode_Reward: -603, 10_Episode_Reward_Avg -283
#  Episode: 616, Episode_Reward: -324, 10_Episode_Reward_Avg -284
#  Episode: 617, Episode_Reward: -496, 10_Episode_Reward_Avg -287
#  Episode: 618, Episode_Reward: -131, 10_Episode_Reward_Avg -283
#  Episode: 619, Episode_Reward: -325, 10_Episode_Reward_Avg -284
#  Episode: 620, Episode_Reward: -117, 10_Episode_Reward_Avg -279
#  Episode: 621, Episode_Reward: -358, 10_Episode_Reward_Avg -280
#  Episode: 622, Episode_Reward: -292, 10_Episode_Reward_Avg -280
#  Episode: 623, Episode_Reward: -311, 10_Episode_Reward_Avg -283
#  Episode: 624, Episode_Reward: -197, 10_Episode_Reward_Avg -280
#  Episode: 625, Episode_Reward: -415, 10_Episode_Reward_Avg -283
#  Episode: 626, Episode_Reward: -180, 10_Episode_Reward_Avg -281
#  Episode: 627, Episode_Reward: -342, 10_Episode_Reward_Avg -282
#  Episode: 628, Episode_Reward: -202, 10_Episode_Reward_Avg -282
#  Episode: 629, Episode_Reward: -297, 10_Episode_Reward_Avg -283
#  Episode: 630, Episode_Reward: -211, 10_Episode_Reward_Avg -281
#  Episode: 631, Episode_Reward: -432, 10_Episode_Reward_Avg -284
#  Episode: 632, Episode_Reward: -364, 10_Episode_Reward_Avg -284
#  Episode: 633, Episode_Reward: -287, 10_Episode_Reward_Avg -281
#  Episode: 634, Episode_Reward: -152, 10_Episode_Reward_Avg -282
#  Episode: 635, Episode_Reward: -299, 10_Episode_Reward_Avg -280
#  Episode: 636, Episode_Reward: -316, 10_Episode_Reward_Avg -280
#  Episode: 637, Episode_Reward: -311, 10_Episode_Reward_Avg -280
#  Episode: 638, Episode_Reward: -102, 10_Episode_Reward_Avg -279
#  Episode: 639, Episode_Reward: -224, 10_Episode_Reward_Avg -280
#  Episode: 640, Episode_Reward: -247, 10_Episode_Reward_Avg -279
#  Episode: 641, Episode_Reward: -250, 10_Episode_Reward_Avg -278
#  Episode: 642, Episode_Reward: -490, 10_Episode_Reward_Avg -281
#  Episode: 643, Episode_Reward: -398, 10_Episode_Reward_Avg -282
#  Episode: 644, Episode_Reward: 30, 10_Episode_Reward_Avg -279
#  Episode: 645, Episode_Reward: -382, 10_Episode_Reward_Avg -280
#  Episode: 646, Episode_Reward: -329, 10_Episode_Reward_Avg -281
#  Episode: 647, Episode_Reward: -85, 10_Episode_Reward_Avg -279
#  Episode: 648, Episode_Reward: -705, 10_Episode_Reward_Avg -284
#  Episode: 649, Episode_Reward: -463, 10_Episode_Reward_Avg -284
#  Episode: 650, Episode_Reward: -102, 10_Episode_Reward_Avg -284
#  Episode: 651, Episode_Reward: -287, 10_Episode_Reward_Avg -284
#  Episode: 652, Episode_Reward: -204, 10_Episode_Reward_Avg -284
#  Episode: 653, Episode_Reward: -338, 10_Episode_Reward_Avg -285
#  Episode: 654, Episode_Reward: -90, 10_Episode_Reward_Avg -284
#  Episode: 655, Episode_Reward: -256, 10_Episode_Reward_Avg -284
#  Episode: 656, Episode_Reward: -344, 10_Episode_Reward_Avg -286
#  Episode: 657, Episode_Reward: -320, 10_Episode_Reward_Avg -285
#  Episode: 658, Episode_Reward: -335, 10_Episode_Reward_Avg -286
#  Episode: 659, Episode_Reward: -549, 10_Episode_Reward_Avg -290
#  Episode: 660, Episode_Reward: -545, 10_Episode_Reward_Avg -292
#  Episode: 661, Episode_Reward: -71, 10_Episode_Reward_Avg -287
#  Episode: 662, Episode_Reward: -414, 10_Episode_Reward_Avg -290
#  Episode: 663, Episode_Reward: -334, 10_Episode_Reward_Avg -292
#  Episode: 664, Episode_Reward: -325, 10_Episode_Reward_Avg -294
#  Episode: 665, Episode_Reward: -149, 10_Episode_Reward_Avg -294
#  Episode: 666, Episode_Reward: -133, 10_Episode_Reward_Avg -293
#  Episode: 667, Episode_Reward: -227, 10_Episode_Reward_Avg -291
#  Episode: 668, Episode_Reward: -387, 10_Episode_Reward_Avg -292
#  Episode: 669, Episode_Reward: -330, 10_Episode_Reward_Avg -294
#  Episode: 670, Episode_Reward: -326, 10_Episode_Reward_Avg -295
#  Episode: 671, Episode_Reward: 2, 10_Episode_Reward_Avg -292
#  Episode: 672, Episode_Reward: -295, 10_Episode_Reward_Avg -291
#  Episode: 673, Episode_Reward: -291, 10_Episode_Reward_Avg -290
#  Episode: 674, Episode_Reward: -178, 10_Episode_Reward_Avg -288
#  Episode: 675, Episode_Reward: -129, 10_Episode_Reward_Avg -289
#  Episode: 676, Episode_Reward: -123, 10_Episode_Reward_Avg -289
#  Episode: 677, Episode_Reward: -605, 10_Episode_Reward_Avg -294
#  Episode: 678, Episode_Reward: -306, 10_Episode_Reward_Avg -295
#  Episode: 679, Episode_Reward: -276, 10_Episode_Reward_Avg -295
#  Episode: 680, Episode_Reward: -233, 10_Episode_Reward_Avg -295
#  Episode: 681, Episode_Reward: -242, 10_Episode_Reward_Avg -296
#  Episode: 682, Episode_Reward: -221, 10_Episode_Reward_Avg -295
#  Episode: 683, Episode_Reward: -467, 10_Episode_Reward_Avg -296
#  Episode: 684, Episode_Reward: -574, 10_Episode_Reward_Avg -300
#  Episode: 685, Episode_Reward: -221, 10_Episode_Reward_Avg -300
#  Episode: 686, Episode_Reward: -237, 10_Episode_Reward_Avg -298
#  Episode: 687, Episode_Reward: -318, 10_Episode_Reward_Avg -301
#  Episode: 688, Episode_Reward: -189, 10_Episode_Reward_Avg -300
#  Episode: 689, Episode_Reward: -243, 10_Episode_Reward_Avg -300
#  Episode: 690, Episode_Reward: -428, 10_Episode_Reward_Avg -300
#  Episode: 691, Episode_Reward: -250, 10_Episode_Reward_Avg -300
#  Episode: 692, Episode_Reward: -256, 10_Episode_Reward_Avg -299
#  Episode: 693, Episode_Reward: -146, 10_Episode_Reward_Avg -300
#  Episode: 694, Episode_Reward: -164, 10_Episode_Reward_Avg -298
#  Episode: 695, Episode_Reward: -230, 10_Episode_Reward_Avg -295
#  Episode: 696, Episode_Reward: -388, 10_Episode_Reward_Avg -296
#  Episode: 697, Episode_Reward: -161, 10_Episode_Reward_Avg -295
#  Episode: 698, Episode_Reward: -245, 10_Episode_Reward_Avg -295
#  Episode: 699, Episode_Reward: -225, 10_Episode_Reward_Avg -294
#  Episode: 700, Episode_Reward: -327, 10_Episode_Reward_Avg -290
#  Episode: 701, Episode_Reward: -216, 10_Episode_Reward_Avg -287
#  Episode: 702, Episode_Reward: -517, 10_Episode_Reward_Avg -289
#  Episode: 703, Episode_Reward: -106, 10_Episode_Reward_Avg -286
#  Episode: 704, Episode_Reward: -238, 10_Episode_Reward_Avg -284
#  Episode: 705, Episode_Reward: -316, 10_Episode_Reward_Avg -286
#  Episode: 706, Episode_Reward: -278, 10_Episode_Reward_Avg -286
#  Episode: 707, Episode_Reward: -291, 10_Episode_Reward_Avg -284
#  Episode: 708, Episode_Reward: -398, 10_Episode_Reward_Avg -287
#  Episode: 709, Episode_Reward: -257, 10_Episode_Reward_Avg -288
#  Episode: 710, Episode_Reward: -329, 10_Episode_Reward_Avg -289
#  Episode: 711, Episode_Reward: -289, 10_Episode_Reward_Avg -288
#  Episode: 712, Episode_Reward: 8, 10_Episode_Reward_Avg -284
#  Episode: 713, Episode_Reward: -338, 10_Episode_Reward_Avg -285
#  Episode: 714, Episode_Reward: -323, 10_Episode_Reward_Avg -285
#  Episode: 715, Episode_Reward: -64, 10_Episode_Reward_Avg -280
#  Episode: 716, Episode_Reward: -238, 10_Episode_Reward_Avg -279
#  Episode: 717, Episode_Reward: -102, 10_Episode_Reward_Avg -275
#  Episode: 718, Episode_Reward: -343, 10_Episode_Reward_Avg -277
#  Episode: 719, Episode_Reward: -367, 10_Episode_Reward_Avg -278
#  Episode: 720, Episode_Reward: -471, 10_Episode_Reward_Avg -281
#  Episode: 721, Episode_Reward: -249, 10_Episode_Reward_Avg -280
#  Episode: 722, Episode_Reward: -179, 10_Episode_Reward_Avg -279
#  Episode: 723, Episode_Reward: -364, 10_Episode_Reward_Avg -279
#  Episode: 724, Episode_Reward: -130, 10_Episode_Reward_Avg -279
#  Episode: 725, Episode_Reward: -422, 10_Episode_Reward_Avg -279
#  Episode: 726, Episode_Reward: -413, 10_Episode_Reward_Avg -281
#  Episode: 727, Episode_Reward: -128, 10_Episode_Reward_Avg -279
#  Episode: 728, Episode_Reward: -218, 10_Episode_Reward_Avg -279
#  Episode: 729, Episode_Reward: -282, 10_Episode_Reward_Avg -279
#  Episode: 730, Episode_Reward: -245, 10_Episode_Reward_Avg -279
#  Episode: 731, Episode_Reward: -302, 10_Episode_Reward_Avg -278
#  Episode: 732, Episode_Reward: -183, 10_Episode_Reward_Avg -276
#  Episode: 733, Episode_Reward: -310, 10_Episode_Reward_Avg -277
#  Episode: 734, Episode_Reward: -376, 10_Episode_Reward_Avg -279
#  Episode: 735, Episode_Reward: -79, 10_Episode_Reward_Avg -277
#  Episode: 736, Episode_Reward: -230, 10_Episode_Reward_Avg -276
#  Episode: 737, Episode_Reward: -201, 10_Episode_Reward_Avg -275
#  Episode: 738, Episode_Reward: -96, 10_Episode_Reward_Avg -275
#  Episode: 739, Episode_Reward: -208, 10_Episode_Reward_Avg -274
#  Episode: 740, Episode_Reward: -471, 10_Episode_Reward_Avg -277
#  Episode: 741, Episode_Reward: -39, 10_Episode_Reward_Avg -275
#  Episode: 742, Episode_Reward: -473, 10_Episode_Reward_Avg -274
#  Episode: 743, Episode_Reward: -302, 10_Episode_Reward_Avg -273
#  Episode: 744, Episode_Reward: -287, 10_Episode_Reward_Avg -277
#  Episode: 745, Episode_Reward: -288, 10_Episode_Reward_Avg -276
#  Episode: 746, Episode_Reward: -280, 10_Episode_Reward_Avg -275
#  Episode: 747, Episode_Reward: -319, 10_Episode_Reward_Avg -277
#  Episode: 748, Episode_Reward: -145, 10_Episode_Reward_Avg -272
#  Episode: 749, Episode_Reward: -269, 10_Episode_Reward_Avg -270
